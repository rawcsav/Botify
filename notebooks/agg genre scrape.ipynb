# %%
from bs4 import BeautifulSoup
import requests, sys
import pandas as pd
import os
import re
import time

from threading import get_ident
from multiprocessing import cpu_count
import asyncio
from concurrent.futures import ThreadPoolExecutor as PoolExecuter

from joblib.externals.loky import set_loky_pickler
from joblib import parallel_backend, Parallel, delayed, wrap_non_picklable_objects

def chunkIt(seq, num):
    avg = len(seq) / float(num)
    out = []
    last = 0.0
    while last < len(seq):
        out.append(seq[int(last):int(last + avg)])
        last += avg
    return out

r = requests.get("http://everynoise.com/engenremap.html")

# %%
import re
import sys
import requests
from bs4 import BeautifulSoup
from requests.exceptions import RequestException
from multiprocessing import cpu_count

def fetch_artists(soup):
    all_artist_divs = set(soup.find_all("div", "genre scanme"))
    artist_list = []
    art_weights = []

    for artist in all_artist_divs:
        weight = artist['style'].split()[-1].replace('%', '')
        artist_name = artist.text.strip().replace("»", "")

        if not artist_name.isspace():
            art_weights.append(weight)
            artist_list.append(artist_name)

    return artist_list, art_weights


def fetch_similar_and_opposite_genres(soup, subgenre_name):
    all_genres_related = set(soup.find_all("div", "genre"))
    all_artist_divs = set(soup.find_all("div", "genre scanme"))
    all_genres_related = all_genres_related - all_artist_divs

    similar_genres = []
    opposite_genres = []
    sim_weights = []
    opp_weights = []

    for other_genre in all_genres_related:
        weight = other_genre['style'].split()[-1].replace('%', '')

        if 'nearby' in other_genre['id']:
            genre = other_genre.text.strip().replace("»", '')

            if genre != subgenre_name:
                sim_weights.append(weight)
                similar_genres.append(genre)

        elif 'mirror' in other_genre['id']:
            opp_weights.append(weight)
            opposite_genres.append(other_genre.text.strip().replace("»", ''))

    return similar_genres, sim_weights, opposite_genres, opp_weights


def genre_scraper(subgenre_subset):
    # Metadata
    subgenre_list_artist = []
    subgenre_list_opp = []
    subgenre_list_sim = []
    subgenre_list = []
    playlists = []
    sim_weights = []
    opp_weights = []
    artist_weights = []

    split_genrecount = 0

    # Maximum number of allowed retries
    max_attempts = 5

    # Looping over subgenres to get metadata
    for genreDiv in subgenre_subset:
        subgenre = re.sub("[:'+»&\s-]", '', genreDiv)
        subgenre_name = re.sub("[:+»\s]", ' ', genreDiv).strip()
        subgenre_list.append(subgenre_name)

        # Printing Genre Name
        sys.stdout.flush()
        print('Pulling genre # {} - Subgenre: {}\n'.format(split_genrecount, subgenre_name))
        sys.stdout.flush()

        # Fetch the subgenre
        subgenre_page = 'http://everynoise.com/engenremap-' + subgenre + '.html'
        skip_subgenre = False

        # Retry the request with a maximum number of attempts
        for attempt in range(max_attempts):
            try:
                r2 = requests.get(subgenre_page, timeout=10)
                break
            except RequestException as e:
                if attempt < max_attempts - 1:
                    print(f"Request {subgenre_page} failed with error '{e}', retrying... (attempt {attempt+1})")
                else:
                    print(f"Max retries exceeded for {subgenre_page}. Skipping...")
                    skip_subgenre = True
                    break

        if skip_subgenre:
            continue

        soup2 = BeautifulSoup(r2.text, 'html.parser')

        # Get the Spotify playlist link
        spotify_link = soup2.find_all('a', text='playlist')
        playlists.append(spotify_link[0]['href'] if spotify_link else None)

        # Fetch artists associated with the subgenre
        artist_list, art_weights = fetch_artists(soup2)
        subgenre_list_artist.append(artist_list)
        artist_weights.append(art_weights)

        # Get similar / opposite genres
        sim_genres, sim_gen_weights, opp_genres, opp_gen_weights = fetch_similar_and_opposite_genres(soup2, subgenre_name)
        subgenre_list_sim.append(sim_genres)
        subgenre_list_opp.append(opp_genres)
        sim_weights.append(sim_gen_weights)
        opp_weights.append(opp_gen_weights)

        split_genrecount += 1

    return [subgenre_list, playlists, subgenre_list_sim, sim_weights, subgenre_list_opp, opp_weights, subgenre_list_artist, artist_weights]

def parallel_wrapper(allGenreDivs, n_jobs=cpu_count()):
    subgenre_subsets = chunkIt(allGenreDivs, n_jobs)
    results = Parallel(n_jobs=n_jobs)(delayed(genre_scraper)(subset) for subset in subgenre_subsets)
    res = list(map(list, zip(*results)))
    res_2 = []
    
    for i in res:
        q = []
        for j in i:
            q += j
        res_2.append(q)

    return res_2

# %%
soup = BeautifulSoup(r.text,"html.parser")
allGenreDivs = soup.find_all("div", "genre scanme")
agd = []
for i in allGenreDivs:
    agd.append(i.text)
t1 = time.time()
music_data = parallel_wrapper(agd)
t2 = time.time()
print('Time Taken to Gather Data: {:.02f}s'.format(t2-t1))
# Out:
# Pulling genre # 0 - Subgenre: musica feirense
#
# Pulling genre # 0 - Subgenre: comedy
#
# Pulling genre # 0 - Subgenre: rap salvadoreno
#
# Pulling genre # 0 - Subgenre: dangdut
#
# Pulling genre # 0 - Subgenre: galician rock
#
# Pulling genre # 0 - Subgenre: pop
#
# Pulling genre # 0 - Subgenre: south sudanese pop
#
# Pulling genre # 0 - Subgenre: tallava
#
# Pulling genre # 1 - Subgenre: fort worth indie
#
# Pulling genre # 1 - Subgenre: bisaya worship
#
# Pulling genre # 1 - Subgenre: garifuna folk
#
# Pulling genre # 1 - Subgenre: street punk espanol
#
# Pulling genre # 1 - Subgenre: german boom bap
#
# Pulling genre # 1 - Subgenre: chicago house
#
# Pulling genre # 1 - Subgenre: rap
#
# Pulling genre # 1 - Subgenre: trancecore
#
# Pulling genre # 2 - Subgenre: meenawati
#
# Pulling genre # 2 - Subgenre: zim gospel
#
# Pulling genre # 2 - Subgenre: jazz puertorriqueno
#
# Pulling genre # 2 - Subgenre: congolese gospel
#
# Pulling genre # 2 - Subgenre: pianissimo
#
# Pulling genre # 2 - Subgenre: shabad
#
# Pulling genre # 2 - Subgenre: rock
#
# Pulling genre # 2 - Subgenre: indie game soundtrack
#
# Pulling genre # 3 - Subgenre: mountain dulcimer
#
# Pulling genre # 3 - Subgenre: american orchestra
#
# Pulling genre # 3 - Subgenre: electronica chilena
#
# Pulling genre # 3 - Subgenre: glitch pop
#
# Pulling genre # 3 - Subgenre: ectofolk
#
# Pulling genre # 3 - Subgenre: dance pop
#
# Pulling genre # 3 - Subgenre: jamaican hip hop
#
# Pulling genre # 3 - Subgenre: adventista
#
# Pulling genre # 4 - Subgenre: chamber ensemble
#
# Pulling genre # 4 - Subgenre: persian traditional
#
# Pulling genre # 4 - Subgenre: hard rock mexicano
#
# Pulling genre # 4 - Subgenre: taiwanese indie
#
# Pulling genre # 4 - Subgenre: bandinhas
#
# Pulling genre # 4 - Subgenre: chutney
#
# Pulling genre # 4 - Subgenre: urbano latino
#
# Pulling genre # 4 - Subgenre: cape town indie
#
# Pulling genre # 5 - Subgenre: australian thrash metal
#
# Pulling genre # 5 - Subgenre: baja indie
#
# Pulling genre # 5 - Subgenre: draga
#
# Pulling genre # 5 - Subgenre: swedish techno
#
# Pulling genre # 5 - Subgenre: slowcore
#
# Pulling genre # 5 - Subgenre: rap catala
#
# Pulling genre # 5 - Subgenre: indonesian ska
#
# Pulling genre # 5 - Subgenre: hip hop
#
# Pulling genre # 6 - Subgenre: polka nortena
#
# Pulling genre # 6 - Subgenre: swazi pop
#
# Pulling genre # 6 - Subgenre: coupe-decale
#
# Pulling genre # 6 - Subgenre: drill dominicano
#
# Pulling genre # 6 - Subgenre: music box
#
# Pulling genre # 6 - Subgenre: christian indie
#
# Pulling genre # 6 - Subgenre: croatian rock
#
# Pulling genre # 6 - Subgenre: trap latino
#
# Pulling genre # 7 - Subgenre: bornehistorier
#
# Pulling genre # 7 - Subgenre: utah metal
#
# Pulling genre # 7 - Subgenre: greek guitar
#
# Pulling genre # 7 - Subgenre: jazz mexicano
#
# Pulling genre # 7 - Subgenre: emo trap italiana
#
# Pulling genre # 7 - Subgenre: french synthpop
#
# Pulling genre # 7 - Subgenre: jazz trio
#
# Pulling genre # 7 - Subgenre: reggaeton
#
# Pulling genre # 8 - Subgenre: neo grime
#
# Pulling genre # 8 - Subgenre: new england hardcore
#
# Pulling genre # 8 - Subgenre: sonora indie
#
# Pulling genre # 8 - Subgenre: progressive power metal
#
# Pulling genre # 8 - Subgenre: christian punk
#
# Pulling genre # 8 - Subgenre: rkt
#
# Pulling genre # 8 - Subgenre: liedermacher
#
# Pulling genre # 8 - Subgenre: modern rock
#
# Pulling genre # 9 - Subgenre: heavy gothic rock
#
# Pulling genre # 9 - Subgenre: muzica bisericeasca
#
# Pulling genre # 9 - Subgenre: american melodeath
#
# Pulling genre # 9 - Subgenre: canadian hardcore
#
# Pulling genre # 9 - Subgenre: post-hardcore
#
# Pulling genre # 9 - Subgenre: grindcore
#
# Pulling genre # 9 - Subgenre: rochester mn indie
#
# Pulling genre # 10 - Subgenre: chinese classical
#
# Pulling genre # 10 - Subgenre: dutch death metal
#
# Pulling genre # 9 - Subgenre: latin pop
#
# Pulling genre # 10 - Subgenre: nitzhonot
#
# Pulling genre # 10 - Subgenre: chamame
#
# Pulling genre # 10 - Subgenre: uk funky
#
# Pulling genre # 10 - Subgenre: experimental vocal
#
# Pulling genre # 10 - Subgenre: swedish soul
#
# Pulling genre # 11 - Subgenre: brazilian stoner rock
#
# Pulling genre # 11 - Subgenre: spanish jazz
#
# Pulling genre # 11 - Subgenre: dutch blues
#
# Pulling genre # 10 - Subgenre: trap
#
# Pulling genre # 11 - Subgenre: ambient post-rock
#
# Pulling genre # 11 - Subgenre: greek pop
#
# Pulling genre # 11 - Subgenre: indie dream pop
#
# Pulling genre # 11 - Subgenre: samba moderno
#
# Pulling genre # 12 - Subgenre: singaporean indie
#
# Pulling genre # 12 - Subgenre: pornogrind
#
# Pulling genre # 12 - Subgenre: macedonian indie
#
# Pulling genre # 11 - Subgenre: musica mexicana
#
# Pulling genre # 12 - Subgenre: deep latin alternative
#
# Pulling genre # 12 - Subgenre: chinese electropop
#
# Pulling genre # 12 - Subgenre: melbourne bounce
#
# Pulling genre # 12 - Subgenre: pop chileno
#
# Pulling genre # 13 - Subgenre: galway indie
#
# Pulling genre # 13 - Subgenre: spanish electropop
#
# Pulling genre # 13 - Subgenre: west african jazz
#
# Pulling genre # 13 - Subgenre: ambient psychill
#
# Pulling genre # 12 - Subgenre: classic rock
#
# Pulling genre # 13 - Subgenre: russian viral pop
#
# Pulling genre # 13 - Subgenre: spanish modern rock
#
# Pulling genre # 13 - Subgenre: deep tropical house
#
# Pulling genre # 14 - Subgenre: vintage french psychedelic
#
# Pulling genre # 14 - Subgenre: chennai indie
#
# Pulling genre # 14 - Subgenre: new isolationism
#
# Pulling genre # 14 - Subgenre: gothic black metal
#
# Pulling genre # 13 - Subgenre: permanent wave
#
# Pulling genre # 14 - Subgenre: jamtronica
#
# Pulling genre # 14 - Subgenre: jangle pop
#
# Pulling genre # 14 - Subgenre: hard rock brasileiro
#
# Pulling genre # 15 - Subgenre: portuguese indie rock
#
# Pulling genre # 15 - Subgenre: dragspel
#
# Pulling genre # 15 - Subgenre: austin singer-songwriter
#
# Pulling genre # 15 - Subgenre: greek downtempo
#
# Pulling genre # 15 - Subgenre: folclore santiagueno
#
# Pulling genre # 15 - Subgenre: ska revival
#
# Pulling genre # 14 - Subgenre: alternative metal
#
# Pulling genre # 15 - Subgenre: london rap
#
# Pulling genre # 16 - Subgenre: bodo pop
#
# Pulling genre # 16 - Subgenre: minimal synth
#
# Pulling genre # 16 - Subgenre: deep liquid bass
#
# Pulling genre # 16 - Subgenre: string duo
#
# Pulling genre # 16 - Subgenre: kundalini
#
# Pulling genre # 16 - Subgenre: rai
#
# Pulling genre # 16 - Subgenre: gospel
#
# Pulling genre # 15 - Subgenre: pop rap
#
# Pulling genre # 17 - Subgenre: australian post-rock
#
# Pulling genre # 17 - Subgenre: arab experimental
#
# Pulling genre # 17 - Subgenre: swiss indie folk
#
# Pulling genre # 17 - Subgenre: austrian hip hop
#
# Pulling genre # 17 - Subgenre: flamenco guitar
#
# Pulling genre # 17 - Subgenre: modern indie folk
#
# Pulling genre # 17 - Subgenre: japanese chillhop
#
# Pulling genre # 16 - Subgenre: r&b
#
# Pulling genre # 18 - Subgenre: malagasy folk
#
# Pulling genre # 18 - Subgenre: baps
#
# Pulling genre # 18 - Subgenre: freakbeat
#
# Pulling genre # 18 - Subgenre: thai pop rap
#
# Pulling genre # 18 - Subgenre: afroswing
#
# Pulling genre # 18 - Subgenre: maga rap
#
# Pulling genre # 18 - Subgenre: trova mexicana
#
# Pulling genre # 17 - Subgenre: pop dance
#
# Pulling genre # 19 - Subgenre: dambora
#
# Pulling genre # 19 - Subgenre: indie singer-songwriter
#
# Pulling genre # 19 - Subgenre: chinese jazz
#
# Pulling genre # 19 - Subgenre: uk dub
#
# Pulling genre # 19 - Subgenre: new jersey hardcore
#
# Pulling genre # 19 - Subgenre: seattle hip hop
#
# Pulling genre # 19 - Subgenre: ostrock
#
# Pulling genre # 20 - Subgenre: instrumental death metal
#
# Pulling genre # 18 - Subgenre: edm
#
# Pulling genre # 20 - Subgenre: norwegian doom metal
#
# Pulling genre # 20 - Subgenre: math pop
#
# Pulling genre # 20 - Subgenre: cantautor catala
#
# Pulling genre # 20 - Subgenre: hawaiian hip hop
#
# Pulling genre # 20 - Subgenre: afrobeat
#
# Pulling genre # 20 - Subgenre: cumbia uruguaya
#
# Pulling genre # 21 - Subgenre: avant-rock
#
# Pulling genre # 19 - Subgenre: corrido
#
# Pulling genre # 21 - Subgenre: rock goiano
#
# Pulling genre # 21 - Subgenre: cosmic death metal
#
# Pulling genre # 21 - Subgenre: nordic post-rock
#
# Pulling genre # 21 - Subgenre: brill building pop
#
# Pulling genre # 21 - Subgenre: neomelodici
#
# Pulling genre # 21 - Subgenre: musica llanera
#
# Pulling genre # 22 - Subgenre: raw black metal
#
# Pulling genre # 22 - Subgenre: brazilian post-hardcore
#
# Pulling genre # 22 - Subgenre: muzica usoara
#
# Pulling genre # 22 - Subgenre: hardstyle
#
# Pulling genre # 20 - Subgenre: norteno
#
# Pulling genre # 22 - Subgenre: anime lo-fi
#
# Pulling genre # 23 - Subgenre: polish post-rock
#
# Pulling genre # 22 - Subgenre: slc indie
#
# Pulling genre # 22 - Subgenre: musica popular mineira
# Pulling genre # 23 - Subgenre: canadian black metal
#
# Pulling genre # 23 - Subgenre: danzon
#
# Pulling genre # 23 - Subgenre: vincy soca
#
# Pulling genre # 23 - Subgenre: cumbia peruana
#
# Pulling genre # 21 - Subgenre: album rock
#
# Pulling genre # 24 - Subgenre: ugandan hip hop
#
# Pulling genre # 23 - Subgenre: french tech house
#
# Pulling genre # 23 - Subgenre: czech punk
#
# Pulling genre # 24 - Subgenre: polyphonies corses
#
# Pulling genre # 24 - Subgenre: beach music
#
# Pulling genre # 24 - Subgenre: rock chapin
#
# Pulling genre # 24 - Subgenre: intelligent dance music
#
# Pulling genre # 25 - Subgenre: candombe
#
# Pulling genre # 24 - Subgenre: lesen
#
# Pulling genre # 22 - Subgenre: contemporary country
#
# Pulling genre # 24 - Subgenre: touhou
#
# Pulling genre # 25 - Subgenre: samba gospel
#
# Pulling genre # 25 - Subgenre: arkansas indie
#
# Pulling genre # 25 - Subgenre: trival
#
# Pulling genre # 25 - Subgenre: ocean
#
# Pulling genre # 26 - Subgenre: finnish electronic
#
# Pulling genre # 25 - Subgenre: russian edm
#
# Pulling genre # 23 - Subgenre: filmi
#
# Pulling genre # 25 - Subgenre: cumbia ecuatoriana
#
# Pulling genre # 26 - Subgenre: indonesian deathcore
#
# Pulling genre # 26 - Subgenre: cavernous death metal
#
# Pulling genre # 26 - Subgenre: slovenian electronic
#
# Pulling genre # 27 - Subgenre: medimeisterschaften
#
# Pulling genre # 26 - Subgenre: rap uliczny
#
# Pulling genre # 26 - Subgenre: comic metal
#
# Pulling genre # 26 - Subgenre: aggrotech
#
# Pulling genre # 27 - Subgenre: cascadian black metal
#
# Pulling genre # 27 - Subgenre: deep funk ostentacao
#
# Pulling genre # 24 - Subgenre: canadian pop
#
# Pulling genre # 27 - Subgenre: funk evangelico
#
# Pulling genre # 28 - Subgenre: dansk comedy
#
# Pulling genre # 27 - Subgenre: yugoslav rock
#
# Pulling genre # 27 - Subgenre: partyschlager
#
# Pulling genre # 28 - Subgenre: trash rock
#
# Pulling genre # 27 - Subgenre: sung poetry
#
# Pulling genre # 28 - Subgenre: pop ambient
#
# Pulling genre # 25 - Subgenre: k-pop
#
# Pulling genre # 28 - Subgenre: deep metalcore
#
# Pulling genre # 29 - Subgenre: finnish rockabilly
#
# Pulling genre # 28 - Subgenre: electra
#
# Pulling genre # 28 - Subgenre: islamic recitation
#
# Pulling genre # 28 - Subgenre: channel islands indie
#
# Pulling genre # 29 - Subgenre: classical trumpet
#
# Pulling genre # 29 - Subgenre: dunedin indie
#
# Pulling genre # 29 - Subgenre: tamazight
#
# Pulling genre # 26 - Subgenre: nueva musica mexicana
#
# Pulling genre # 30 - Subgenre: russian choir
#
# Pulling genre # 29 - Subgenre: reggae tuga
#
# Pulling genre # 29 - Subgenre: boston folk
#
# Pulling genre # 29 - Subgenre: copla
#
# Pulling genre # 30 - Subgenre: japanese classical performance
#
# Pulling genre # 30 - Subgenre: rennes indie
#
# Pulling genre # 30 - Subgenre: norwegian space disco
#
# Pulling genre # 31 - Subgenre: lesotho traditional
#
# Pulling genre # 27 - Subgenre: soft rock
#
# Pulling genre # 30 - Subgenre: pop quebecois
#
# Pulling genre # 30 - Subgenre: hindi indie
#
# Pulling genre # 30 - Subgenre: cuban alternative
#
# Pulling genre # 31 - Subgenre: indy indie
#
# Pulling genre # 31 - Subgenre: russian old school hip hop
#
# Pulling genre # 31 - Subgenre: nordic classical piano
#
# Pulling genre # 32 - Subgenre: abstractro
#
# Pulling genre # 28 - Subgenre: sierreno
#
# Pulling genre # 31 - Subgenre: ska mexicano
#
# Pulling genre # 31 - Subgenre: pastoral
#
# Pulling genre # 31 - Subgenre: nu age
#
# Pulling genre # 32 - Subgenre: telugu hip hop
#
# Pulling genre # 32 - Subgenre: german thrash metal
#
# Pulling genre # 32 - Subgenre: minimal dnb
#
# Pulling genre # 33 - Subgenre: italo beats
#
# Pulling genre # 29 - Subgenre: hard rock
#
# Pulling genre # 32 - Subgenre: big beat
#
# Pulling genre # 32 - Subgenre: tecnobrega
#
# Pulling genre # 32 - Subgenre: viet lo-fi
#
# Pulling genre # 33 - Subgenre: pune indie
#
# Pulling genre # 33 - Subgenre: salsa urbana
#
# Pulling genre # 33 - Subgenre: deep ragga
#
# Pulling genre # 34 - Subgenre: japanese melodic hardcore
#
# Pulling genre # 33 - Subgenre: doo-wop
#
# Pulling genre # 30 - Subgenre: post-teen pop
#
# Pulling genre # 33 - Subgenre: oyun havasi
#
# Pulling genre # 34 - Subgenre: austrian techno
#
# Pulling genre # 33 - Subgenre: louisville indie
#
# Pulling genre # 34 - Subgenre: icelandic electronic
#
# Pulling genre # 34 - Subgenre: panpipe
#
# Pulling genre # 35 - Subgenre: korean musicals
#
# Pulling genre # 34 - Subgenre: australian indie rock
#
# Pulling genre # 34 - Subgenre: german trap
#
# Pulling genre # 31 - Subgenre: uk pop
#
# Pulling genre # 35 - Subgenre: byzantine
#
# Pulling genre # 34 - Subgenre: fidget house
#
# Pulling genre # 35 - Subgenre: rock keyboard
#
# Pulling genre # 35 - Subgenre: russian techno
#
# Pulling genre # 36 - Subgenre: kinderchor
#
# Pulling genre # 35 - Subgenre: south african house
#
# Pulling genre # 36 - Subgenre: polish folk
#
# Pulling genre # 35 - Subgenre: pop romantico
#
# Pulling genre # 35 - Subgenre: sudanese pop
#
# Pulling genre # 32 - Subgenre: sad sierreno
#
# Pulling genre # 36 - Subgenre: rumeli turkuleri
#
# Pulling genre # 36 - Subgenre: musique pour enfant quebecois
#
# Pulling genre # 37 - Subgenre: zeuhl
#
# Pulling genre # 37 - Subgenre: acousmatic
#
# Pulling genre # 36 - Subgenre: filthstep
#
# Pulling genre # 36 - Subgenre: experimental hip hop
#
# Pulling genre # 36 - Subgenre: deathrash
#
# Pulling genre # 37 - Subgenre: ilahiler
#
# Pulling genre # 33 - Subgenre: nu metal
#
# Pulling genre # 37 - Subgenre: yoga
#
# Pulling genre # 38 - Subgenre: leon gto indie
#
# Pulling genre # 38 - Subgenre: go-go
#
# Pulling genre # 37 - Subgenre: musica aragonesa
#
# Pulling genre # 37 - Subgenre: african reggae
#
# Pulling genre # 37 - Subgenre: chinese viral pop
#
# Pulling genre # 38 - Subgenre: south african deep house
#
# Pulling genre # 34 - Subgenre: mellow gold
#
# Pulling genre # 38 - Subgenre: salsa cristiana
#
# Pulling genre # 39 - Subgenre: christian thrash metal
#
# Pulling genre # 39 - Subgenre: french oi
#
# Pulling genre # 38 - Subgenre: italian opera
#
# Pulling genre # 38 - Subgenre: poezja spiewana
#
# Pulling genre # 39 - Subgenre: indie rock peruano
#
# Pulling genre # 35 - Subgenre: melodic rap
#
# Pulling genre # 39 - Subgenre: russian pop punk
#
# Pulling genre # 38 - Subgenre: salsa colombiana
#
# Pulling genre # 40 - Subgenre: italian post-rock
#
# Pulling genre # 40 - Subgenre: argentine jazz
#
# Pulling genre # 39 - Subgenre: welsh metal
#
# Pulling genre # 39 - Subgenre: paisley underground
#
# Pulling genre # 40 - Subgenre: audiophile vocal
#
# Pulling genre # 36 - Subgenre: country
#
# Pulling genre # 40 - Subgenre: mandible
#
# Pulling genre # 39 - Subgenre: sigilkore
#
# Pulling genre # 41 - Subgenre: tuna estudiantil
#
# Pulling genre # 40 - Subgenre: kansas city hip hop
#
# Pulling genre # 41 - Subgenre: kuduro antigo
#
# Pulling genre # 40 - Subgenre: reggae catala
#
# Pulling genre # 41 - Subgenre: tatar pop
#
# Pulling genre # 41 - Subgenre: polyphony
#
# Pulling genre # 40 - Subgenre: frauenrap
#
# Pulling genre # 37 - Subgenre: post-grunge
#
# Pulling genre # 42 - Subgenre: viola
#
# Pulling genre # 41 - Subgenre: wrestling
#
# Pulling genre # 42 - Subgenre: latvian rock
#
# Pulling genre # 41 - Subgenre: raw techno
#
# Pulling genre # 42 - Subgenre: vintage hollywood
#
# Pulling genre # 41 - Subgenre: progressive bluegrass
#
# Pulling genre # 42 - Subgenre: chattanooga indie
#
# Pulling genre # 38 - Subgenre: desi pop
#
# Pulling genre # 43 - Subgenre: tibetan traditional
#
# Pulling genre # 43 - Subgenre: indie salvadoreno
#
# Pulling genre # 42 - Subgenre: symphonic power metal
#
# Pulling genre # 43 - Subgenre: alberta hip hop
#
# Pulling genre # 42 - Subgenre: german trance
#
# Pulling genre # 43 - Subgenre: ecuadorian alternative rock
#
# Pulling genre # 44 - Subgenre: raga rock
#
# Pulling genre # 39 - Subgenre: alt z
#
# Pulling genre # 44 - Subgenre: grenada soca
#
# Pulling genre # 43 - Subgenre: classic iskelma
#
# Pulling genre # 44 - Subgenre: musica jalisciense
#
# Pulling genre # 43 - Subgenre: plugg francais
#
# Pulling genre # 44 - Subgenre: folk black metal
#
# Pulling genre # 45 - Subgenre: greek jazz
#
# Pulling genre # 42 - Subgenre: cumbia
#
# Pulling genre # 40 - Subgenre: banda
#
# Pulling genre # 45 - Subgenre: jazz accordion
#
# Pulling genre # 45 - Subgenre: chinese drama ost
#
# Pulling genre # 44 - Subgenre: turntablism
#
# Pulling genre # 44 - Subgenre: samba-rock
#
# Pulling genre # 45 - Subgenre: technical black metal
#
# Pulling genre # 46 - Subgenre: musique concrete
#
# Pulling genre # 43 - Subgenre: trap soul
#
# Pulling genre # 46 - Subgenre: deep psychobilly
#
# Pulling genre # 41 - Subgenre: urban contemporary
# Pulling genre # 46 - Subgenre: trap maroc
#
# Pulling genre # 45 - Subgenre: drone metal
#
# Pulling genre # 45 - Subgenre: arab electronic
#
# Pulling genre # 46 - Subgenre: serbian electronic
#
# Pulling genre # 47 - Subgenre: streichquartett
#
# Pulling genre # 44 - Subgenre: folklore argentino
#
# Pulling genre # 47 - Subgenre: lao pop
#
# Pulling genre # 42 - Subgenre: sertanejo universitario
#
# Pulling genre # 47 - Subgenre: rhode island indie
#
# Pulling genre # 46 - Subgenre: dream trance
#
# Pulling genre # 46 - Subgenre: drain
#
# Pulling genre # 47 - Subgenre: sheilat
#
# Pulling genre # 48 - Subgenre: folclore castilla y leon
#
# Pulling genre # 45 - Subgenre: boston rock
#
# Pulling genre # 48 - Subgenre: indie pop rock
#
# Pulling genre # 43 - Subgenre: alternative rock
#
# Pulling genre # 48 - Subgenre: pittsburgh rock
#
# Pulling genre # 47 - Subgenre: christian afrobeat
#
# Pulling genre # 47 - Subgenre: classic french pop
#
# Pulling genre # 48 - Subgenre: berlin minimal techno
#
# Pulling genre # 49 - Subgenre: grim death metal
#
# Pulling genre # 46 - Subgenre: rome indie
#
# Pulling genre # 49 - Subgenre: bhojpuri folk
#
# Pulling genre # 49 - Subgenre: hiplife
#
# Pulling genre # 44 - Subgenre: art pop
#
# Pulling genre # 48 - Subgenre: anime latino
#
# Pulling genre # 48 - Subgenre: dutch cabaret
#
# Pulling genre # 49 - Subgenre: gamecore
#
# Pulling genre # 50 - Subgenre: hangoskonyvek
#
# Pulling genre # 47 - Subgenre: j-rap
#
# Pulling genre # 49 - Subgenre: modern uplift
#
# Pulling genre # 45 - Subgenre: modern bollywood
#
# Pulling genre # 49 - Subgenre: viking folk
#
# Pulling genre # 50 - Subgenre: swiss singer-songwriter
#
# Pulling genre # 51 - Subgenre: norwegian punk
#
# Pulling genre # 50 - Subgenre: rap moldovenesc
#
# Pulling genre # 50 - Subgenre: german indie rock
#
# Pulling genre # 50 - Subgenre: oriental metal
#
# Pulling genre # 48 - Subgenre: greek hip hop
#
# Pulling genre # 51 - Subgenre: concert band
#
# Pulling genre # 50 - Subgenre: idol kayo
#
# Pulling genre # 46 - Subgenre: atl hip hop
#
# Pulling genre # 52 - Subgenre: deep vocal house
#
# Pulling genre # 51 - Subgenre: hull indie
#
# Pulling genre # 51 - Subgenre: deep christian rock
#
# Pulling genre # 51 - Subgenre: huayno
#
# Pulling genre # 49 - Subgenre: visual kei
#
# Pulling genre # 53 - Subgenre: hardingfele
#
# Pulling genre # 52 - Subgenre: chicano punk
#
# Pulling genre # 51 - Subgenre: rap underground mexicano
#
# Pulling genre # 47 - Subgenre: reggaeton colombiano
#
# Pulling genre # 52 - Subgenre: japanese post-punk
#
# Pulling genre # 52 - Subgenre: charanga
#
# Pulling genre # 52 - Subgenre: boogaloo
#
# Pulling genre # 54 - Subgenre: koto
#
# Pulling genre # 53 - Subgenre: french dnb
#
# Pulling genre # 48 - Subgenre: singer-songwriter
#
# Pulling genre # 50 - Subgenre: classic indonesian rock
#
# Pulling genre # 53 - Subgenre: german post-punk
#
# Pulling genre # 52 - Subgenre: minimalism
#
# Pulling genre # 53 - Subgenre: leeds indie
#
# Pulling genre # 53 - Subgenre: melbourne indie
#
# Pulling genre # 55 - Subgenre: ohangla
#
# Pulling genre # 54 - Subgenre: swahili gospel
#
# Pulling genre # 51 - Subgenre: afro r&b
#
# Pulling genre # 49 - Subgenre: country road
#
# Pulling genre # 54 - Subgenre: rap sureno chileno
#
# Pulling genre # 53 - Subgenre: gothic rock
#
# Pulling genre # 54 - Subgenre: talentkonkurranse
#
# Pulling genre # 54 - Subgenre: comedie musicale
#
# Pulling genre # 56 - Subgenre: western ny metal
#
# Pulling genre # 52 - Subgenre: ska punk
#
# Pulling genre # 55 - Subgenre: punta rock
#
# Pulling genre # 55 - Subgenre: uk rockabilly
#
# Pulling genre # 50 - Subgenre: colombian pop
#
# Pulling genre # 54 - Subgenre: bgm
#
# Pulling genre # 55 - Subgenre: belgian dnb
#
# Pulling genre # 55 - Subgenre: chopped and screwed
#
# Pulling genre # 57 - Subgenre: swiss punk
#
# Pulling genre # 56 - Subgenre: puglia indie
#
# Pulling genre # 53 - Subgenre: argentine telepop
#
# Pulling genre # 56 - Subgenre: portuguese black metal
#
# Pulling genre # 55 - Subgenre: theme
#
# Pulling genre # 51 - Subgenre: tropical house
#
# Pulling genre # 56 - Subgenre: choro
#
# Pulling genre # 56 - Subgenre: elektropunk
#
# Pulling genre # 58 - Subgenre: pontian folk
#
# Pulling genre # 54 - Subgenre: anadolu rock
#
# Pulling genre # 57 - Subgenre: dirty texas rap
#
# Pulling genre # 57 - Subgenre: guidance
#
# Pulling genre # 56 - Subgenre: australian garage punk
#
# Pulling genre # 52 - Subgenre: arrocha
#
# Pulling genre # 57 - Subgenre: vaqueiro
#
# Pulling genre # 57 - Subgenre: norwegian classical
#
# Pulling genre # 59 - Subgenre: korean classical performance
#
# Pulling genre # 55 - Subgenre: nwobhm
#
# Pulling genre # 58 - Subgenre: mexican hardcore
#
# Pulling genre # 58 - Subgenre: telugu remix
#
# Pulling genre # 58 - Subgenre: neo metal
#
# Pulling genre # 57 - Subgenre: icelandic experimental
#
# Pulling genre # 53 - Subgenre: french hip hop
#
# Pulling genre # 58 - Subgenre: jersey club
#
# Pulling genre # 60 - Subgenre: swedish grindcore
#
# Pulling genre # 59 - Subgenre: emoviolence
#
# Pulling genre # 56 - Subgenre: uplifting trance
#
# Pulling genre # 59 - Subgenre: greek psychedelic rock
#
# Pulling genre # 58 - Subgenre: turkish edm
#
# Pulling genre # 59 - Subgenre: andean flute
#
# Pulling genre # 59 - Subgenre: latincore
#
# Pulling genre # 54 - Subgenre: corridos tumbados
#
# Pulling genre # 61 - Subgenre: folk cantabria
#
# Pulling genre # 60 - Subgenre: musica colombiana instrumental
#
# Pulling genre # 60 - Subgenre: polish folk metal
#
# Pulling genre # 57 - Subgenre: argentine reggae
#
# Pulling genre # 59 - Subgenre: volkspop
#
# Pulling genre # 60 - Subgenre: jazz organ
#
# Pulling genre # 62 - Subgenre: deep smooth r&b
#
# Pulling genre # 60 - Subgenre: trap metal italiana
#
# Pulling genre # 55 - Subgenre: southern hip hop
#
# Pulling genre # 61 - Subgenre: drikkelek
#
# Pulling genre # 61 - Subgenre: classical cello
#
# Pulling genre # 58 - Subgenre: vapor twitch
#
# Pulling genre # 60 - Subgenre: bouncy house
#
# Pulling genre # 61 - Subgenre: marathi devotional
#
# Pulling genre # 61 - Subgenre: swedish metalcore
#
# Pulling genre # 63 - Subgenre: iraqi hip hop
#
# Pulling genre # 62 - Subgenre: fado antigo
#
# Pulling genre # 56 - Subgenre: pop urbaine
#
# Pulling genre # 62 - Subgenre: lagu aceh
#
# Pulling genre # 59 - Subgenre: detroit rock
#
# Pulling genre # 62 - Subgenre: 432hz
#
# Pulling genre # 61 - Subgenre: nottingham hip hop
#
# Pulling genre # 64 - Subgenre: israeli traditional
#
# Pulling genre # 62 - Subgenre: brazilian house
#
# Pulling genre # 63 - Subgenre: musiikkia lapista
#
# Pulling genre # 57 - Subgenre: indietronica
#
# Pulling genre # 63 - Subgenre: gospel italiano
#
# Pulling genre # 60 - Subgenre: contemporary post-bop
#
# Pulling genre # 63 - Subgenre: german literature
#
# Pulling genre # 62 - Subgenre: glitchbreak
#
# Pulling genre # 65 - Subgenre: neo-proto
#
# Pulling genre # 63 - Subgenre: geek folk
#
# Pulling genre # 64 - Subgenre: acid idm
#
# Pulling genre # 64 - Subgenre: dutch jazz
#
# Pulling genre # 58 - Subgenre: mexican pop
#
# Pulling genre # 61 - Subgenre: british soundtrack
#
# Pulling genre # 63 - Subgenre: kabarett
#
# Pulling genre # 64 - Subgenre: new orleans indie
#
# Pulling genre # 64 - Subgenre: italian metal
#
# Pulling genre # 66 - Subgenre: neo-trad prog
#
# Pulling genre # 65 - Subgenre: czech electronic
#
# Pulling genre # 65 - Subgenre: christian hard rock
#
# Pulling genre # 65 - Subgenre: reggae mexicano
#
# Pulling genre # 62 - Subgenre: jamaican dancehall
#
# Pulling genre # 59 - Subgenre: sertanejo
#
# Pulling genre # 64 - Subgenre: transpop
#
# Pulling genre # 65 - Subgenre: kannada hip hop
#
# Pulling genre # 67 - Subgenre: hypertrance
#
# Pulling genre # 66 - Subgenre: rap gaucho
#
# Pulling genre # 66 - Subgenre: gengetone
#
# Pulling genre # 66 - Subgenre: bomba
#
# Pulling genre # 65 - Subgenre: czech drill
#
# Pulling genre # 60 - Subgenre: indie pop
#
# Pulling genre # 63 - Subgenre: basshall
#
# Pulling genre # 66 - Subgenre: alternative pop
#
# Pulling genre # 68 - Subgenre: prague indie
#
# Pulling genre # 67 - Subgenre: seattle metal
#
# Pulling genre # 67 - Subgenre: uilleann pipes
#
# Pulling genre # 66 - Subgenre: trap antillais
#
# Pulling genre # 67 - Subgenre: deep uplifting trance
#
# Pulling genre # 64 - Subgenre: ukrainian pop
#
# Pulling genre # 61 - Subgenre: pop punk
#
# Pulling genre # 67 - Subgenre: enka
#
# Pulling genre # 69 - Subgenre: glitter trance
#
# Pulling genre # 68 - Subgenre: yemeni pop
#
# Pulling genre # 68 - Subgenre: eritrean pop
#
# Pulling genre # 68 - Subgenre: library music
#
# Pulling genre # 67 - Subgenre: diy emo
# Pulling genre # 65 - Subgenre: musica infantil
#
# Pulling genre # 62 - Subgenre: gangster rap
#
# Pulling genre # 69 - Subgenre: japanese techno
#
# Pulling genre # 70 - Subgenre: danish folk
#
# Pulling genre # 68 - Subgenre: british modern classical
#
# Pulling genre # 69 - Subgenre: contemporary folk
#
# Pulling genre # 69 - Subgenre: korean indie folk
#
# Pulling genre # 68 - Subgenre: rap boricua
#
# Pulling genre # 66 - Subgenre: gujarati pop
#
# Pulling genre # 63 - Subgenre: latin alternative
#
# Pulling genre # 71 - Subgenre: oromo pop
#
# Pulling genre # 69 - Subgenre: hokkaido indie
#
# Pulling genre # 70 - Subgenre: guam indie
#
# Pulling genre # 70 - Subgenre: worcester ma indie
#
# Pulling genre # 70 - Subgenre: west australian hip hop
#
# Pulling genre # 69 - Subgenre: rock independant francais
#
# Pulling genre # 67 - Subgenre: rock urbano mexicano
#
# Pulling genre # 64 - Subgenre: ranchera
#
# Pulling genre # 70 - Subgenre: modern hardcore
#
# Pulling genre # 72 - Subgenre: anime game
#
# Pulling genre # 71 - Subgenre: sesotho pop
#
# Pulling genre # 71 - Subgenre: minneapolis metal
#
# Pulling genre # 71 - Subgenre: post-black metal
#
# Pulling genre # 70 - Subgenre: australian indigenous
#
# Pulling genre # 68 - Subgenre: diva house
#
# Pulling genre # 65 - Subgenre: new wave pop
#
# Pulling genre # 73 - Subgenre: maghreb
#
# Pulling genre # 72 - Subgenre: rock campineiro
#
# Pulling genre # 71 - Subgenre: asheville indie
#
# Pulling genre # 72 - Subgenre: experimental club
#
# Pulling genre # 72 - Subgenre: instrumental surf
#
# Pulling genre # 69 - Subgenre: kentucky indie
#
# Pulling genre # 71 - Subgenre: uk experimental electronic
#
# Pulling genre # 74 - Subgenre: indie psychedelic rock
#
# Pulling genre # 73 - Subgenre: rap toscana
#
# Pulling genre # 72 - Subgenre: bristol indie
#
# Pulling genre # 66 - Subgenre: j-pop
#
# Pulling genre # 73 - Subgenre: german black metal
#
# Pulling genre # 70 - Subgenre: northern soul
#
# Pulling genre # 73 - Subgenre: zillertal
#
# Pulling genre # 72 - Subgenre: vintage french electronic
#
# Pulling genre # 75 - Subgenre: re techno
#
# Pulling genre # 74 - Subgenre: indie cantabria
#
# Pulling genre # 73 - Subgenre: american post-rock
#
# Pulling genre # 67 - Subgenre: electropop
#
# Pulling genre # 74 - Subgenre: british experimental
#
# Pulling genre # 71 - Subgenre: high vibe
#
# Pulling genre # 73 - Subgenre: portland indie
#
# Pulling genre # 74 - Subgenre: bali indie
#
# Pulling genre # 76 - Subgenre: adivasi pop
#
# Pulling genre # 75 - Subgenre: danish experimental
#
# Pulling genre # 74 - Subgenre: drill brasileiro
#
# Pulling genre # 68 - Subgenre: rock en espanol
#
# Pulling genre # 75 - Subgenre: indie veneto
#
# Pulling genre # 72 - Subgenre: vancouver indie
#
# Pulling genre # 75 - Subgenre: japanese garage rock
#
# Pulling genre # 74 - Subgenre: native american
#
# Pulling genre # 77 - Subgenre: botswana pop
#
# Pulling genre # 76 - Subgenre: georgian electronic
#
# Pulling genre # 75 - Subgenre: reading indie
#
# Pulling genre # 69 - Subgenre: german hip hop
#
# Pulling genre # 76 - Subgenre: texas hardcore
#
# Pulling genre # 76 - Subgenre: jazz brass
#
# Pulling genre # 73 - Subgenre: classic opm
#
# Pulling genre # 78 - Subgenre: classical percussion
#
# Pulling genre # 75 - Subgenre: east coast reggae
#
# Pulling genre # 77 - Subgenre: mexican death metal
#
# Pulling genre # 76 - Subgenre: arkansas hip hop
#
# Pulling genre # 70 - Subgenre: canadian contemporary r&b
#
# Pulling genre # 77 - Subgenre: brazilian hardcore
#
# Pulling genre # 77 - Subgenre: trinidadian reggae
#
# Pulling genre # 76 - Subgenre: samba-jazz
#
# Pulling genre # 79 - Subgenre: lithuanian folk
#
# Pulling genre # 74 - Subgenre: persian pop
#
# Pulling genre # 77 - Subgenre: chinderlieder
#
# Pulling genre # 78 - Subgenre: japanese progressive house
#
# Pulling genre # 71 - Subgenre: soul
#
# Pulling genre # 78 - Subgenre: west virginia indie
#
# Pulling genre # 77 - Subgenre: hungarian rock
#
# Pulling genre # 80 - Subgenre: modern electroacoustic
#
# Pulling genre # 79 - Subgenre: liechtenstein
#
# Pulling genre # 78 - Subgenre: british black metal
#
# Pulling genre # 78 - Subgenre: canadian metalcore
#
# Pulling genre # 75 - Subgenre: musica de fondo
#
# Pulling genre # 72 - Subgenre: neo mellow
#
# Pulling genre # 79 - Subgenre: south african underground rap
#
# Pulling genre # 80 - Subgenre: jazzcore
#
# Pulling genre # 81 - Subgenre: american classical piano
#
# Pulling genre # 79 - Subgenre: japanese jazz
#
# Pulling genre # 79 - Subgenre: porro
#
# Pulling genre # 78 - Subgenre: ska chileno
#
# Pulling genre # 76 - Subgenre: pinoy r&b
#
# Pulling genre # 73 - Subgenre: italian pop
#
# Pulling genre # 80 - Subgenre: power thrash
#
# Pulling genre # 81 - Subgenre: taiwanese indigenous
#
# Pulling genre # 82 - Subgenre: chill-out trance
#
# Pulling genre # 80 - Subgenre: german ccm
#
# Pulling genre # 80 - Subgenre: musical advocacy
#
# Pulling genre # 79 - Subgenre: progressive psytrance
#
# Pulling genre # 77 - Subgenre: new jersey underground rap
#
# Pulling genre # 74 - Subgenre: electro house
#
# Pulling genre # 81 - Subgenre: canadian psychedelic rock
#
# Pulling genre # 83 - Subgenre: tabla
#
# Pulling genre # 82 - Subgenre: swedish rock-and-roll
#
# Pulling genre # 81 - Subgenre: swing italiano
#
# Pulling genre # 81 - Subgenre: american modern classical
#
# Pulling genre # 80 - Subgenre: indian classical
#
# Pulling genre # 78 - Subgenre: electronica argentina
#
# Pulling genre # 82 - Subgenre: mongolian pop
#
# Pulling genre # 84 - Subgenre: russian death metal
#
# Pulling genre # 83 - Subgenre: symphonic melodic death metal
#
# Pulling genre # 82 - Subgenre: irish neo-traditional
#
# Pulling genre # 75 - Subgenre: latin hip hop
#
# Pulling genre # 82 - Subgenre: electro-industrial
#
# Pulling genre # 79 - Subgenre: instrumental worship
#
# Pulling genre # 81 - Subgenre: vaporwave
#
# Pulling genre # 83 - Subgenre: string folk
#
# Pulling genre # 85 - Subgenre: bengali folk
#
# Pulling genre # 84 - Subgenre: nz hardcore
#
# Pulling genre # 83 - Subgenre: dark jazz
#
# Pulling genre # 76 - Subgenre: latin arena pop
#
# Pulling genre # 83 - Subgenre: michigan indie
#
# Pulling genre # 80 - Subgenre: manguebeat
#
# Pulling genre # 82 - Subgenre: russian grime
#
# Pulling genre # 84 - Subgenre: solomon islands pop
#
# Pulling genre # 85 - Subgenre: prog quebec
#
# Pulling genre # 86 - Subgenre: indian instrumental rock
#
# Pulling genre # 84 - Subgenre: coco
#
# Pulling genre # 77 - Subgenre: k-pop boy group
#
# Pulling genre # 84 - Subgenre: brass band
#
# Pulling genre # 81 - Subgenre: stoner metal
#
# Pulling genre # 83 - Subgenre: ambeat
#
# Pulling genre # 86 - Subgenre: russian romance
#
# Pulling genre # 85 - Subgenre: east anglia indie
#
# Pulling genre # 87 - Subgenre: molam
#
# Pulling genre # 85 - Subgenre: phleng phuea chiwit
#
# Pulling genre # 85 - Subgenre: chanson virale
#
# Pulling genre # 78 - Subgenre: heartland rock
#
# Pulling genre # 82 - Subgenre: ambient worship
#
# Pulling genre # 84 - Subgenre: japanese viral pop
#
# Pulling genre # 88 - Subgenre: dark black metal
#
# Pulling genre # 86 - Subgenre: acid trance
#
# Pulling genre # 86 - Subgenre: halftime dnb
#
# Pulling genre # 87 - Subgenre: balkan folk metal
#
# Pulling genre # 86 - Subgenre: electro dub
#
# Pulling genre # 79 - Subgenre: chicago rap
#
# Pulling genre # 83 - Subgenre: german indie
#
# Pulling genre # 85 - Subgenre: brazilian punk
#
# Pulling genre # 89 - Subgenre: indie hidrocalido
#
# Pulling genre # 87 - Subgenre: traditional british folk
#
# Pulling genre # 88 - Subgenre: musica queretana
#
# Pulling genre # 87 - Subgenre: experimental indie
#
# Pulling genre # 87 - Subgenre: neo-traditional country
#
# Pulling genre # 80 - Subgenre: pop rock
#
# Pulling genre # 84 - Subgenre: uk dnb
#
# Pulling genre # 89 - Subgenre: italian stoner rock
#
# Pulling genre # 88 - Subgenre: brazilian percussion
#
# Pulling genre # 86 - Subgenre: japanese metalcore
#
# Pulling genre # 90 - Subgenre: guitarra portuguesa
#
# Pulling genre # 88 - Subgenre: naija old school
#
# Pulling genre # 88 - Subgenre: progressive trance house
#
# Pulling genre # 81 - Subgenre: canadian hip hop
#
# Pulling genre # 90 - Subgenre: rock cearense
#
# Pulling genre # 89 - Subgenre: okinawan folk
#
# Pulling genre # 87 - Subgenre: kavkaz
#
# Pulling genre # 91 - Subgenre: medieval ensemble
#
# Pulling genre # 89 - Subgenre: dark progressive house
#
# Pulling genre # 85 - Subgenre: grupero romantico
#
# Pulling genre # 89 - Subgenre: cuban rumba
#
# Pulling genre # 82 - Subgenre: k-pop girl group
#
# Pulling genre # 92 - Subgenre: rajasthani folk
#
# Pulling genre # 90 - Subgenre: pinoy drill
#
# Pulling genre # 91 - Subgenre: street punk
#
# Pulling genre # 88 - Subgenre: swedish indie folk
#
# Pulling genre # 86 - Subgenre: new school turkce rap
#
# Pulling genre # 90 - Subgenre: gospel singers
# Pulling genre # 90 - Subgenre: indonesian blues
#
# Pulling genre # 83 - Subgenre: latin rock
#
# Pulling genre # 91 - Subgenre: pinoy praise
#
# Pulling genre # 93 - Subgenre: luxembourgian hip hop
#
# Pulling genre # 89 - Subgenre: pop nacional antigas
#
# Pulling genre # 92 - Subgenre: serbian indie
#
# Pulling genre # 91 - Subgenre: drift
#
# Pulling genre # 91 - Subgenre: ottawa indie
#
# Pulling genre # 87 - Subgenre: italian underground hip hop
#
# Pulling genre # 84 - Subgenre: rap metal
#
# Pulling genre # 92 - Subgenre: malayalam indie
#
# Pulling genre # 93 - Subgenre: hip hop galsen
#
# Pulling genre # 94 - Subgenre: romanian contemporary classical
#
# Pulling genre # 90 - Subgenre: parody
#
# Pulling genre # 92 - Subgenre: kingston on indie
#
# Pulling genre # 92 - Subgenre: french garage rock
#
# Pulling genre # 88 - Subgenre: toronto indie
#
# Pulling genre # 85 - Subgenre: modern alternative rock
#
# Pulling genre # 95 - Subgenre: tuna
#
# Pulling genre # 94 - Subgenre: rap abc paulista
#
# Pulling genre # 93 - Subgenre: underground amapiano
#
# Pulling genre # 91 - Subgenre: geek rock
#
# Pulling genre # 93 - Subgenre: downtempo bass
#
# Pulling genre # 93 - Subgenre: ukrainian folk pop
#
# Pulling genre # 89 - Subgenre: australian indie folk
#
# Pulling genre # 86 - Subgenre: conscious hip hop
#
# Pulling genre # 96 - Subgenre: eletronica underground brasileira
#
# Pulling genre # 92 - Subgenre: pinoy indie
#
# Pulling genre # 95 - Subgenre: musica eletronica brasileira
#
# Pulling genre # 94 - Subgenre: corrosion
#
# Pulling genre # 94 - Subgenre: hong kong indie
#
# Pulling genre # 94 - Subgenre: detske pisnicky
#
# Pulling genre # 90 - Subgenre: jazz trumpet
#
# Pulling genre # 87 - Subgenre: uk dance
#
# Pulling genre # 97 - Subgenre: haitian traditional
#
# Pulling genre # 96 - Subgenre: pinoy edm
#
# Pulling genre # 95 - Subgenre: japanese dream pop
#
# Pulling genre # 93 - Subgenre: classic house
#
# Pulling genre # 95 - Subgenre: calgary indie
#
# Pulling genre # 95 - Subgenre: beach house
#
# Pulling genre # 91 - Subgenre: rock gospel brasileiro
#
# Pulling genre # 88 - Subgenre: toronto rap
#
# Pulling genre # 98 - Subgenre: dutch folk
#
# Pulling genre # 97 - Subgenre: fort wayne indie
#
# Pulling genre # 96 - Subgenre: israeli folk
#
# Pulling genre # 94 - Subgenre: karadeniz pop
#
# Pulling genre # 96 - Subgenre: irish metal
#
# Pulling genre # 96 - Subgenre: libyan pop
#
# Pulling genre # 92 - Subgenre: swedish alternative rock
#
# Pulling genre # 99 - Subgenre: colorado hardcore
#
# Pulling genre # 89 - Subgenre: new wave
#
# Pulling genre # 98 - Subgenre: harmonica jazz
#
# Pulling genre # 97 - Subgenre: canterbury scene
#
# Pulling genre # 95 - Subgenre: country gospel
#
# Pulling genre # 97 - Subgenre: mezmur
#
# Pulling genre # 97 - Subgenre: french indie folk
#
# Pulling genre # 93 - Subgenre: progressive trance
#
# Pulling genre # 100 - Subgenre: new jack smooth
#
# Pulling genre # 90 - Subgenre: indie rock
#
# Pulling genre # 99 - Subgenre: coventry indie
#
# Pulling genre # 98 - Subgenre: spiritual hip hop
#
# Pulling genre # 96 - Subgenre: peruvian rock
#
# Pulling genre # 98 - Subgenre: riddim dubstep
#
# Pulling genre # 98 - Subgenre: guitarra clasica
#
# Pulling genre # 94 - Subgenre: instrumental rock
#
# Pulling genre # 101 - Subgenre: irish ballad
#
# Pulling genre # 100 - Subgenre: rap ecuatoriano
#
# Pulling genre # 91 - Subgenre: viral pop
#
# Pulling genre # 99 - Subgenre: latvian hip hop
#
# Pulling genre # 99 - Subgenre: musica nublensina
#
# Pulling genre # 97 - Subgenre: korean instrumental
#
# Pulling genre # 99 - Subgenre: west coast trap
#
# Pulling genre # 95 - Subgenre: japanese soul
#
# Pulling genre # 102 - Subgenre: portuguese death metal
#
# Pulling genre # 101 - Subgenre: old school uk hip hop
#
# Pulling genre # 92 - Subgenre: indonesian pop
#
# Pulling genre # 100 - Subgenre: jackin' house
#
# Pulling genre # 98 - Subgenre: gabba
#
# Pulling genre # 100 - Subgenre: accordeon
#
# Pulling genre # 100 - Subgenre: rock piauiense
#
# Pulling genre # 96 - Subgenre: hip hop tuga
#
# Pulling genre # 103 - Subgenre: irish gaelic folk
#
# Pulling genre # 102 - Subgenre: assyrian pop
#
# Pulling genre # 101 - Subgenre: underground power pop
#
# Pulling genre # 93 - Subgenre: folk rock
#
# Pulling genre # 99 - Subgenre: punjabi lo-fi
#
# Pulling genre # 101 - Subgenre: bolobedu house
#
# Pulling genre # 101 - Subgenre: vintage italian pop
#
# Pulling genre # 97 - Subgenre: psychedelic hip hop
#
# Pulling genre # 104 - Subgenre: brazilian contemporary classical
#
# Pulling genre # 103 - Subgenre: string quartet
#
# Pulling genre # 100 - Subgenre: hip hop quebecois
#
# Pulling genre # 94 - Subgenre: new romantic
#
# Pulling genre # 102 - Subgenre: ugandan pop
#
# Pulling genre # 102 - Subgenre: speed garage
#
# Pulling genre # 102 - Subgenre: gospel rap
#
# Pulling genre # 105 - Subgenre: croatian folk
#
# Pulling genre # 98 - Subgenre: hungarian pop
#
# Pulling genre # 104 - Subgenre: persian neo-traditional
#
# Pulling genre # 95 - Subgenre: house
#
# Pulling genre # 103 - Subgenre: power-pop punk
#
# Pulling genre # 103 - Subgenre: jazz double bass
#
# Pulling genre # 103 - Subgenre: punk tuga
#
# Pulling genre # 101 - Subgenre: scandinavian r&b
#
# Pulling genre # 106 - Subgenre: umea indie
#
# Pulling genre # 99 - Subgenre: rebel blues
#
# Pulling genre # 105 - Subgenre: myanmar hip hop
#
# Pulling genre # 96 - Subgenre: east coast hip hop
#
# Pulling genre # 104 - Subgenre: lithuanian indie
#
# Pulling genre # 102 - Subgenre: israeli hip hop
#
# Pulling genre # 104 - Subgenre: gaian doom
#
# Pulling genre # 104 - Subgenre: rare groove
#
# Pulling genre # 107 - Subgenre: dutch stoner rock
#
# Pulling genre # 106 - Subgenre: japanese prog
#
# Pulling genre # 100 - Subgenre: trap baiano
#
# Pulling genre # 105 - Subgenre: socal indie
#
# Pulling genre # 105 - Subgenre: canadian post-punk
#
# Pulling genre # 103 - Subgenre: croatian pop
#
# Pulling genre # 105 - Subgenre: mappila paattu
#
# Pulling genre # 97 - Subgenre: metal
#
# Pulling genre # 108 - Subgenre: spanish baroque
#
# Pulling genre # 107 - Subgenre: modular techno
#
# Pulling genre # 101 - Subgenre: traditional blues
#
# Pulling genre # 106 - Subgenre: kids dance party
#
# Pulling genre # 106 - Subgenre: orchestral performance
#
# Pulling genre # 106 - Subgenre: japanese shoegaze
#
# Pulling genre # 104 - Subgenre: indonesian reggae
#
# Pulling genre # 98 - Subgenre: italian hip hop
#
# Pulling genre # 109 - Subgenre: latin american heavy psych
#
# Pulling genre # 108 - Subgenre: musique mahoraise
#
# Pulling genre # 102 - Subgenre: vocal house
#
# Pulling genre # 107 - Subgenre: louange
#
# Pulling genre # 105 - Subgenre: slovak hip hop
#
# Pulling genre # 107 - Subgenre: action rock
#
# Pulling genre # 107 - Subgenre: pop peruano
#
# Pulling genre # 110 - Subgenre: mainland se asia metal
#
# Pulling genre # 109 - Subgenre: gotlandsk musik
#
# Pulling genre # 99 - Subgenre: trap argentino
#
# Pulling genre # 103 - Subgenre: indian indie
#
# Pulling genre # 108 - Subgenre: japanese idm
#
# Pulling genre # 106 - Subgenre: new weird america
#
# Pulling genre # 108 - Subgenre: sevdah
#
# Pulling genre # 108 - Subgenre: kent indie
#
# Pulling genre # 111 - Subgenre: belgian punk
#
# Pulling genre # 100 - Subgenre: bedroom pop
#
# Pulling genre # 110 - Subgenre: krajiska muzika
#
# Pulling genre # 104 - Subgenre: canadian contemporary country
#
# Pulling genre # 109 - Subgenre: nordic ambient
#
# Pulling genre # 107 - Subgenre: texas pop punk
#
# Pulling genre # 109 - Subgenre: darkstep
#
# Pulling genre # 112 - Subgenre: rock nica
#
# Pulling genre # 109 - Subgenre: rumba congolaise
#
# Pulling genre # 111 - Subgenre: goa psytrance
#
# Pulling genre # 101 - Subgenre: hoerspiel
#
# Pulling genre # 105 - Subgenre: ghazal
#
# Pulling genre # 110 - Subgenre: modern swing
#
# Pulling genre # 108 - Subgenre: acoustic rock
#
# Pulling genre # 110 - Subgenre: serbian hip hop
#
# Pulling genre # 113 - Subgenre: dutch punk rock
#
# Pulling genre # 110 - Subgenre: multidisciplinary
#
# Pulling genre # 112 - Subgenre: brazilian lo-fi rock
#
# Pulling genre # 106 - Subgenre: j-division
#
# Pulling genre # 102 - Subgenre: slap house
#
# Pulling genre # 111 - Subgenre: ambient black metal
#
# Pulling genre # 109 - Subgenre: korean old school hip hop
#
# Pulling genre # 114 - Subgenre: horror punk brasileiro
#
# Pulling genre # 111 - Subgenre: horrorcore
#
# Pulling genre # 111 - Subgenre: slack-key guitar
#
# Pulling genre # 113 - Subgenre: murga
#
# Pulling genre # 103 - Subgenre: west coast rap
#
# Pulling genre # 112 - Subgenre: dronescape
#
# Pulling genre # 107 - Subgenre: lo-fi
# Pulling genre # 110 - Subgenre: easycore
#
# Pulling genre # 114 - Subgenre: honky-tonk piano
#
# Pulling genre # 115 - Subgenre: rap sergipano
#
# Pulling genre # 112 - Subgenre: new mexico music
#
# Pulling genre # 112 - Subgenre: medieval folk
#
# Pulling genre # 104 - Subgenre: talent show
#
# Pulling genre # 113 - Subgenre: memphis indie
#
# Pulling genre # 108 - Subgenre: dangdut koplo
#
# Pulling genre # 115 - Subgenre: taiwan metal
#
# Pulling genre # 116 - Subgenre: belarusian metal
#
# Pulling genre # 111 - Subgenre: indie rockism
#
# Pulling genre # 113 - Subgenre: norsk lovsang
#
# Pulling genre # 113 - Subgenre: japanese chill rap
#
# Pulling genre # 105 - Subgenre: boy band
#
# Pulling genre # 114 - Subgenre: ambient trance
#
# Pulling genre # 116 - Subgenre: italian post-hardcore
#
# Pulling genre # 109 - Subgenre: rock alternativo brasileiro
#
# Pulling genre # 117 - Subgenre: norwegian blues
#
# Pulling genre # 112 - Subgenre: american folk revival
#
# Pulling genre # 114 - Subgenre: chinese traditional
#
# Pulling genre # 114 - Subgenre: tanzanian pop
#
# Pulling genre # 106 - Subgenre: miami hip hop
#
# Pulling genre # 115 - Subgenre: deep funk house
#
# Pulling genre # 117 - Subgenre: scottish fiddle
#
# Pulling genre # 118 - Subgenre: slash punk
#
# Pulling genre # 110 - Subgenre: jazz saxophone
#
# Pulling genre # 113 - Subgenre: brisbane indie
#
# Pulling genre # 115 - Subgenre: harp
#
# Pulling genre # 115 - Subgenre: early synthpop
#
# Pulling genre # 107 - Subgenre: underground hip hop
#
# Pulling genre # 116 - Subgenre: guinean pop
#
# Pulling genre # 118 - Subgenre: rasiya
#
# Pulling genre # 119 - Subgenre: rock progresivo mexicano
#
# Pulling genre # 111 - Subgenre: corridos clasicos
#
# Pulling genre # 114 - Subgenre: uk garage
#
# Pulling genre # 116 - Subgenre: detroit house
#
# Pulling genre # 116 - Subgenre: classic nz pop
#
# Pulling genre # 119 - Subgenre: bohemian baroque
#
# Pulling genre # 108 - Subgenre: spanish pop
#
# Pulling genre # 117 - Subgenre: polish contemporary classical
#
# Pulling genre # 120 - Subgenre: muzica ardeleneasca
#
# Pulling genre # 112 - Subgenre: taiwan singer-songwriter
#
# Pulling genre # 115 - Subgenre: chinese indie
#
# Pulling genre # 117 - Subgenre: oulu metal
#
# Pulling genre # 117 - Subgenre: dark hardcore
#
# Pulling genre # 120 - Subgenre: tennessee experimental
#
# Pulling genre # 118 - Subgenre: japanese worship
#
# Pulling genre # 121 - Subgenre: armenian indie
#
# Pulling genre # 109 - Subgenre: neo soul
#
# Pulling genre # 113 - Subgenre: rap df
#
# Pulling genre # 118 - Subgenre: bajki
#
# Pulling genre # 116 - Subgenre: north east england indie
#
# Pulling genre # 118 - Subgenre: bluegrass gospel
#
# Pulling genre # 121 - Subgenre: australian jazz
#
# Pulling genre # 119 - Subgenre: danish singer-songwriter
#
# Pulling genre # 122 - Subgenre: mento
#
# Pulling genre # 110 - Subgenre: glam metal
#
# Pulling genre # 119 - Subgenre: spanish post-punk
#
# Pulling genre # 117 - Subgenre: electro jazz
#
# Pulling genre # 114 - Subgenre: j-acoustic
#
# Pulling genre # 119 - Subgenre: rap uruguayo
#
# Pulling genre # 120 - Subgenre: russian dnb
#
# Pulling genre # 122 - Subgenre: mevlevi sufi
#
# Pulling genre # 123 - Subgenre: rock sergipano
#
# Pulling genre # 111 - Subgenre: puerto rican pop
#
# Pulling genre # 120 - Subgenre: deathrock
#
# Pulling genre # 115 - Subgenre: colombian hip hop
#
# Pulling genre # 118 - Subgenre: german indie folk
#
# Pulling genre # 120 - Subgenre: new orleans funk
#
# Pulling genre # 121 - Subgenre: finnish pop punk
#
# Pulling genre # 123 - Subgenre: native american spiritual
#
# Pulling genre # 124 - Subgenre: min'yo
#
# Pulling genre # 112 - Subgenre: glam rock
#
# Pulling genre # 119 - Subgenre: polish underground rap
#
# Pulling genre # 121 - Subgenre: classic azeri pop
#
# Pulling genre # 116 - Subgenre: cool jazz
#
# Pulling genre # 121 - Subgenre: musica oaxaquena
#
# Pulling genre # 122 - Subgenre: gypsy fusion
#
# Pulling genre # 124 - Subgenre: ostschlager
#
# Pulling genre # 125 - Subgenre: northamptonshire indie
#
# Pulling genre # 113 - Subgenre: stomp and holler
#
# Pulling genre # 122 - Subgenre: funk mexicano
#
# Pulling genre # 117 - Subgenre: banda jalisciense
#
# Pulling genre # 120 - Subgenre: neoclassicism
#
# Pulling genre # 122 - Subgenre: nerdcore
#
# Pulling genre # 123 - Subgenre: hmong pop
#
# Pulling genre # 125 - Subgenre: hypnosis
#
# Pulling genre # 126 - Subgenre: marimba
#
# Pulling genre # 114 - Subgenre: progressive house
#
# Pulling genre # 123 - Subgenre: romanian electronic
#
# Pulling genre # 121 - Subgenre: tagalog worship
#
# Pulling genre # 118 - Subgenre: mainland chinese pop
#
# Pulling genre # 124 - Subgenre: pop catracho
#
# Pulling genre # 123 - Subgenre: vintage schlager
#
# Pulling genre # 127 - Subgenre: rock potiguar
#
# Pulling genre # 126 - Subgenre: maithili
#
# Pulling genre # 115 - Subgenre: piano rock
#
# Pulling genre # 124 - Subgenre: koligeet
#
# Pulling genre # 122 - Subgenre: gaming dubstep
#
# Pulling genre # 119 - Subgenre: suomi rock
#
# Pulling genre # 128 - Subgenre: guatemalan metal
#
# Pulling genre # 125 - Subgenre: muzica copii
#
# Pulling genre # 124 - Subgenre: irish pub song
#
# Pulling genre # 127 - Subgenre: muzica populara
#
# Pulling genre # 116 - Subgenre: dark trap
#
# Pulling genre # 125 - Subgenre: jazz drums
#
# Pulling genre # 123 - Subgenre: japanese pop punk
#
# Pulling genre # 120 - Subgenre: dark pop
#
# Pulling genre # 126 - Subgenre: orquestas de galicia
#
# Pulling genre # 129 - Subgenre: romanian black metal
#
# Pulling genre # 125 - Subgenre: thai folk
#
# Pulling genre # 128 - Subgenre: icelandic jazz
#
# Pulling genre # 126 - Subgenre: indie shoegaze
#
# Pulling genre # 124 - Subgenre: balkan trap
#
# Pulling genre # 117 - Subgenre: ccm
#
# Pulling genre # 121 - Subgenre: canadian pop punk
#
# Pulling genre # 130 - Subgenre: guatemalan indie
#
# Pulling genre # 127 - Subgenre: surinamese pop
#
# Pulling genre # 126 - Subgenre: dc hardcore
#
# Pulling genre # 129 - Subgenre: lagu tarling
#
# Pulling genre # 125 - Subgenre: victoria bc indie
#
# Pulling genre # 127 - Subgenre: warm drone
#
# Pulling genre # 118 - Subgenre: country rock
#
# Pulling genre # 122 - Subgenre: rap espanol
#
# Pulling genre # 131 - Subgenre: american early music
#
# Pulling genre # 128 - Subgenre: milwaukee hip hop
#
# Pulling genre # 127 - Subgenre: classic venezuelan pop
#
# Pulling genre # 130 - Subgenre: cajun
#
# Pulling genre # 128 - Subgenre: reggae maghreb
#
# Pulling genre # 119 - Subgenre: punjabi pop
#
# Pulling genre # 132 - Subgenre: lombok indie
#
# Pulling genre # 129 - Subgenre: czech indie
#
# Pulling genre # 123 - Subgenre: crank wave
#
# Pulling genre # 131 - Subgenre: musique mandingue
#
# ...
#
# Pulling genre # 677 - Subgenre: dubstep
#
# Pulling genre # 748 - Subgenre: rock catracho
#
# Pulling genre # 737 - Subgenre: finnish jazz
#
# Pulling genre # 711 - Subgenre: azeri rap
#
# Pulling genre # 704 - Subgenre: mississippi indie
#
# Pulling genre # 751 - Subgenre: swazi traditional
#
# Pulling genre # 727 - Subgenre: son cubano
#
# Pulling genre # 707 - Subgenre: fourth world
#
# Pulling genre # 738 - Subgenre: progressive black metal
#
# Pulling genre # 749 - Subgenre: musica prehispanica
#
# Pulling genre # 712 - Subgenre: orchestra
#
# Pulling genre # 705 - Subgenre: french black metal
#
# Pulling genre # 678 - Subgenre: musica popular colombiana
#
# Pulling genre # 752 - Subgenre: cinematic dubstep
#
# Pulling genre # 728 - Subgenre: christian hardcore
#
# Pulling genre # 708 - Subgenre: norwegian hip hop
#
# Pulling genre # 713 - Subgenre: funky house
#
# Pulling genre # 739 - Subgenre: swedish post-punk
#
# Pulling genre # 750 - Subgenre: hard dance
#
# Pulling genre # 706 - Subgenre: psydub
#
# Pulling genre # 679 - Subgenre: funk ostentacao
#
# Pulling genre # 753 - Subgenre: baroque brass
#
# Pulling genre # 729 - Subgenre: vintage dutch pop
#
# Pulling genre # 709 - Subgenre: bergen indie
#
# Pulling genre # 714 - Subgenre: nepali indie
#
# Pulling genre # 751 - Subgenre: finnish choir
#
# Pulling genre # 740 - Subgenre: neo soul-jazz
# Pulling genre # 680 - Subgenre: new jersey rap
#
# Pulling genre # 754 - Subgenre: himene tarava
#
# Pulling genre # 707 - Subgenre: norwegian americana
#
# Pulling genre # 730 - Subgenre: persian melodic rap
#
# Pulling genre # 710 - Subgenre: chiptune
#
# Pulling genre # 715 - Subgenre: straight edge
#
# Pulling genre # 741 - Subgenre: canadian death metal
#
# Pulling genre # 752 - Subgenre: chinese experimental
#
# Pulling genre # 681 - Subgenre: covertronica
#
# Pulling genre # 755 - Subgenre: yunnan traditional
#
# Pulling genre # 708 - Subgenre: uk beatdown
#
# Pulling genre # 731 - Subgenre: tampa indie
#
# Pulling genre # 711 - Subgenre: afrikaans
#
# Pulling genre # 742 - Subgenre: hampton roads indie
#
# Pulling genre # 682 - Subgenre: british singer-songwriter
#
# Pulling genre # 756 - Subgenre: classical piano quartet
#
# Pulling genre # 716 - Subgenre: vgm remix
#
# Pulling genre # 709 - Subgenre: czsk reggae
#
# Pulling genre # 732 - Subgenre: musica ayacuchana
#
# Pulling genre # 753 - Subgenre: hungarian classical piano
#
# Pulling genre # 743 - Subgenre: russian experimental electronic
#
# Pulling genre # 683 - Subgenre: rif
#
# Pulling genre # 757 - Subgenre: string quintet
#
# Pulling genre # 712 - Subgenre: idol rock
#
# Pulling genre # 733 - Subgenre: tunisian pop
#
# Pulling genre # 710 - Subgenre: aarhus indie
#
# Pulling genre # 754 - Subgenre: rominimal
#
# Pulling genre # 717 - Subgenre: dangdut remix
#
# Pulling genre # 744 - Subgenre: greenlandic pop
#
# Pulling genre # 684 - Subgenre: malaysian pop
#
# Pulling genre # 758 - Subgenre: quartetto d'archi
#
# Pulling genre # 713 - Subgenre: technical death metal
#
# Pulling genre # 755 - Subgenre: deep full on
#
# Pulling genre # 711 - Subgenre: deep brazilian pop
#
# Pulling genre # 718 - Subgenre: kleinkunst
#
# Pulling genre # 734 - Subgenre: brega paraense
#
# Pulling genre # 745 - Subgenre: dutch musical
#
# Pulling genre # 685 - Subgenre: israeli pop
#
# Pulling genre # 759 - Subgenre: vintage western
#
# Pulling genre # 712 - Subgenre: sega mauricien
#
# Pulling genre # 756 - Subgenre: mathgrind
#
# Pulling genre # 735 - Subgenre: deep adult standards
#
# Pulling genre # 714 - Subgenre: early us punk
#
# Pulling genre # 719 - Subgenre: polish old school hip hop
#
# Pulling genre # 686 - Subgenre: spanish new wave
#
# Pulling genre # 746 - Subgenre: canadian drill
#
# Pulling genre # 760 - Subgenre: classical string trio
#
# Pulling genre # 713 - Subgenre: histoire pour enfants
#
# Pulling genre # 757 - Subgenre: indie trujillano
#
# Pulling genre # 736 - Subgenre: lapland metal
#
# Pulling genre # 715 - Subgenre: instrumental post-rock
#
# Pulling genre # 720 - Subgenre: atmospheric black metal
#
# Pulling genre # 687 - Subgenre: kentucky roots
#
# Pulling genre # 747 - Subgenre: khmer
#
# Pulling genre # 758 - Subgenre: spanish classical piano
#
# Pulling genre # 714 - Subgenre: violin
#
# Pulling genre # 761 - Subgenre: youth orchestra
#
# Pulling genre # 737 - Subgenre: blaskapelle
#
# Pulling genre # 716 - Subgenre: auckland indie
#
# Pulling genre # 721 - Subgenre: musica gaucha
#
# Pulling genre # 688 - Subgenre: boom bap espanol
#
# Pulling genre # 748 - Subgenre: jazz flute
#
# Pulling genre # 759 - Subgenre: belgian stoner rock
#
# Pulling genre # 738 - Subgenre: freeform hardcore
#
# Pulling genre # 722 - Subgenre: instrumental math rock
#
# Pulling genre # 717 - Subgenre: american shoegaze
#
# Pulling genre # 715 - Subgenre: tucson indie
#
# Pulling genre # 689 - Subgenre: italo dance
#
# Pulling genre # 749 - Subgenre: umea hardcore
#
# Pulling genre # 760 - Subgenre: south african punk
#
# Pulling genre # 739 - Subgenre: classic dutch pop
#
# Pulling genre # 723 - Subgenre: balearic
#
# Pulling genre # 718 - Subgenre: uk melodic rap
#
# Pulling genre # 716 - Subgenre: ny roots
#
# Pulling genre # 750 - Subgenre: bachchon ke geet
#
# Pulling genre # 761 - Subgenre: jazz colombiano
#
# Pulling genre # 690 - Subgenre: scorecore
#
# Pulling genre # 740 - Subgenre: straight-ahead jazz
#
# Pulling genre # 719 - Subgenre: bay area indie
#
# Pulling genre # 717 - Subgenre: musica evangelica instrumental
#
# Pulling genre # 724 - Subgenre: russian hyperpop
#
# Pulling genre # 751 - Subgenre: black speed metal
#
# Pulling genre # 741 - Subgenre: underground rap
#
# Pulling genre # 720 - Subgenre: new beat
#
# Pulling genre # 718 - Subgenre: deep dubstep
#
# Pulling genre # 691 - Subgenre: drill francais
#
# Pulling genre # 752 - Subgenre: swedish experimental
#
# Pulling genre # 725 - Subgenre: north carolina indie
#
# Pulling genre # 742 - Subgenre: dissonant death metal
#
# Pulling genre # 721 - Subgenre: folktronica
#
# Pulling genre # 719 - Subgenre: north dakota indie
#
# Pulling genre # 692 - Subgenre: dembow
#
# Pulling genre # 753 - Subgenre: czech alternative rap
#
# Pulling genre # 726 - Subgenre: spanish synthpop
#
# Pulling genre # 743 - Subgenre: techno rave
#
# Pulling genre # 722 - Subgenre: buffalo hip hop
#
# Pulling genre # 720 - Subgenre: swedish prog
#
# Pulling genre # 693 - Subgenre: political hip hop
#
# Pulling genre # 754 - Subgenre: mindfulness
#
# Pulling genre # 727 - Subgenre: instrumental bluegrass
#
# Pulling genre # 744 - Subgenre: afro drill
#
# Pulling genre # 723 - Subgenre: neue deutsche welle
#
# Pulling genre # 721 - Subgenre: ryukyu ongaku
#
# Pulling genre # 694 - Subgenre: alternative country
#
# Pulling genre # 755 - Subgenre: czsk electropop
#
# Pulling genre # 728 - Subgenre: cumbia amazonica
#
# Pulling genre # 745 - Subgenre: gambian hip hop
#
# Pulling genre # 724 - Subgenre: latin metal
#
# Pulling genre # 722 - Subgenre: norwegian punk rock
#
# Pulling genre # 695 - Subgenre: hardcore punk
#
# Pulling genre # 756 - Subgenre: marcha funebre
#
# Pulling genre # 729 - Subgenre: dutch drill
#
# Pulling genre # 746 - Subgenre: native american flute
#
# Pulling genre # 725 - Subgenre: belgian indie
#
# Pulling genre # 723 - Subgenre: military band
#
# Pulling genre # 696 - Subgenre: milan indie
#
# Pulling genre # 730 - Subgenre: japanese folk
#
# Pulling genre # 757 - Subgenre: deep r&b
#
# Pulling genre # 747 - Subgenre: austin hip hop
#
# Pulling genre # 726 - Subgenre: musica gaucha tradicionalista
#
# Pulling genre # 697 - Subgenre: neo-singer-songwriter
#
# Pulling genre # 731 - Subgenre: miami bass
#
# Pulling genre # 758 - Subgenre: dessin anime
#
# Pulling genre # 724 - Subgenre: flemish folk
#
# Pulling genre # 748 - Subgenre: virginia punk
#
# Pulling genre # 727 - Subgenre: classic danish pop
#
# Pulling genre # 732 - Subgenre: brega saudade
#
# Pulling genre # 698 - Subgenre: chill drill
#
# Pulling genre # 759 - Subgenre: japanoise
#
# Pulling genre # 725 - Subgenre: garage psych
#
# Pulling genre # 749 - Subgenre: hokkien pop
#
# Pulling genre # 728 - Subgenre: deep latin christian
#
# Pulling genre # 733 - Subgenre: huapango
#
# Pulling genre # 699 - Subgenre: reggaeton chileno
#
# Pulling genre # 750 - Subgenre: croatian hip hop
#
# Pulling genre # 726 - Subgenre: mpb gospel
#
# Pulling genre # 729 - Subgenre: deep pop edm
#
# Pulling genre # 760 - Subgenre: japanese death metal
#
# Pulling genre # 734 - Subgenre: japanese indie rock
#
# Pulling genre # 751 - Subgenre: kolkata indie
#
# Pulling genre # 730 - Subgenre: turkish instrumental
#
# Pulling genre # 700 - Subgenre: dancefloor dnb
#
# Pulling genre # 727 - Subgenre: british industrial
#
# Pulling genre # 735 - Subgenre: kwaito
#
# Pulling genre # 752 - Subgenre: twoubadou
#
# Pulling genre # 731 - Subgenre: spectra
#
# Pulling genre # 728 - Subgenre: bahamian pop
#
# Pulling genre # 701 - Subgenre: chillwave
#
# Pulling genre # 736 - Subgenre: vintage tollywood
#
# Pulling genre # 753 - Subgenre: bristol electronic
#
# Pulling genre # 732 - Subgenre: psychedelic pop
#
# Pulling genre # 729 - Subgenre: spanish rockabilly
#
# Pulling genre # 702 - Subgenre: epicore
#
# Pulling genre # 737 - Subgenre: modern jazz trio
#
# Pulling genre # 754 - Subgenre: 48g
#
# Pulling genre # 733 - Subgenre: icelandic classical
#
# Pulling genre # 730 - Subgenre: raboday
#
# Pulling genre # 703 - Subgenre: detroit trap
#
# Pulling genre # 755 - Subgenre: british contemporary classical
#
# Pulling genre # 738 - Subgenre: london indie
#
# Pulling genre # 734 - Subgenre: cumbia paraguaya
#
# Pulling genre # 731 - Subgenre: rap portuense
#
# Pulling genre # 704 - Subgenre: deep groove house
#
# Pulling genre # 756 - Subgenre: welsh hip hop
#
# Pulling genre # 739 - Subgenre: 8d
#
# Pulling genre # 735 - Subgenre: turkce kadin rap
#
# Pulling genre # 732 - Subgenre: indie electronica
#
# Pulling genre # 705 - Subgenre: scottish rock
#
# Pulling genre # 757 - Subgenre: argentine indie rock
#
# Pulling genre # 740 - Subgenre: kasi rap
#
# Pulling genre # 736 - Subgenre: instrumental grime
# Pulling genre # 733 - Subgenre: canadian experimental
#
# Pulling genre # 706 - Subgenre: small room
#
# Pulling genre # 758 - Subgenre: chinese indie rock
#
# Pulling genre # 741 - Subgenre: collage pop
#
# Pulling genre # 737 - Subgenre: future rock
#
# Pulling genre # 734 - Subgenre: rap galego
#
# Pulling genre # 707 - Subgenre: philly indie
#
# Pulling genre # 759 - Subgenre: cyber metal
#
# Pulling genre # 738 - Subgenre: ethereal wave
#
# Pulling genre # 742 - Subgenre: ontario indie
#
# Pulling genre # 735 - Subgenre: fijian pop
#
# Pulling genre # 708 - Subgenre: japanese emo
#
# Pulling genre # 760 - Subgenre: modern funk
#
# Pulling genre # 743 - Subgenre: russian chanson
#
# Pulling genre # 739 - Subgenre: northern irish indie
#
# Pulling genre # 736 - Subgenre: deep deep house
#
# Pulling genre # 709 - Subgenre: gothic metal
#
# Pulling genre # 761 - Subgenre: smooth soul
#
# Pulling genre # 744 - Subgenre: kurdish hip hop
#
# Pulling genre # 740 - Subgenre: spanish folk metal
#
# Pulling genre # 710 - Subgenre: indonesian rock
#
# Pulling genre # 737 - Subgenre: polish jazz
#
# Pulling genre # 741 - Subgenre: emoplugg
#
# Pulling genre # 745 - Subgenre: afro house
#
# Pulling genre # 738 - Subgenre: svensk lovsang
#
# Pulling genre # 711 - Subgenre: acoustic cover
#
# Pulling genre # 746 - Subgenre: melodic groove metal
#
# Pulling genre # 742 - Subgenre: rune folk
#
# Pulling genre # 739 - Subgenre: atmospheric sludge
#
# Pulling genre # 712 - Subgenre: double drumming
#
# Pulling genre # 747 - Subgenre: palestinian hip hop
#
# Pulling genre # 743 - Subgenre: samba-enredo
#
# Pulling genre # 740 - Subgenre: chill baile
#
# Pulling genre # 713 - Subgenre: deep ccm
#
# Pulling genre # 748 - Subgenre: virgin islands reggae
#
# Pulling genre # 741 - Subgenre: quebec death metal
#
# Pulling genre # 744 - Subgenre: tropical alternativo
#
# Pulling genre # 714 - Subgenre: tecnobanda
#
# Pulling genre # 749 - Subgenre: american contemporary classical
#
# Pulling genre # 742 - Subgenre: industrial techno
#
# Pulling genre # 745 - Subgenre: rock catala
#
# Pulling genre # 715 - Subgenre: modern southern rock
#
# Pulling genre # 750 - Subgenre: tin pan alley
#
# Pulling genre # 716 - Subgenre: canadian electronic
#
# Pulling genre # 746 - Subgenre: ann arbor indie
#
# Pulling genre # 743 - Subgenre: italian ska
#
# Pulling genre # 751 - Subgenre: twee pop
#
# Pulling genre # 717 - Subgenre: norwegian indie
#
# Pulling genre # 747 - Subgenre: grungegaze
#
# Pulling genre # 744 - Subgenre: italian new wave
#
# Pulling genre # 752 - Subgenre: leipzig electronic
#
# Pulling genre # 718 - Subgenre: zolo
#
# Pulling genre # 745 - Subgenre: baptist gospel
#
# Pulling genre # 748 - Subgenre: acoustic blues
#
# Pulling genre # 753 - Subgenre: classic punjabi pop
#
# Pulling genre # 719 - Subgenre: rap calme
#
# Pulling genre # 746 - Subgenre: swedish hardcore
#
# Pulling genre # 749 - Subgenre: indonesian emo
#
# Pulling genre # 754 - Subgenre: musica cristiana guatemalteca
#
# Pulling genre # 720 - Subgenre: canadian country
#
# Pulling genre # 747 - Subgenre: musica hondurena
#
# Pulling genre # 750 - Subgenre: texas blues
#
# Pulling genre # 755 - Subgenre: rap regio
#
# Pulling genre # 721 - Subgenre: musica sonorense
#
# Pulling genre # 748 - Subgenre: texas punk
#
# Pulling genre # 751 - Subgenre: chill guitar
#
# Pulling genre # 756 - Subgenre: new england americana
#
# Pulling genre # 722 - Subgenre: deboxe
#
# Pulling genre # 749 - Subgenre: punta
#
# Pulling genre # 752 - Subgenre: concepcion indie
#
# Pulling genre # 723 - Subgenre: arab pop
#
# Pulling genre # 757 - Subgenre: naat
#
# Pulling genre # 750 - Subgenre: spirituals
#
# Pulling genre # 753 - Subgenre: lo-fi house
#
# Pulling genre # 758 - Subgenre: arab trap
#
# Pulling genre # 724 - Subgenre: post-disco
#
# Pulling genre # 751 - Subgenre: new york death metal
#
# Pulling genre # 759 - Subgenre: pittsburgh indie
#
# Pulling genre # 725 - Subgenre: minimal techno
#
# Pulling genre # 754 - Subgenre: japanese trap
#
# Pulling genre # 752 - Subgenre: hindi worship
#
# Pulling genre # 726 - Subgenre: laiko
#
# Pulling genre # 755 - Subgenre: samba reggae
#
# Pulling genre # 760 - Subgenre: musica canaria
#
# Pulling genre # 753 - Subgenre: musica pitiusa
#
# Pulling genre # 727 - Subgenre: nu disco
#
# Pulling genre # 756 - Subgenre: uk dancehall
#
# Pulling genre # 754 - Subgenre: boogie-woogie
#
# Pulling genre # 728 - Subgenre: melodic dubstep
#
# Pulling genre # 757 - Subgenre: chinese singer-songwriter
#
# Pulling genre # 755 - Subgenre: deep big room
#
# Pulling genre # 729 - Subgenre: bossa nova cover
#
# Pulling genre # 758 - Subgenre: chicago blues
#
# Pulling genre # 756 - Subgenre: afro psych
#
# Pulling genre # 730 - Subgenre: czech hip hop
#
# Pulling genre # 759 - Subgenre: central asian hip hop
#
# Pulling genre # 757 - Subgenre: rap tico
#
# Pulling genre # 731 - Subgenre: bossbeat
#
# Pulling genre # 760 - Subgenre: hungarian hip hop
#
# Pulling genre # 758 - Subgenre: solipsynthm
#
# Pulling genre # 732 - Subgenre: classic hardstyle
#
# Pulling genre # 761 - Subgenre: swedish country
#
# Pulling genre # 759 - Subgenre: leipzig indie
#
# Pulling genre # 733 - Subgenre: lagu jawa
#
# Pulling genre # 760 - Subgenre: wyoming indie
#
# Pulling genre # 734 - Subgenre: oakland hip hop
#
# Pulling genre # 761 - Subgenre: sanfona
#
# Pulling genre # 735 - Subgenre: modern power pop
#
# Pulling genre # 736 - Subgenre: russian alt pop
#
# Pulling genre # 737 - Subgenre: south carolina hip hop
#
# Pulling genre # 738 - Subgenre: canadian punk
#
# Pulling genre # 739 - Subgenre: gothic symphonic metal
#
# Pulling genre # 740 - Subgenre: funk bh
#
# Pulling genre # 741 - Subgenre: swedish synthpop
#
# Pulling genre # 742 - Subgenre: modern hard rock
#
# Pulling genre # 743 - Subgenre: r&b brasileiro
#
# Pulling genre # 744 - Subgenre: pop electronico
#
# Pulling genre # 745 - Subgenre: swedish trap
#
# Pulling genre # 746 - Subgenre: vapor soul
#
# Pulling genre # 747 - Subgenre: speedrun
#
# Pulling genre # 748 - Subgenre: german romanticism
#
# Pulling genre # 749 - Subgenre: dutch trance
#
# Pulling genre # 750 - Subgenre: deathcore
#
# Pulling genre # 751 - Subgenre: russelater
#
# Pulling genre # 752 - Subgenre: latin talent show
#
# Pulling genre # 753 - Subgenre: chicago indie
#
# Pulling genre # 754 - Subgenre: cumbia pop
#
# Pulling genre # 755 - Subgenre: cumbia chilena
#
# Pulling genre # 756 - Subgenre: swedish idol pop
#
# Pulling genre # 757 - Subgenre: melodic death metal
#
# Pulling genre # 758 - Subgenre: hi-nrg
#
# Pulling genre # 759 - Subgenre: supergroup
#
# Pulling genre # 760 - Subgenre: christian hip hop
#
# Time Taken to Gather Data: 647.24s

# %%
import sys
import re
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd

class GenreProcessingError(Exception):
    def __init__(self, message, genre, *args, **kwargs):
        super(GenreProcessingError, self).__init__(message, *args, **kwargs)
        self.genre = genre

def fetch_genre_page(subgenre):
    try:
        genre_page_url = f"http://everynoise.com/engenremap-{subgenre}.html"
        response = requests.get(genre_page_url)
        return BeautifulSoup(response.text, "html.parser")
    except requests.RequestException as request_err:
        raise GenreProcessingError("Error fetching genre page.", subgenre) from request_err

def process_genre(genre_div):
    genre = re.sub("[:'+»&\s-]", '', genre_div.text)
    soup2 = fetch_genre_page(genre)

    spotify_link = soup2.find_all("a", text='playlist')
    playlist = spotify_link[0]['href'] if len(spotify_link) > 0 else None

    all_artist_divs = set(soup2.find_all("div", "genre scanme"))
    all_genres_related = set(soup2.find_all("div", "genre")) - all_artist_divs

    artist_weights = [
        artist['style'].split()[-1].replace('%', '') for artist in all_artist_divs
    ]
    artists = [
        artist.text.strip().replace("»", "") for artist in all_artist_divs
        if not artist.text.strip().replace("»", "").isspace()
    ]

    sim_weights = [
        weight['style'].split()[-1].replace('%', '')
        for weight in all_genres_related if 'nearby' in weight['id']
    ]
    opp_weights = [
        weight['style'].split()[-1].replace('%', '')
        for weight in all_genres_related if 'mirror' in weight['id']
    ]

    sim_genres = [
        other_genre.text.strip().replace("»", "")
        for other_genre in all_genres_related if 'nearby' in other_genre['id']
    ]
    opp_genres = [
        other_genre.text.strip().replace("»", "")
        for other_genre in all_genres_related if 'mirror' in other_genre['id']
    ]

    return {
        'genre': genre,
        'playlist': playlist,
        'artist_weights': artist_weights,
        'artists': artists,
        'sim_weights': sim_weights,
        'opp_weights': opp_weights,
        'sim_genres': sim_genres,
        'opp_genres': opp_genres,
    }
    
def process_genres_and_update_csv(filename):
    df = pd.read_csv(filename)

    for idx, row in df.iterrows():
        if pd.isnull(row['SPOTIFY_URL']):
            genre_div = BeautifulSoup(f'<div>{row["GENRE"]}</div>', "html.parser")
            try:
                result = process_genre(genre_div)
                print(f"Processed genre #{idx}: {result['genre']}")

                # Update the corresponding row in the DataFrame
                df.at[idx, 'SIM_GENRES'] = ', '.join(result['sim_genres'])
                df.at[idx, 'SIM_WEIGHTS'] = ', '.join(result['sim_weights'])
                df.at[idx, 'OPP_GENRES'] = ', '.join(result['opp_genres'])
                df.at[idx, 'OPP_WEIGHTS'] = ', '.join(result['opp_weights'])
                df.at[idx, 'REL_ARTISTS'] = ', '.join(result['artists'])
                df.at[idx, 'ARTIST_WEIGHTS'] = ', '.join(result['artist_weights'])
                df.at[idx, 'SPOTIFY_URL'] = result['playlist']
            except GenreProcessingError as gpe:
                print(f"Error processing genre #{idx} ({gpe.genre}): {gpe}")

    # Save the updated DataFrame back to the CSV file
    df.to_csv(filename, index=False)

filename = "all_genres1.csv"
process_genres_and_update_csv(filename)

response = requests.get("http://everynoise.com/engenremap.html")
soup = BeautifulSoup(response.text, "html.parser")
all_genre_divs = soup.find_all("div", "genre scanme")

results = []

for index, genre_div in enumerate(all_genre_divs):
    genre = re.sub("[:'+»&\s-]", '', genre_div.text)

    if genre in genres_to_process:
        try:
            result = process_genre(genre_div)
            results.append(result)
            print(f"Processed genre #{index}: {result['genre']}")
        except GenreProcessingError as gpe:
            print(f"Error processing genre #{index} ({gpe.genre}): {gpe}")
# Out:
# Processed genre #208: hardcorehiphop
# Processed genre #211: popvenezolano
# Processed genre #212: frenchpop
# Processed genre #215: popreggaeton
# Processed genre #216: classicsoul
# Processed genre #219: dutchhouse
# Processed genre #220: orchestralsoundtrack
# Processed genre #222: popsoul
# Processed genre #224: outlawcountry
# Processed genre #225: braziliangospel
# Processed genre #226: calirap
# Processed genre #434: viralrap
# Processed genre #438: indonesiansingersongwriter
# Processed genre #441: ambientpop
# Processed genre #442: ukalternativepop
# Processed genre #443: kentuckyhiphop
# Processed genre #448: brazilianreggae
# Processed genre #449: czskhiphop
# Processed genre #452: latinworship
# Processed genre #454: jazzpop
# Processed genre #458: pagodebaiano
# Processed genre #465: mexicanindie
# Processed genre #466: earlymusic
# Processed genre #467: germandrill
# Processed genre #468: frenchrock
# Processed genre #469: elpasoindie
# Processed genre #470: countryrap
# Processed genre #477: drillespanol
# Processed genre #478: turkcedrill
# Processed genre #479: neuedeutscheharte
# Processed genre #480: indierockitaliano
# Processed genre #481: bachatadominicana
# Processed genre #483: classicjpop
# Processed genre #486: nigerianhiphop
# Processed genre #487: indieanthemfolk
# Processed genre #488: hindihiphop
# Processed genre #491: indiegaragerock
# Processed genre #492: japanesevgm
# Processed genre #497: classiccanadianrock
# Processed genre #500: belgianedm
# Processed genre #501: contemporaryvocaljazz
# Processed genre #502: poprockbrasileiro
# Processed genre #503: animescore
# Processed genre #505: irishpop
# Processed genre #507: australianindie
# Processed genre #508: melbournebounceinternational
# Processed genre #511: shimmerpop
# Processed genre #512: edmontonindie
# Processed genre #513: lofijazzhop
# Processed genre #515: poprapbrasileiro
# Processed genre #519: chicagodrill
# Processed genre #520: belgianhiphop
# Processed genre #521: cpop
# Processed genre #524: harekrishna
# Processed genre #525: memphissoul
# Processed genre #529: indonesianjazz
# Processed genre #530: gauzepop
# Processed genre #531: australianelectropop
# Processed genre #532: punkblues
# Processed genre #533: taiwanpop
# Processed genre #534: swamprock
# Processed genre #537: postpunk
# Processed genre #539: deepundergroundhiphop
# Processed genre #540: canadianmetal
# Processed genre #541: lateromanticera
# Processed genre #542: nouvellechansonfrancaise
# Processed genre #543: celticrock
# Processed genre #546: nucumbia
# Processed genre #552: germancloudrap
# Processed genre #553: musicaparaninos
# Processed genre #555: musicachihuahuense
# Processed genre #557: deepeurohouse
# Processed genre #559: earlyromanticera
# Processed genre #564: turkishfolk
# Processed genre #567: dancepunk
# Processed genre #574: stonerrock
# Processed genre #577: progressivemetal
# Processed genre #578: hiphouse
# Processed genre #579: reggaerock
# Processed genre #582: blackamericana
# Processed genre #586: classicalera
# Processed genre #592: koreanpop
# Processed genre #594: modernalternativepop
# Processed genre #597: ukalternativehiphop
# Processed genre #599: italianindiepop
# Processed genre #600: turkishsingersongwriter
# Processed genre #601: desitrap
# Processed genre #602: alternativeemo
# Processed genre #604: venezuelanhiphop
# Processed genre #605: germanalternativerap
# Processed genre #606: postromanticera
# Processed genre #607: greektrap
# Processed genre #610: basshouse
# Processed genre #611: dutchrappop
# Processed genre #612: turkishalternativerock
# Processed genre #614: ppop
# Processed genre #615: trapchileno
# Processed genre #616: smoothjazz
# Processed genre #619: dutchrock
# Processed genre #621: reddirt
# Processed genre #624: canadianindie
# Processed genre #625: danishhiphop
# Processed genre #626: swedishgangstarap
# Processed genre #630: moderndreampop
# Processed genre #631: japanesesoundtrack
# Processed genre #633: euphorichardstyle
# Processed genre #634: acidrock
# Processed genre #637: albanianhiphop
# Processed genre #638: nashvillesound
# Processed genre #639: rapgenovese
# Processed genre #640: nujazz
# Processed genre #641: sunshinepop
# Processed genre #642: arkansascountry
# Processed genre #644: drumandbass
# Processed genre #646: finnishpop
# Processed genre #647: rappolitico
# Processed genre #648: belgianpop
# Processed genre #649: frenchindietronica
# Processed genre #650: panamanianpop
# Processed genre #651: reggaetonmexicano
# Processed genre #652: birminghammetal
# Processed genre #653: poplgbtqbrasileira
# Processed genre #654: pianocover
# Processed genre #655: albanianpop
# Processed genre #657: brazilianedm
# Processed genre #658: classicschlager
# Processed genre #659: chicanorap
# Processed genre #660: finnishhiphop
# Processed genre #661: discohouse
# Processed genre #662: germanbaroque
# Processed genre #663: rockcristiano
# Processed genre #665: houstonrap
# Processed genre #668: shiverpop
# Processed genre #669: germansoundtrack
# Processed genre #670: jazzrap
# Processed genre #671: modernblues
# Processed genre #672: backgroundjazz
# Processed genre #673: trapmexicano
# Processed genre #674: deathmetal
# Processed genre #675: socialmediapop
# Processed genre #676: japanesealternativerock
# Processed genre #678: musicapopularcolombiana
# Processed genre #679: funkostentacao
# Processed genre #680: newjerseyrap
# Processed genre #682: britishsingersongwriter
# Processed genre #684: malaysianpop
# Processed genre #685: israelipop
# Processed genre #686: spanishnewwave
# Processed genre #687: kentuckyroots
# Processed genre #688: boombapespanol
# Processed genre #693: politicalhiphop
# Processed genre #694: alternativecountry
# Processed genre #695: hardcorepunk
# Processed genre #696: milanindie
# Processed genre #698: chilldrill
# Processed genre #703: detroittrap
# Processed genre #704: deepgroovehouse
# Processed genre #705: scottishrock
# Processed genre #706: smallroom
# Processed genre #707: phillyindie
# Processed genre #708: japaneseemo
# Processed genre #709: gothicmetal
# Processed genre #710: indonesianrock
# Processed genre #711: acousticcover
# Processed genre #712: doubledrumming
# Processed genre #713: deepccm
# Processed genre #715: modernsouthernrock
# Processed genre #716: canadianelectronic
# Processed genre #717: norwegianindie
# Processed genre #719: rapcalme
# Processed genre #720: canadiancountry
# Processed genre #721: musicasonorense
# Processed genre #723: arabpop
# Processed genre #724: postdisco
# Processed genre #725: minimaltechno
# Processed genre #727: nudisco
# Processed genre #728: melodicdubstep
# Processed genre #729: bossanovacover
# Processed genre #730: czechhiphop
# Processed genre #732: classichardstyle
# Processed genre #733: lagujawa
# Processed genre #734: oaklandhiphop
# Processed genre #735: modernpowerpop
# Processed genre #737: southcarolinahiphop
# Processed genre #738: canadianpunk
# Processed genre #739: gothicsymphonicmetal
# Processed genre #740: funkbh
# Processed genre #741: swedishsynthpop
# Processed genre #742: modernhardrock
# Processed genre #743: rbbrasileiro
# Processed genre #744: popelectronico
# Processed genre #745: swedishtrap
# Processed genre #746: vaporsoul
# Processed genre #748: germanromanticism
# Processed genre #752: latintalentshow
# Processed genre #753: chicagoindie
# Processed genre #754: cumbiapop
# Processed genre #755: cumbiachilena
# Processed genre #757: melodicdeathmetal
# Processed genre #758: hinrg
# Processed genre #760: christianhiphop
# Processed genre #978: mexicanrockandroll
# Processed genre #984: southafricanpop
# Processed genre #985: ghanaianhiphop
# Processed genre #986: antiviralpop
# Processed genre #989: westcoastflow
# Processed genre #991: futurehouse
# Processed genre #992: classickollywood
# Processed genre #995: scamrap
# Processed genre #996: japaneseclassical
# Processed genre #1222: indianedm
# Processed genre #1224: thaiindierock
# Processed genre #1226: antifolk
# Processed genre #1229: christianmetal
# Processed genre #1235: welshrock
# Processed genre #1238: bandungindie
# Processed genre #1240: nerdcorebrasileiro
# Processed genre #1241: vaporpop
# Processed genre #1242: kazakhpop
# Processed genre #1243: australianhouse
# Processed genre #1247: turkishdeephouse
# Processed genre #1248: surfpunk
# Processed genre #1250: japanesepunkrock
# Processed genre #1256: lofiemo
# Processed genre #1259: regionalmexicanofemenil
# Processed genre #1260: thairock
# Processed genre #1263: focusbeats
# Processed genre #1264: musicatradicionalcubana
# Processed genre #1265: afghanpop
# Processed genre #1266: russianpostpunk
# Processed genre #1267: boombapbrasileiro
# Processed genre #1269: chicagosoul
# Processed genre #1271: canzonenapoletana
# Processed genre #1275: ghanaianpop
# Processed genre #1276: classiccantopop
# Processed genre #1280: psychedelictrance
# Processed genre #1287: swedishindierock
# Processed genre #1290: russianpunk
# Processed genre #1296: cancioninfantillatinoamericana
# Processed genre #1297: riotgrrrl
# Processed genre #1300: australianalternativepop
# Processed genre #1302: celticpunk
# Processed genre #1305: ukrainianrock
# Processed genre #1307: mexicanclassicrock
# Processed genre #1312: russiandrill
# Processed genre #1315: sludgemetal
# Processed genre #1318: neueneuedeutschewelle
# Processed genre #1321: vikingmetal
# Processed genre #1324: mariachicristiano
# Processed genre #1325: canadianccm
# Processed genre #1332: classicrussianpop
# Processed genre #1334: anthememo
# Processed genre #1336: folkrockitaliano
# Processed genre #1337: kiwirock
# Processed genre #1338: minimaltechhouse
# Processed genre #1341: polishrock
# Processed genre #1342: monterreyindie
# Processed genre #1344: frenchromanticism
# Processed genre #1348: nashvillesingersongwriter
# Processed genre #1349: canadianamericana
# Processed genre #1351: horrorpunk
# Processed genre #1352: koreanindierock
# Processed genre #1353: germanrb
# Processed genre #1354: okinawanpop
# Processed genre #1355: celticmetal
# Processed genre #1356: experimentalrock
# Processed genre #1357: texasmetal
# Processed genre #1358: musicatristebrasileira
# Processed genre #1359: salsaperuana
# Processed genre #1361: chillbreakcore
# Processed genre #1363: frenchtechno
# Processed genre #1364: moroccanpop
# Processed genre #1365: thaitrap
# Processed genre #1368: channelpop
# Processed genre #1369: guadalajaraindie
# Processed genre #1370: anthemworship
# Processed genre #1374: chineserb
# Processed genre #1375: australiantrap
# Processed genre #1377: detroittrapbrasileiro
# Processed genre #1380: latinxalternative
# Processed genre #1381: magyartrap
# Processed genre #1384: scottishindie
# Processed genre #1387: indiejazz
# Processed genre #1388: mexicanpoppunk
# Processed genre #1389: sambaderoda
# Processed genre #1390: kosovanpop
# Processed genre #1391: trapdominicano
# Processed genre #1393: smoothsaxophone
# Processed genre #1395: operametal
# Processed genre #1397: postminimalism
# Processed genre #1398: contemporaryjazz
# Processed genre #1400: dutchindie
# Processed genre #1401: dembowdominicano
# Processed genre #1402: classicisraelipop
# Processed genre #1403: pianoblues
# Processed genre #1405: classicgaragerock
# Processed genre #1406: darktechno
# Processed genre #1413: ukpoppunk
# Processed genre #1414: rhythmandblues
# Processed genre #1416: canadianfolk
# Processed genre #1418: jazzboombap
# Processed genre #1420: progressivegroovemetal
# Processed genre #1427: zhenskiyrep
# Processed genre #1428: childrensfolk
# Processed genre #1429: chihuahuaindie
# Processed genre #1430: christianmetalcore
# Processed genre #1431: melodicmetal
# Processed genre #1434: trapcatala
# Processed genre #1435: comedyrap
# Processed genre #1438: bulgarianpop
# Processed genre #1439: rockandaluz
# Processed genre #1440: czskemorap
# Processed genre #1442: folkmetal
# Processed genre #1443: nordicsoundtrack
# Processed genre #1445: jindie
# Processed genre #1446: studybeats
# Processed genre #1447: indierockmexicano
# Processed genre #1448: musiquepourenfants
# Processed genre #1450: taiwanhiphop
# Processed genre #1452: japanesealternativepop
# Processed genre #1453: classicdiscopolo
# Processed genre #1454: drillchileno
# Processed genre #1455: latinclassical
# Processed genre #1456: classicpraise
# Processed genre #1457: italianromanticism
# Processed genre #1458: indonesianviralpop
# Processed genre #1459: calminginstrumental
# Processed genre #1460: floathouse
# Processed genre #1461: midwestemo
# Processed genre #1462: classicarabpop
# Processed genre #1464: cdoindie
# Processed genre #1465: belgianrock
# Processed genre #1466: christlicherrap
# Processed genre #1467: southafricanhiphop
# Processed genre #1468: fourthworld
# Processed genre #1469: norwegianhiphop
# Processed genre #1470: bergenindie
# Processed genre #1473: idolrock
# Processed genre #1475: earlyuspunk
# Processed genre #1476: instrumentalpostrock
# Processed genre #1477: aucklandindie
# Processed genre #1478: americanshoegaze
# Processed genre #1479: ukmelodicrap
# Processed genre #1480: bayareaindie
# Processed genre #1481: newbeat
# Processed genre #1483: buffalohiphop
# Processed genre #1484: neuedeutschewelle
# Processed genre #1485: latinmetal
# Processed genre #1486: belgianindie
# Processed genre #1487: musicagauchatradicionalista
# Processed genre #1488: classicdanishpop
# Processed genre #1489: deeplatinchristian
# Processed genre #1490: deeppopedm
# Processed genre #1491: turkishinstrumental
# Processed genre #1493: psychedelicpop
# Processed genre #1494: icelandicclassical
# Processed genre #1495: cumbiaparaguaya
# Processed genre #1496: turkcekadinrap
# Processed genre #1497: instrumentalgrime
# Processed genre #1498: futurerock
# Processed genre #1499: etherealwave
# Processed genre #1500: northernirishindie
# Processed genre #1501: spanishfolkmetal
# Processed genre #1503: runefolk
# Processed genre #1504: sambaenredo
# Processed genre #1505: tropicalalternativo
# Processed genre #1506: rockcatala
# Processed genre #1509: acousticblues
# Processed genre #1510: indonesianemo
# Processed genre #1511: texasblues
# Processed genre #1513: concepcionindie
# Processed genre #1515: japanesetrap
# Processed genre #1516: sambareggae
# Processed genre #1517: ukdancehall
# Processed genre #1518: chinesesingersongwriter
# Processed genre #1519: chicagoblues
# Processed genre #1520: centralasianhiphop
# Processed genre #1521: hungarianhiphop
# Processed genre #1522: swedishcountry
# Processed genre #1732: reggaecristao
# Processed genre #1737: alabamaindie
# Processed genre #1738: swedishamericana
# Processed genre #1739: kawaiimetal
# Processed genre #1741: indonesianposthardcore
# Processed genre #1743: bigband
# Processed genre #1744: pinoyalternativerap
# Processed genre #1745: rapundergroundargentino
# Processed genre #1746: sanmarcostxindie
# Processed genre #1982: musicacoahuilense
# Processed genre #1984: mathrock
# Processed genre #1989: deepnewamericana
# Processed genre #1991: sertanejogospel
# Processed genre #1993: christianlofi
# Processed genre #1994: honkytonk
# Processed genre #1998: japanesecontemporaryclassical
# Processed genre #1999: africanrock
# Processed genre #2000: germanviralrap
# Processed genre #2001: witchhouse
# Processed genre #2003: sandiegorap
# Processed genre #2004: indianfusion
# Processed genre #2005: murciaindie
# Processed genre #2007: chileanhardcore
# Processed genre #2008: reggaegaucho
# Processed genre #2010: cumbiaandinamexicana
# Processed genre #2012: hyperpopenespanol
# Processed genre #2013: balletclass
# Processed genre #2015: classicgreekpop
# Processed genre #2018: southafricanalternative
# Processed genre #2019: czechpoprock
# Processed genre #2020: finnishedm
# Processed genre #2026: messianicpraise
# Processed genre #2030: darkcabaret
# Processed genre #2031: trapperuano
# Processed genre #2032: cumbiacolombianaregia
# Processed genre #2033: hyperpopfrancais
# Processed genre #2035: japaneseindiepop
# Processed genre #2037: swedishgaragerock
# Processed genre #2040: westend
# Processed genre #2044: newcomedy
# Processed genre #2045: denpakei
# Processed genre #2046: russianindie
# Processed genre #2047: rodadesamba
# Processed genre #2050: swedishdancehall
# Processed genre #2051: skanskmusik
# Processed genre #2052: turksanatmuzigi
# Processed genre #2054: scottishindierock
# Processed genre #2057: metalcover
# Processed genre #2058: britishpowermetal
# Processed genre #2060: animepiano
# Processed genre #2061: dutchrb
# Processed genre #2062: melodicdeathcore
# Processed genre #2063: sandiegoindie
# Processed genre #2064: montrealindie
# Processed genre #2065: venezuelanindie
# Processed genre #2067: ukposthardcore
# Processed genre #2069: supereurobeat
# Processed genre #2070: baltimorehiphop
# Processed genre #2071: russianska
# Processed genre #2073: gypsyjazz
# Processed genre #2074: finnishdeathmetal
# Processed genre #2076: brazilianboogie
# Processed genre #2077: shibuyakei
# Processed genre #2078: pinoyindierock
# Processed genre #2079: canadianceltic
# Processed genre #2080: acousticguitarcover
# Processed genre #2084: frenchdeathmetal
# Processed genre #2087: polishpunk
# Processed genre #2088: indianrock
# Processed genre #2092: deepchill
# Processed genre #2095: musicaperbambini
# Processed genre #2097: jreggae
# Processed genre #2098: balkanbeats
# Processed genre #2100: bostonmetal
# Processed genre #2101: ocindie
# Processed genre #2102: worldfusion
# Processed genre #2108: grooveroom
# Processed genre #2109: acidhouse
# Processed genre #2110: rockquebecois
# Processed genre #2112: malianblues
# Processed genre #2117: southafricantrap
# Processed genre #2118: estonianhiphop
# Processed genre #2119: fremantleindie
# Processed genre #2120: neotraditionalbluegrass
# Processed genre #2122: japanesedancepop
# Processed genre #2124: alaskaindie
# Processed genre #2126: salsachoke
# Processed genre #2129: nzhiphop
# Processed genre #2130: bongoflava
# Processed genre #2131: deeptechhouse
# Processed genre #2133: musicaalagoana
# Processed genre #2134: newitalodisco
# Processed genre #2135: vlaamsekinderliedje
# Processed genre #2139: ukcontemporaryjazz
# Processed genre #2141: christmasinstrumental
# Processed genre #2142: southcarolinaindie
# Processed genre #2144: russianwitchhouse
# Processed genre #2145: atlantametal
# Processed genre #2147: canadianoldschoolhiphop
# Processed genre #2148: norwegiansingersongwriter
# Processed genre #2149: carnaticvocal
# Processed genre #2151: norwegianblackmetal
# Processed genre #2153: discopolo
# Processed genre #2156: jpunk
# Processed genre #2157: nowave
# Processed genre #2159: azeritraditional
# Processed genre #2166: indonesianpunk
# Processed genre #2168: germanpunkrock
# Processed genre #2170: australianamericana
# Processed genre #2171: dutchtechhouse
# Processed genre #2172: novamusicacarioca
# Processed genre #2173: nantesindie
# Processed genre #2175: memphisblues
# Processed genre #2176: experimentalclassical
# Processed genre #2177: classicalpiano
# Processed genre #2178: mexicanedm
# Processed genre #2181: danishalternativerock
# Processed genre #2182: popteenbrasileiro
# Processed genre #2183: thaifolkpop
# Processed genre #2187: argentineambient
# Processed genre #2189: classicbhangra
# Processed genre #2191: norskeviser
# Processed genre #2192: canadianposthardcore
# Processed genre #2193: freejazz
# Processed genre #2195: sinhalaindie
# Processed genre #2196: magyaralternative
# Processed genre #2197: bosnianpop
# Processed genre #2198: ukrainianclassical
# Processed genre #2199: classicczechpop
# Processed genre #2200: modrevival
# Processed genre #2201: raggajungle
# Processed genre #2202: speedplugbrasileiro
# Processed genre #2203: malangindie
# Processed genre #2204: folkloresurero
# Processed genre #2205: italiantechhouse
# Processed genre #2206: christianuplift
# Processed genre #2207: chillout
# Processed genre #2208: folkloreecuatoriano
# Processed genre #2209: germanjazz
# Processed genre #2210: vintagejazz
# Processed genre #2211: jacksonvilleindie
# Processed genre #2213: japaneseska
# Processed genre #2214: lofibrasileiro
# Processed genre #2216: jazzrock
# Processed genre #2217: atlantabass
# Processed genre #2221: oceaniasoundtrack
# Processed genre #2222: germanjazzrap
# Processed genre #2223: swedishprogressivemetal
# Processed genre #2225: tempeindie
# Processed genre #2226: darkdisco
# Processed genre #2227: militaryrap
# Processed genre #2228: cocuksarkilari
# Processed genre #2230: krock
# Processed genre #2231: dakkedak
# Processed genre #2232: germanworship
# Processed genre #2233: swissrock
# Processed genre #2234: azerirap
# Processed genre #2236: funkyhouse
# Processed genre #2237: nepaliindie
# Processed genre #2240: dangdutremix
# Processed genre #2242: polisholdschoolhiphop
# Processed genre #2243: atmosphericblackmetal
# Processed genre #2244: musicagaucha
# Processed genre #2245: instrumentalmathrock
# Processed genre #2248: northcarolinaindie
# Processed genre #2249: spanishsynthpop
# Processed genre #2250: instrumentalbluegrass
# Processed genre #2251: cumbiaamazonica
# Processed genre #2252: dutchdrill
# Processed genre #2253: japanesefolk
# Processed genre #2254: miamibass
# Processed genre #2255: bregasaudade
# Processed genre #2257: japaneseindierock
# Processed genre #2259: vintagetollywood
# Processed genre #2261: londonindie
# Processed genre #2263: kasirap
# Processed genre #2264: collagepop
# Processed genre #2265: ontarioindie
# Processed genre #2266: russianchanson
# Processed genre #2267: kurdishhiphop
# Processed genre #2268: afrohouse
# Processed genre #2269: melodicgroovemetal
# Processed genre #2270: palestinianhiphop
# Processed genre #2272: americancontemporaryclassical
# Processed genre #2273: tinpanalley
# Processed genre #2274: tweepop
# Processed genre #2275: leipzigelectronic
# Processed genre #2276: classicpunjabipop
# Processed genre #2277: musicacristianaguatemalteca
# Processed genre #2278: rapregio
# Processed genre #2279: newenglandamericana
# Processed genre #2281: arabtrap
# Processed genre #2283: musicacanaria
# Processed genre #2510: tapeclub
# Processed genre #2511: electricbass
# Processed genre #2512: tribalhouse
# Processed genre #2513: salsacubana
# Processed genre #2516: africangospel
# Processed genre #2517: dutchdnb
# Processed genre #2520: kenyanpop
# Processed genre #2521: electronicdjent
# Processed genre #2522: belarusianpop
# Processed genre #2523: chansonhumoristique
# Processed genre #2759: neworleanssoul
# Processed genre #2760: dungeonsynth
# Processed genre #2761: duluthindie
# Processed genre #2762: modernoldtime
# Processed genre #2767: finnishpunk
# Processed genre #2768: munichindie
# Processed genre #2770: turkishpunk
# Processed genre #2772: modularsynth
# Processed genre #2775: folkloreperuano
# Processed genre #2777: industrialpop
# Processed genre #2780: koreanundergroundrap
# Processed genre #2785: musiqueguadeloupe
# Processed genre #2786: depressiveblackmetal
# Processed genre #2788: rapparanaense
# Processed genre #2790: mansorchestra
# Processed genre #2791: greekmetal
# Processed genre #2795: middleeasthiphop
# Processed genre #2797: avantgardejazz
# Processed genre #2798: downtempodeathcore
# Processed genre #2800: frankfurtelectronic
# Processed genre #2801: avantgarde
# Processed genre #2802: russiantrance
# Processed genre #2805: experimentalhouse
# Processed genre #2809: belgiantechno
# Processed genre #2811: manipuripop
# Processed genre #2812: tpopgirlgroup
# Processed genre #2813: slovenianpop
# Processed genre #2814: experimentalfolk
# Processed genre #2815: germancountry
# Processed genre #2817: dusseldorfelectronic
# Processed genre #2818: newwaveofthrashmetal
# Processed genre #2821: bulgariantrap
# Processed genre #2827: folcloretucumano
# Processed genre #2828: raialgerien
# Processed genre #2830: speedupturkce
# Processed genre #2832: technicalgroovemetal
# Processed genre #2833: tronderskmusikk
# Processed genre #2834: dalarnaindie
# Processed genre #2835: atlantapunk
# Processed genre #2836: neapolitanfunk
# Processed genre #2837: folklorenuevoargentino
# Processed genre #2838: jazzclarinet
# Processed genre #2839: denverindie
# Processed genre #2840: deepgermanindie
# Processed genre #2841: thaiidol
# Processed genre #2842: piedmontblues
# Processed genre #2843: telugufolk
# Processed genre #2844: slowgame
# Processed genre #2847: granadaindie
# Processed genre #2849: omahaindie
# Processed genre #2852: slovakpunk
# Processed genre #2854: ecuadorianindie
# Processed genre #2855: norwegianfolkrock
# Processed genre #2861: instrumentaldjent
# Processed genre #2863: rapangolano
# Processed genre #2865: indieplatense
# Processed genre #2868: merenguetipico
# Processed genre #2869: cincinnatiindie
# Processed genre #2873: sydneyindie
# Processed genre #2874: frenchpunk
# Processed genre #2875: kizombacaboverdiana
# Processed genre #2876: persianalternative
# Processed genre #2877: soulfulhouse
# Processed genre #2878: crustpunk
# Error processing genre #2880 (violacaipira): Error fetching genre page.
# Processed genre #2882: germanindiepop
# Processed genre #2884: gypsypunk
# Processed genre #2887: manitobaindie
# Processed genre #2890: swedishpunk
# Processed genre #2897: adoracionpentecostal
# Processed genre #2900: thaiteenpop
# Processed genre #2902: classicnepalipop
# Processed genre #2903: electrobailando
# Processed genre #2904: aussieemo
# Processed genre #2908: tibetanpop
# Processed genre #2909: rapinde
# Processed genre #2912: igbopop
# Processed genre #2913: musicasudcaliforniana
# Processed genre #2914: charlottencindie
# Processed genre #2916: arabgroove
# Processed genre #2919: instrumentalstonerrock
# Processed genre #2923: danishjazz
# Processed genre #2924: rapundergroundcolombiano
# Processed genre #2926: autonomousblackmetal
# Processed genre #2929: kannadapop
# Processed genre #2931: symphonicdeathmetal
# Processed genre #2932: nordnorskmusikk
# Processed genre #2938: classicsinhalapop
# Processed genre #2946: cypriotpop
# Processed genre #2947: vietnamesebolero
# Processed genre #2948: mongolianalternative
# Processed genre #2950: indonesianindiepop
# Processed genre #2951: bleeptechno
# Processed genre #2952: bogorindie
# Processed genre #2954: wufam
# Processed genre #2955: bassmusic
# Processed genre #2959: munichelectronic
# Processed genre #2964: victorianbritain
# Processed genre #2967: horrorsynth
# Processed genre #2968: indienapoletano
# Processed genre #2970: coveracustico
# Processed genre #2972: danishpostpunk
# Processed genre #2973: spanishfolkrock
# Processed genre #2976: spanishreggae
# Processed genre #2977: atmosphericdnb
# Processed genre #2978: okcindie
# Processed genre #2979: windsoronindie
# Processed genre #2981: cincinnatirap
# Processed genre #2985: musiikkialapsille
# Processed genre #2986: funkybreaks
# Processed genre #2987: plenauruguaya
# Processed genre #2989: hardtechno
# Processed genre #2990: hungarianedm
# Processed genre #2991: ukrainianedm
# Processed genre #2992: experimentaljazz
# Processed genre #2993: dutchprog
# Processed genre #2994: musicaistmena
# Processed genre #2995: jazzcubano
# Processed genre #2996: kurdishremix
# Processed genre #2997: musicaquintanarroense
# Processed genre #2998: japaneseundergroundrap
# Processed genre #3000: classicicelandicpop
# Processed genre #3002: armenianpop
# Processed genre #3003: greekhouse
# Processed genre #3004: moderngoth
# Processed genre #3005: dentontxindie
# Processed genre #3007: soulflow
# Processed genre #3009: vocaltrance
# Processed genre #3010: italianjazz
# Processed genre #3011: soncubano
# Processed genre #3012: christianhardcore
# Processed genre #3013: vintagedutchpop
# Processed genre #3014: persianmelodicrap
# Processed genre #3015: tampaindie
# Processed genre #3016: musicaayacuchana
# Processed genre #3018: bregaparaense
# Processed genre #3019: deepadultstandards
# Processed genre #3020: laplandmetal
# Processed genre #3022: freeformhardcore
# Processed genre #3023: classicdutchpop
# Processed genre #3024: straightaheadjazz
# Processed genre #3025: undergroundrap
# Processed genre #3026: dissonantdeathmetal
# Processed genre #3027: technorave
# Processed genre #3028: afrodrill
# Processed genre #3029: gambianhiphop
# Processed genre #3030: nativeamericanflute
# Processed genre #3031: austinhiphop
# Processed genre #3032: virginiapunk
# Processed genre #3033: hokkienpop
# Processed genre #3034: croatianhiphop
# Processed genre #3035: kolkataindie
# Processed genre #3037: bristolelectronic
# Processed genre #3039: britishcontemporaryclassical
# Processed genre #3040: welshhiphop
# Processed genre #3041: argentineindierock
# Processed genre #3042: chineseindierock
# Processed genre #3043: cybermetal
# Processed genre #3044: modernfunk
# Processed genre #3045: smoothsoul
# Processed genre #3260: trancemexicano
# Processed genre #3262: germanopera
# Processed genre #3264: nuevatrovachilena
# Processed genre #3265: musicacaboverdiana
# Processed genre #3267: koreanworship
# Processed genre #3273: deepsoundtrack
# Processed genre #3274: okindie
# Processed genre #3275: longislandpunk
# Processed genre #3497: montenegrinpop
# Processed genre #3498: rapfemeninomexicano
# Processed genre #3500: sepedipop
# Processed genre #3501: rockabillyenespanol
# Processed genre #3502: alpineyodeling
# Processed genre #3507: folklorechileno
# Processed genre #3508: deathnroll
# Processed genre #3513: vintagechanson
# Processed genre #3515: israelijazz
# Processed genre #3516: samoanpop
# Processed genre #3518: czechmetal
# Processed genre #3519: newwaveofglammetal
# Processed genre #3520: austinrock
# Processed genre #3521: rockofgibraltar
# Processed genre #3522: icelandichiphop
# Processed genre #3524: newcastleindie
# Processed genre #3526: clevelandmetal
# Processed genre #3528: blackcomedy
# Processed genre #3529: corridosadictivos
# Processed genre #3534: northeastindianindie
# Processed genre #3536: folklorevenezolano
# Processed genre #3538: hungarianmetal
# Processed genre #3543: fallenangel
# Processed genre #3544: crackrocksteady
# Processed genre #3546: buffalonyindie
# Processed genre #3549: italianrenaissance
# Processed genre #3553: czechfolkrock
# Processed genre #3554: dancehallcolombiano
# Processed genre #3555: lampungindie
# Processed genre #3556: cartonianimati
# Processed genre #3557: kidshiphop
# Processed genre #3558: modernprogressiverock
# Processed genre #3561: chineseclassicalperformance
# Processed genre #3567: carnavallimburg
# Processed genre #3570: hungarianpunk
# Processed genre #3571: koreanelectronic
# Processed genre #3572: rapfemininochileno
# Processed genre #3573: classicitalianfolkpop
# Processed genre #3575: brokenbeat
# Processed genre #3577: vikingblackmetal
# Processed genre #3578: folkloreuruguayo
# Processed genre #3580: neokyma
# Processed genre #3581: brazilianmodernjazz
# Processed genre #3585: ukchristianrap
# Processed genre #3587: chineseindiepop
# Processed genre #3588: zambianhiphop
# Processed genre #3589: ukulelecover
# Processed genre #3590: nzdnb
# Processed genre #3592: vintagebroadway
# Processed genre #3593: ukrainianclassicalpiano
# Processed genre #3598: jazzharp
# Processed genre #3603: springfieldmoindie
# Processed genre #3605: nordiccontemporaryclassical
# Processed genre #3608: paidikatragoudia
# Processed genre #3610: garagepunk
# Processed genre #3611: portlandmetal
# Processed genre #3614: stlouisdrill
# Processed genre #3617: lightmusic
# Processed genre #3619: indonesianhardcore
# Processed genre #3622: norwegianalternativerock
# Processed genre #3631: spanishelectronic
# Processed genre #3636: dominicanindie
# Processed genre #3639: chinesesoundtrack
# Processed genre #3641: balkanpunk
# Processed genre #3643: backgroundjazzproduct
# Processed genre #3645: psychgaze
# Processed genre #3646: kansasindie
# Processed genre #3647: rapmetalespanol
# Processed genre #3648: deepidm
# Processed genre #3650: punkcatala
# Processed genre #3652: littlerockindie
# Processed genre #3654: kurdishrock
# Processed genre #3657: peruvianpunk
# Processed genre #3658: dancehallguyanaise
# Processed genre #3662: detskiepesni
# Processed genre #3664: caucasianclassical
# Processed genre #3665: rockenasturiano
# Processed genre #3666: christiandance
# Processed genre #3668: hungarianundergroundrap
# Processed genre #3669: bretonfolk
# Processed genre #3673: shoegazebrasileiro
# Processed genre #3674: mexicantraditional
# Processed genre #3676: jordanianpop
# Processed genre #3678: yugoslavnewwave
# Processed genre #3679: igborap
# Processed genre #3682: musicainfantilcatala
# Processed genre #3683: musiquecomorienne
# Processed genre #3686: kenyanhiphop
# Processed genre #3688: classickoreanpop
# Processed genre #3689: zimurbangroove
# Processed genre #3690: hungarianclassicalperformance
# Processed genre #3691: marimbadeguatemala
# Processed genre #3692: rockcuritibano
# Processed genre #3693: muzikalyeladim
# Processed genre #3695: northernirishpunk
# Processed genre #3698: spanishprog
# Processed genre #3699: musicacapixaba
# Processed genre #3700: martialindustrial
# Processed genre #3705: jewishhiphop
# Processed genre #3706: worldmeditation
# Processed genre #3707: technicalmelodicdeathmetal
# Processed genre #3708: hungariantechno
# Processed genre #3710: kansaiindie
# Processed genre #3711: musichall
# Processed genre #3712: afrikaanshiphop
# Processed genre #3714: gulfhiphop
# Processed genre #3715: taiwaninstrumental
# Processed genre #3716: persiandrill
# Processed genre #3717: veganstraightedge
# Processed genre #3718: israelitechno
# Processed genre #3720: hamburgerschule
# Processed genre #3721: deepcontemporarycountry
# Processed genre #3722: cumbiacristiana
# Processed genre #3723: indiecristao
# Processed genre #3724: fanchant
# Processed genre #3726: malaysianpunk
# Processed genre #3727: puertoricanindie
# Processed genre #3728: hindustaniinstrumental
# Processed genre #3733: southamptonindie
# Processed genre #3734: dubpunk
# Processed genre #3735: punkmelodicochileno
# Processed genre #3737: bangladeshiindie
# Processed genre #3738: italianfolk
# Processed genre #3739: musicaduranguense
# Processed genre #3740: rvaindie
# Processed genre #3741: rappernambucano
# Processed genre #3742: magyarmulatos
# Processed genre #3743: armenianfolk
# Processed genre #3745: singaporeanhiphop
# Processed genre #3746: indiefolkitaliano
# Processed genre #3747: musicalombarda
# Processed genre #3748: halifaxindie
# Processed genre #3750: mississippiindie
# Processed genre #3751: frenchblackmetal
# Processed genre #3753: norwegianamericana
# Processed genre #3754: ukbeatdown
# Processed genre #3755: czskreggae
# Processed genre #3756: aarhusindie
# Processed genre #3757: deepbrazilianpop
# Processed genre #3758: segamauricien
# Processed genre #3759: histoirepourenfants
# Processed genre #3761: tucsonindie
# Processed genre #3762: nyroots
# Processed genre #3763: musicaevangelicainstrumental
# Processed genre #3764: deepdubstep
# Processed genre #3765: northdakotaindie
# Processed genre #3766: swedishprog
# Processed genre #3767: ryukyuongaku
# Processed genre #3770: flemishfolk
# Processed genre #3771: garagepsych
# Processed genre #3773: britishindustrial
# Processed genre #3774: bahamianpop
# Processed genre #3775: spanishrockabilly
# Processed genre #3777: rapportuense
# Processed genre #3778: indieelectronica
# Processed genre #3779: canadianexperimental
# Processed genre #3780: rapgalego
# Processed genre #3781: fijianpop
# Processed genre #3782: deepdeephouse
# Processed genre #3783: polishjazz
# Processed genre #3784: svensklovsang
# Processed genre #3785: atmosphericsludge
# Processed genre #3786: chillbaile
# Processed genre #3787: quebecdeathmetal
# Processed genre #3789: italianska
# Processed genre #3790: italiannewwave
# Processed genre #3791: baptistgospel
# Processed genre #3792: swedishhardcore
# Processed genre #3793: musicahondurena
# Processed genre #3794: texaspunk
# Processed genre #3797: newyorkdeathmetal
# Processed genre #3798: hindiworship
# Processed genre #3799: musicapitiusa
# Processed genre #3800: boogiewoogie
# Processed genre #3801: deepbigroom
# Processed genre #3802: afropsych
# Processed genre #3803: raptico
# Processed genre #3805: leipzigindie
# Processed genre #3806: wyomingindie
# Processed genre #4035: drilltuga
# Processed genre #4036: dancehallmauricien
# Processed genre #4038: eroticproduct
# Processed genre #4040: bandaguanajuatense
# Processed genre #4043: iowahiphop
# Processed genre #4046: zurichindie
# Processed genre #4049: pacificislandsgospel
# Processed genre #4290: blackenedcrust
# Processed genre #4296: italianmandolin
# Processed genre #4298: beninesepop
# Processed genre #4300: tijuanaelectronic
# Processed genre #4303: epicdoom
# Processed genre #4305: stuttgartindie
# Processed genre #4306: technicalbrutaldeathmetal
# Processed genre #4307: bandaperuana
# Processed genre #4308: musicacalabrese
# Processed genre #4313: sunsetlounge
# Processed genre #4318: turkishclassical
# Processed genre #4320: chineseinstrumental
# Processed genre #4322: darkambient
# Processed genre #4324: vlaamserap
# Processed genre #4329: deepitalodisco
# Processed genre #4331: swedishposthardcore
# Processed genre #4332: southernchinaindie
# Processed genre #4335: gospelsoul
# Processed genre #4340: swissblackmetal
# Processed genre #4341: musicavalenciana
# Processed genre #4342: turkishclassicalperformance
# Processed genre #4345: indonesiandeathmetal
# Processed genre #4347: musicamocambicana
# Processed genre #4348: classicmoroccanpop
# Processed genre #4349: adelaideindie
# Processed genre #4350: neocrust
# Processed genre #4351: latinocomedy
# Processed genre #4352: vietnameseelectronic
# Processed genre #4357: newenglandmetal
# Processed genre #4358: deepmelodicdeathmetal
# Processed genre #4359: montanaindie
# Processed genre #4361: germandeathmetal
# Error processing genre #4362 (metalcolombiano): Error fetching genre page.
# Processed genre #4365: norwegiandeathmetal
# Processed genre #4366: russianclassicalpiano
# Processed genre #4371: brasiliaindie
# Processed genre #4372: ukrainianmetal
# Processed genre #4374: nordicshoegaze
# Processed genre #4375: punkgalego
# Processed genre #4378: militarycadence
# Processed genre #4379: estonianelectronic
# Processed genre #4380: earlymusicchoir
# Processed genre #4381: slovakfolk
# Processed genre #4383: togolesepop
# Processed genre #4384: georgianalternative
# Processed genre #4385: winnipeghiphop
# Processed genre #4388: caracasindie
# Processed genre #4390: traditionalreggae
# Processed genre #4391: africanpercussion
# Processed genre #4392: uatrap
# Processed genre #4394: finnishprogressivemetal
# Processed genre #4395: azerialternative
# Processed genre #4397: norwegiangospel
# Processed genre #4403: greekblackmetal
# Processed genre #4404: virginiaindie
# Processed genre #4405: psychedelicspacerock
# Processed genre #4406: khandeshipop
# Processed genre #4407: floridahardcore
# Processed genre #4408: deepprogressiverock
# Processed genre #4409: southafricanelectronic
# Processed genre #4410: finnishmetalcore
# Processed genre #4415: balmusette
# Processed genre #4419: darkpsytrance
# Processed genre #4423: uaeindie
# Processed genre #4426: musiquenigerienne
# Processed genre #4427: traditionalska
# Processed genre #4428: bolivianrock
# Processed genre #4429: dresdenindie
# Processed genre #4430: bluesmexicano
# Processed genre #4431: cardiffindie
# Processed genre #4435: bagpipemarchingband
# Processed genre #4437: lawrenceksindie
# Processed genre #4438: polishthrashmetal
# Processed genre #4439: oldschoolnederhop
# Processed genre #4441: bosnianindie
# Processed genre #4443: joseonpop
# Processed genre #4445: deepfreestyle
# Processed genre #4447: dubmetal
# Processed genre #4449: francoflemishschool
# Processed genre #4451: spanishexperimental
# Processed genre #4453: deepeurodance
# Processed genre #4454: somalipop
# Processed genre #4455: israeliclassicalpiano
# Processed genre #4456: hiphopboliviano
# Processed genre #4458: westyorkshireindie
# Processed genre #4460: prewarblues
# Processed genre #4461: musicadeintervencao
# Processed genre #4464: finlandssvenskamusik
# Processed genre #4465: cascadiapsych
# Processed genre #4466: undergroundgrunge
# Processed genre #4468: atmosphericpostrock
# Processed genre #4471: raptugaunderground
# Processed genre #4472: hitech
# Processed genre #4475: indiemichoacano
# Processed genre #4477: arizonapunk
# Processed genre #4482: deepdiscofox
# Processed genre #4483: thaiinstrumental
# Processed genre #4486: bajansoca
# Processed genre #4489: canadianrockabilly
# Processed genre #4492: milwaukeeindie
# Processed genre #4493: michiganfolk
# Processed genre #4494: backingtrack
# Processed genre #4495: musicamexiquense
# Processed genre #4496: albanianrock
# Processed genre #4497: indiecampechano
# Processed genre #4498: italiandeathmetal
# Processed genre #4499: pittsburghmetal
# Processed genre #4502: indonesianemorap
# Processed genre #4503: braziliandeathmetal
# Processed genre #4505: estonianindie
# Processed genre #4506: indianmetal
# Processed genre #4508: dundeeindie
# Processed genre #4509: sierraleoneanpop
# Processed genre #4510: psychedelicjazzfusion
# Processed genre #4512: bostonelectronic
# Processed genre #4514: ilocanopop
# Processed genre #4515: folkloreveracruzano
# Processed genre #4516: montanaroots
# Processed genre #4517: slovakelectronic
# Processed genre #4518: swedishpoppunk
# Processed genre #4520: osloindie
# Processed genre #4521: russianpostrock
# Processed genre #4522: algerianfolk
# Processed genre #4523: ukrainianblackmetal
# Processed genre #4524: mexicanexperimental
# Processed genre #4525: reggaetico
# Processed genre #4526: blackdeath
# Processed genre #4527: australianhardcore
# Processed genre #4528: seannossinging
# Processed genre #4529: southasianmetal
# Processed genre #4530: surinamesehiphop
# Processed genre #4531: louisvilleunderground
# Processed genre #4534: maltesehiphop
# Processed genre #4535: southdakotaindie
# Processed genre #4536: danishdeathmetal
# Processed genre #4537: finnishworship
# Processed genre #4538: forroinstrumental
# Processed genre #4539: kannadabhavageethe
# Processed genre #4541: preparedpiano
# Processed genre #4542: jazzguitartrio
# Processed genre #4544: norwegiancontemporaryjazz
# Processed genre #4545: finnishjazz
# Processed genre #4546: progressiveblackmetal
# Processed genre #4547: swedishpostpunk
# Processed genre #4548: neosouljazz
# Processed genre #4549: canadiandeathmetal
# Processed genre #4550: hamptonroadsindie
# Processed genre #4552: greenlandicpop
# Processed genre #4553: dutchmusical
# Processed genre #4554: canadiandrill
# Processed genre #4556: jazzflute
# Processed genre #4557: umeahardcore
# Processed genre #4558: bachchonkegeet
# Processed genre #4559: blackspeedmetal
# Processed genre #4560: swedishexperimental
# Processed genre #4561: czechalternativerap
# Processed genre #4563: czskelectropop
# Processed genre #4565: deeprb
# Processed genre #4566: dessinanime
# Processed genre #4568: japanesedeathmetal
# Processed genre #4801: hawaiianindie
# Processed genre #4802: organicambient
# Processed genre #4806: geininsong
# Processed genre #4810: mexicanpostrock
# Processed genre #4811: sufichant
# Processed genre #4812: faroeserock
# Processed genre #4814: progressivethrash
# Processed genre #4818: southcarolinametal
# Processed genre #4819: australianpostpunk
# Processed genre #5058: warmetal
# Processed genre #5060: hammereddulcimer
# Processed genre #5062: derryindie
# Processed genre #5064: hotjazz
# Processed genre #5066: musicamadeirense
# Processed genre #5068: norwegiantechno
# Processed genre #5069: newhampshireindie
# Processed genre #5071: italianblackmetal
# Processed genre #5075: namibianpop
# Processed genre #5077: danishclassical
# Processed genre #5085: bernindie
# Processed genre #5087: batonrougeindie
# Processed genre #5092: deepdarkpsy
# Processed genre #5097: brassbandbrasileiro
# Processed genre #5099: latvianfolk
# Processed genre #5100: indiepoblano
# Processed genre #5104: portsmouthindie
# Processed genre #5107: deepfilthstep
# Processed genre #5108: latinsurfrock
# Processed genre #5111: deepsunsetlounge
# Processed genre #5114: finnishexperimental
# Processed genre #5115: sulawesiindie
# Processed genre #5116: missouriindie
# Processed genre #5118: industrialhardcore
# Processed genre #5120: jugband
# Processed genre #5124: magyarmusicalek
# Processed genre #5125: slovenskechvaly
# Processed genre #5126: germanorchestra
# Processed genre #5127: russiancontemporaryclassical
# Processed genre #5128: peruvianmetal
# Processed genre #5129: seychellespop
# Processed genre #5130: canadianclassicalpiano
# Processed genre #5132: finnishhardcore
# Processed genre #5134: singaporeanmetal
# Processed genre #5135: isleofmanindie
# Processed genre #5136: irishcontemporaryclassical
# Processed genre #5137: kannadaindie
# Processed genre #5139: hongkongtvdrama
# Processed genre #5141: italiancontemporaryclassical
# Processed genre #5142: modernmod
# Processed genre #5143: greekpunk
# Processed genre #5144: canadianshoegaze
# Processed genre #5145: adelaidepunk
# Processed genre #5147: cantialpini
# Processed genre #5149: surabayaindie
# Processed genre #5150: tajikpop
# Processed genre #5153: luxembourgianpop
# Processed genre #5155: womenschoir
# Processed genre #5158: ritualambient
# Processed genre #5159: sundanesetraditional
# Processed genre #5161: radiosymphony
# Processed genre #5162: gothicdoom
# Processed genre #5165: japanesechoir
# Processed genre #5166: musicamorelense
# Processed genre #5171: serbianfolk
# Processed genre #5174: turkishdeathmetal
# Processed genre #5176: chamamebrasilero
# Processed genre #5179: dronerock
# Processed genre #5180: brazilianexperimental
# Processed genre #5181: nubiantraditional
# Processed genre #5183: syroaramaicchant
# Processed genre #5184: finnishpsychedelicrock
# Processed genre #5186: sanantonioindie
# Processed genre #5188: malangpunk
# Processed genre #5190: folkmetallatinoamericano
# Processed genre #5193: frenchrenaissance
# Processed genre #5194: firenzeindie
# Processed genre #5195: australianshoegaze
# Processed genre #5196: deepmelodicmetalcore
# Processed genre #5197: irishblackmetal
# Processed genre #5198: laguiban
# Processed genre #5199: konkanipop
# Processed genre #5200: volkstumlichemusik
# Processed genre #5201: musicacampista
# Processed genre #5202: irishtrap
# Processed genre #5203: cumbiafunk
# Processed genre #5206: swedishemo
# Processed genre #5207: cambridgechoir
# Processed genre #5208: westvirginiametal
# Processed genre #5211: rapmocambicana
# Processed genre #5213: vintagenorwegianpop
# Processed genre #5215: swedishebm
# Processed genre #5216: bernudziesmas
# Processed genre #5218: rockalagoano
# Processed genre #5219: irishflute
# Processed genre #5220: aberdeenindie
# Processed genre #5221: neoindustrialrock
# Processed genre #5224: tuvanfolk
# Processed genre #5230: powerelectronics
# Processed genre #5232: jazztico
# Processed genre #5233: vintagespanishpop
# Processed genre #5234: chamberchoir
# Processed genre #5235: neohonkytonk
# Processed genre #5236: deepclassicgaragerock
# Processed genre #5237: vintageswing
# Processed genre #5239: karbipop
# Processed genre #5241: jazzchileno
# Processed genre #5242: ancientmediterranean
# Processed genre #5243: rotterdamindie
# Processed genre #5246: wisconsinmetal
# Processed genre #5247: norwegianfolk
# Processed genre #5248: deepjazzfusion
# Processed genre #5251: freeimprovisation
# Processed genre #5252: svenskindie
# Processed genre #5254: folcloreportugues
# Processed genre #5256: indianambient
# Processed genre #5258: russianpowermetal
# Processed genre #5259: indiesudcaliforniano
# Processed genre #5260: bulgarianfolk
# Processed genre #5262: japaneseblackmetal
# Processed genre #5263: musicasergipana
# Processed genre #5266: paraguayanindie
# Processed genre #5267: chinesepostpunk
# Processed genre #5269: bulgarianindie
# Processed genre #5270: indieboliviano
# Processed genre #5274: diypoppunk
# Processed genre #5277: arkansasmetal
# Processed genre #5278: karenpop
# Processed genre #5279: jazzdominicano
# Processed genre #5280: grungerevival
# Processed genre #5281: cubanelectronic
# Processed genre #5283: occultblackmetal
# Processed genre #5284: canzonesiciliane
# Processed genre #5285: germanshoegaze
# Processed genre #5288: bahamianfolk
# Processed genre #5289: myanmargospel
# Processed genre #5291: chinesemetal
# Processed genre #5293: musicamenorquina
# Processed genre #5296: libyanhiphop
# Processed genre #5297: pinoyshoegaze
# Processed genre #5299: russianblackmetal
# Processed genre #5301: popsorchestra
# Processed genre #5302: colombianhardcore
# Processed genre #5303: indianviolin
# Processed genre #5305: danishhardcore
# Processed genre #5306: rapecuatoguineano
# Processed genre #5308: indonesianshoegaze
# Processed genre #5309: irishundergroundrap
# Processed genre #5310: stpetersburgflindie
# Processed genre #5311: mizogospel
# Processed genre #5312: austrianorchestra
# Processed genre #5314: japanesehardcore
# Processed genre #5315: icelandictraditional
# Processed genre #5316: metalparanaense
# Processed genre #5317: rockcatracho
# Processed genre #5318: musicaprehispanica
# Processed genre #5319: harddance
# Processed genre #5322: hungarianclassicalpiano
# Processed genre #5324: deepfullon
# Processed genre #5326: indietrujillano
# Processed genre #5327: spanishclassicalpiano
# Processed genre #5328: belgianstonerrock
# Processed genre #5329: southafricanpunk
# Processed genre #5330: jazzcolombiano
# Processed genre #5565: deepsurfmusic
# Processed genre #5566: delawareindie
# Processed genre #5568: swissexperimental
# Processed genre #5570: classicalmezzosoprano
# Processed genre #5577: muzicamaramureseana
# Processed genre #5578: deepspacerock
# Processed genre #5581: izvornamuzika
# Processed genre #5823: experimentalpoetry
# Processed genre #5824: magyarkabare
# Processed genre #5825: taiwanexperimental
# Processed genre #5826: portugueseexperimental
# Processed genre #5830: garopop
# Processed genre #5831: latvianmetal
# Processed genre #5832: deepdeltablues
# Processed genre #5833: jotaaragonesa
# Processed genre #5834: moroccantraditional
# Processed genre #5836: rockparaense
# Processed genre #5842: spanishcontemporaryclassical
# Processed genre #5845: turkishhardcore
# Processed genre #5846: persianpoetry
# Processed genre #5848: afrikaansfolk
# Processed genre #5849: botswanahiphop
# Processed genre #5850: maldivianpop
# Processed genre #5854: classicalguitarduo
# Processed genre #5857: indienordesteargentino
# Processed genre #5858: tatarfolk
# Processed genre #5859: czechpsychedelic
# Processed genre #5860: songpoem
# Processed genre #5862: italianindustrial
# Processed genre #5867: tibetanfolkpop
# Processed genre #5868: irishdeathmetal
# Processed genre #5872: irishmodernjazz
# Processed genre #5874: metalcearense
# Processed genre #5878: italianheavymetal
# Processed genre #5880: latinamericanbaroque
# Processed genre #5882: appenzellerfolk
# Processed genre #5883: grungeargentina
# Processed genre #5884: brazilianclassicalpiano
# Processed genre #5885: animalsinging
# Processed genre #5886: hardchime
# Processed genre #5887: portugueseearlymusic
# Processed genre #5891: policeband
# Processed genre #5892: punkska
# Processed genre #5893: hardstonerrock
# Processed genre #5894: accordionband
# Processed genre #5895: metaluruguayo
# Processed genre #5897: balticblackmetal
# Processed genre #5899: fifeanddrum
# Processed genre #5900: koreanhardcore
# Processed genre #5901: alternativehardcore
# Processed genre #5905: classicalguitarquartet
# Processed genre #5906: marathibalgeet
# Processed genre #5908: balticchoir
# Processed genre #5909: chaoticblackmetal
# Processed genre #5910: austrianchoir
# Processed genre #5911: yiddishfolk
# Processed genre #5914: chineseblackmetal
# Processed genre #5916: mexicanblackmetal
# Processed genre #5923: maliantraditional
# Processed genre #5927: musicasinfonica
# Processed genre #5928: montanametal
# Processed genre #5930: estonianjazz
# Processed genre #5933: czechcontemporaryclassical
# Processed genre #5936: iranianmetal
# Processed genre #5943: uyghurfolk
# Processed genre #5945: cosmicupliftingtrance
# Processed genre #5946: metalbalear
# Processed genre #5948: polishexperimental
# Processed genre #5949: industrialnoise
# Processed genre #5952: centralasianfolk
# Processed genre #5953: kadongokamu
# Processed genre #5955: balticclassicalpiano
# Processed genre #5957: musicaurbanaoaxaquena
# Processed genre #5960: jewishcantorial
# Processed genre #5962: metisfiddle
# Processed genre #5966: cypriotmetal
# Processed genre #5967: operachorus
# Processed genre #5971: deepindiepop
# Processed genre #5973: australianchoir
# Processed genre #5974: pygmymusic
# Processed genre #5975: classicalpianoduo
# Processed genre #5982: dronepsych
# Processed genre #5983: metalpiauiense
# Processed genre #5984: artsong
# Processed genre #5989: czechexperimental
# Processed genre #5990: lagulampung
# Processed genre #5995: classicalhorn
# Processed genre #5996: deepsymphonicblackmetal
# Processed genre #5997: janglerock
# Processed genre #5998: cantonesetraditional
# Processed genre #6001: burundiantraditional
# Processed genre #6002: polishearlymusic
# Processed genre #6003: classicaltuba
# Processed genre #6004: russianoi
# Processed genre #6005: baroquewoodwind
# Processed genre #6006: schoolensemble
# Processed genre #6007: deeppowerpoppunk
# Processed genre #6008: albanianisopolyphony
# Processed genre #6010: wagneriansinging
# Processed genre #6015: indietabasqueno
# Processed genre #6016: tweeindiepop
# Processed genre #6017: swisscontemporaryclassical
# Processed genre #6019: indonesianindigenous
# Processed genre #6020: musicamogiana
# Processed genre #6024: musiquealsacienne
# Processed genre #6025: deepchillout
# Processed genre #6030: chiphop
# Processed genre #6031: baroqueviolin
# Processed genre #6032: metalcatarinense
# Processed genre #6033: harshnoisewall
# Processed genre #6036: kabagaida
# Processed genre #6037: deepdeeptechhouse
# Processed genre #6039: rhythmandboogie
# Processed genre #6040: faroesejazz
# Processed genre #6041: peruvianexperimental
# Processed genre #6042: vintageswoon
# Processed genre #6044: cambodiantraditional
# Processed genre #6045: burmesetraditional
# Processed genre #6046: vintagerockabilly
# Processed genre #6047: baroquecello
# Processed genre #6048: lagumadura
# Processed genre #6049: ghanaiantraditional
# Processed genre #6050: musiquecentrafricaine
# Processed genre #6051: balikpapanindie
# Processed genre #6052: bruneianindie
# Processed genre #6053: indieemorock
# Processed genre #6054: rwandantraditional
# Processed genre #6055: bothyballad
# Processed genre #6056: gaychorus
# Processed genre #6057: laotraditional
# Processed genre #6058: uzbektraditional
# Processed genre #6059: polishfreejazz
# Processed genre #6063: chineseopera
# Processed genre #6064: deepbreakcore
# Processed genre #6065: papuantraditional
# Processed genre #6066: windquintet
# Processed genre #6067: macedonianmetal
# Processed genre #6068: kenyantraditional
# Processed genre #6069: mazandaranifolk
# Processed genre #6070: yemenitraditional
# Processed genre #6071: tajiktraditional
# Processed genre #6072: italianchoir
# Processed genre #6073: ugandantraditional
# Processed genre #6074: quatuoracordes
# Processed genre #6076: hungarianchoir
# Processed genre #6078: italianmezzosoprano
# Processed genre #6079: windensemble
# Processed genre #6080: swissclassicalpiano
# Processed genre #6082: swazitraditional
# Processed genre #6083: cinematicdubstep
# Processed genre #6084: baroquebrass
# Processed genre #6085: himenetarava
# Processed genre #6086: yunnantraditional
# Processed genre #6087: classicalpianoquartet
# Processed genre #6088: stringquintet
# Processed genre #6089: quartettodarchi
# Processed genre #6090: vintagewestern
# Processed genre #6092: youthorchestra

# %%
import pandas as pd
# [subgenre_list, playlists, subgenre_list_sim, sim_weights, subgenre_list_opp, opp_weights, subgenre_list_artist, artist_weights]
#df = pd.DataFrame({"GENRE":music_data[0], 
                  # "SIM_GENRES":music_data[2],
                  # "SIM_WEIGHTS":music_data[3],
                  # "OPP_GENRES":music_data[4],
                  # "OPP_WEIGHTS":music_data[5],
                  # "REL_ARTISTS":music_data[6], 
                  # "ARTIST_WEIGHTS":music_data[7],
                  # "SPOTIFY_URL":music_data[1]})
#df.to_csv('all_genres1.csv')
df = pd.read_csv("all_genres1.csv")
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6091 entries, 0 to 6092
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GENRE           6091 non-null   object
#  1   SIM_GENRES      6091 non-null   object
#  2   SIM_WEIGHTS     6091 non-null   object
#  3   OPP_GENRES      6091 non-null   object
#  4   OPP_WEIGHTS     6091 non-null   object
#  5   REL_ARTISTS     6091 non-null   object
#  6   ARTIST_WEIGHTS  6091 non-null   object
#  7   SPOTIFY_URL     6091 non-null   object
# dtypes: object(8)
# memory usage: 428.3+ KB

# %%
import spotipy
import spotipy.oauth2 as oauth2
from spotipy.oauth2 import SpotifyClientCredentials

sp_client_id = ''
sp_client_secret = ''
credentials = oauth2.SpotifyClientCredentials(client_id=sp_client_id, client_secret=sp_client_secret)
sp = spotipy.Spotify(client_credentials_manager=credentials)

features = ['popularity', 'danceability', 'energy', 'key', 'loudness',
                    'mode', 'speechiness', 'acousticness', 'instrumentalness',
                    'liveness', 'valence', 'tempo', 'time_signature']

# %%
import time
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor
import json

def get_track_ids_from_playlist(sp, playlist_id):

    results = sp.playlist_tracks(playlist_id)
    track_ids = [item['track']['id'] for item in results['items']]
    return track_ids


def get_track_ids_for_playlists(sp, playlists):
    track_ids_dict = {}

        # Load existing track IDs
    try:
        with open('track_ids.json', 'r') as f:
            track_ids_dict = json.load(f)
    except FileNotFoundError:
        pass
    # Define a function for processing a single playlist URL in a separate thread
    def process_playlist_url(playlist_url):
        nonlocal track_ids_dict

        if playlist_url is None:
            track_ids_dict[playlist_url] = None
        elif playlist_url not in track_ids_dict:
            playlist_id = playlist_url.split('playlist/')[1]

            success, retries = False, 0
            while not success and retries < 2:  # Attempt once and retry once
                try:
                    track_ids = get_track_ids_from_playlist(sp, playlist_id)
                    track_ids_dict[playlist_url] = track_ids
                    success = True
                except Exception as e:
                    sleep_time = 2 ** retries
                    time.sleep(sleep_time)
                    retries += 1

    # Process all playlist URLs concurrently
    with ThreadPoolExecutor() as executor:
        list(tqdm(executor.map(process_playlist_url, playlists), total=len(playlists), desc='Processing playlists'))

    # Save track IDs to a file
    with open('track_ids.json', 'w') as f:
        json.dump(track_ids_dict, f)

    return track_ids_dict

playlists = [url for url in df['SPOTIFY_URL'].tolist() if isinstance(url, str)]
playlist_track_ids = get_track_ids_for_playlists(sp, playlists)
# Out:
# Processing playlists: 100%|█████████████████| 6091/6091 [02:46<00:00, 36.65it/s]

# %%
from ratelimiter import RateLimiter
sp = spotipy.Spotify(client_credentials_manager=spotipy.oauth2.SpotifyClientCredentials(client_id = '', client_secret = ''))

def get_track_popularity(sp, track_ids):
    track_popularity = {}
    
    tracks = sp.tracks(track_ids)
    for track in tracks['tracks']:
        track_popularity[track['id']] = track['popularity']

    return track_popularity

def get_audio_features_for_tracks(sp, track_ids_dict):
    audio_features_dict = {}
        # Load existing audio features
    try:
        with open('audio_features.json', 'r') as f:
            audio_features_dict = json.load(f)
    except FileNotFoundError:
        pass
    
    rate_limiter = RateLimiter(max_calls=30, period=1)
    # Adjust the rate limit as needed

    def process_track_ids(track_ids):
        nonlocal audio_features_dict
        batch_size = 50
    
        for i in range(0, len(track_ids), batch_size):
            batch = track_ids[i:i + batch_size]
        
        # Divide the batch into two parts: unprocessed_batch and processed_batch
        unprocessed_batch = [tid for tid in batch if tid not in audio_features_dict]
        processed_batch = [tid for tid in batch if tid in audio_features_dict]
        
        if unprocessed_batch:
            success, retries = False, 0
            while not success and retries < 10:  # Attempt once and retry once
                with rate_limiter:
                    try:
                        features = sp.audio_features(unprocessed_batch)
                        popularity = get_track_popularity(sp, unprocessed_batch)
                        
                        for feature in features:
                            feature['popularity'] = popularity[feature['id']]
                            audio_features_dict[feature['id']] = feature
                        
                        success = True
                    except Exception as e:
                        sleep_time = 2 ** retries
                        time.sleep(sleep_time)
                        retries += 1
        
        # Update popularity for processed tracks
        if processed_batch:
            popularity = get_track_popularity(sp, processed_batch)
                
            for tid in processed_batch:
                audio_features_dict[tid]['popularity'] = popularity[tid]
                
    # Process all track IDs concurrently
    with ThreadPoolExecutor(max_workers=6) as executor:
        track_ids_list = [ids for ids in track_ids_dict.values() if ids is not None]
        all_track_ids = [tid for ids in track_ids_list for tid in ids]
        chunks = [all_track_ids[i:i+50] for i in range(0, len(all_track_ids), 50)]
        list(tqdm(executor.map(process_track_ids, chunks), total=len(chunks), desc='Processing audio features'))
    # Save audio features to a file
    with open('audio_features.json', 'w') as f:
        json.dump(audio_features_dict, f)

    return audio_features_dict

audio_features = get_audio_features_for_tracks(sp, playlist_track_ids)
# Out:
# Processing audio features:  26%|██▊        | 3069/11805 [05:25<15:25,  9.43it/s]
#
# KeyboardInterrupt

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# Create a dictionary with genres as keys and lists of track IDs as values
genre_track_ids = {}
for index, row in df.iterrows():
    genre = row['GENRE']
    playlist_url = row['SPOTIFY_URL']
    track_ids = playlist_track_ids.get(playlist_url, [])
    if track_ids is not None:
        if genre not in genre_track_ids:
            genre_track_ids[genre] = []
        genre_track_ids[genre].extend(track_ids)

# Calculate the average of each audio feature for the tracks in each genre
genre_audio_features_avg = {}
for genre, track_ids in tqdm(genre_track_ids.items(), desc='Processing genres'):
    features_list = [audio_features[tid] for tid in track_ids if tid in audio_features]
    if features_list:
        features_df = pd.DataFrame(features_list)
        features_mean = features_df.mean(numeric_only=True)
        genre_audio_features_avg[genre] = features_mean.to_dict()
    else:
        genre_audio_features_avg[genre] = None

# %%
genre_audio_features_avg
# Out:
# {'pop': {'danceability': 0.6620600000000002,
#   'energy': 0.6511099999999999,
#   'key': 5.12,
#   'loudness': -5.726880000000001,
#   'mode': 0.64,
#   'speechiness': 0.07093500000000001,
#   'acousticness': 0.1975984,
#   'instrumentalness': 0.006247488700000001,
#   'liveness': 0.17319500000000002,
#   'valence': 0.512612,
#   'tempo': 123.58468999999997,
#   'duration_ms': 204923.68,
#   'time_signature': 3.94},
#  'rap': {'danceability': 0.7286400000000001,
#   'energy': 0.63693,
#   'key': 5.77,
#   'loudness': -6.236810000000002,
#   'mode': 0.56,
#   'speechiness': 0.15241000000000002,
#   'acousticness': 0.14459235000000004,
#   'instrumentalness': 0.0012794415999999996,
#   'liveness': 0.196954,
#   'valence': 0.4643110000000001,
#   'tempo': 114.62312999999999,
#   'duration_ms': 223874.0,
#   'time_signature': 3.96},
#  'rock': {'danceability': 0.5032700000000001,
#   'energy': 0.71774,
#   'key': 4.68,
#   'loudness': -7.786729999999999,
#   'mode': 0.7,
#   'speechiness': 0.058156,
#   'acousticness': 0.12671333900000004,
#   'instrumentalness': 0.047587683,
#   'liveness': 0.17069100000000004,
#   'valence': 0.5680900000000001,
#   'tempo': 121.70702999999997,
#   'duration_ms': 242727.62,
#   'time_signature': 3.99},
#  'dance pop': {'danceability': 0.6963199999999999,
#   'energy': 0.7195400000000001,
#   'key': 5.46,
#   'loudness': -5.35701,
#   'mode': 0.56,
#   'speechiness': 0.07654599999999999,
#   'acousticness': 0.10629905200000002,
#   'instrumentalness': 0.0162272085,
#   'liveness': 0.15897200000000003,
#   'valence': 0.5761809999999999,
#   'tempo': 121.68416,
#   'duration_ms': 220204.02,
#   'time_signature': 3.99},
#  'urbano latino': {'danceability': 0.7759500000000001,
#   'energy': 0.6909200000000001,
#   'key': 4.96,
#   'loudness': -5.6326399999999985,
#   'mode': 0.42,
#   'speechiness': 0.132842,
#   'acousticness': 0.25042580000000003,
#   'instrumentalness': 0.010534195100000001,
#   'liveness': 0.17157400000000003,
#   'valence': 0.6086,
#   'tempo': 121.42360000000001,
#   'duration_ms': 231184.68,
#   'time_signature': 4.0},
#  'hip hop': {'danceability': 0.7421800000000001,
#   'energy': 0.67266,
#   'key': 5.96,
#   'loudness': -7.23033,
#   'mode': 0.48,
#   'speechiness': 0.198549,
#   'acousticness': 0.14554995,
#   'instrumentalness': 0.010963743700000002,
#   'liveness': 0.19531600000000002,
#   'valence': 0.6048269999999999,
#   'tempo': 106.78379999999999,
#   'duration_ms': 241749.08,
#   'time_signature': 4.0},
#  'trap latino': {'danceability': 0.77142,
#   'energy': 0.6794500000000001,
#   'key': 4.56,
#   'loudness': -5.691190000000001,
#   'mode': 0.4,
#   'speechiness': 0.14786600000000003,
#   'acousticness': 0.29534679999999996,
#   'instrumentalness': 0.0085050379,
#   'liveness': 0.184715,
#   'valence': 0.5810700000000001,
#   'tempo': 122.87929000000003,
#   'duration_ms': 230789.32,
#   'time_signature': 3.99},
#  'reggaeton': {'danceability': 0.7606999999999999,
#   'energy': 0.73139,
#   'key': 5.35,
#   'loudness': -5.673629999999998,
#   'mode': 0.51,
#   'speechiness': 0.128739,
#   'acousticness': 0.2004204,
#   'instrumentalness': 0.009762689300000002,
#   'liveness': 0.18057600000000001,
#   'valence': 0.66385,
#   'tempo': 120.73056999999999,
#   'duration_ms': 234144.03,
#   'time_signature': 4.0},
#  'modern rock': {'danceability': 0.54237,
#   'energy': 0.7652000000000001,
#   'key': 4.83,
#   'loudness': -5.506699999999998,
#   'mode': 0.66,
#   'speechiness': 0.050673,
#   'acousticness': 0.09552965199999999,
#   'instrumentalness': 0.0473479221,
#   'liveness': 0.19892200000000007,
#   'valence': 0.54027,
#   'tempo': 128.74127,
#   'duration_ms': 217132.6,
#   'time_signature': 3.98},
#  'latin pop': {'danceability': 0.6340499999999999,
#   'energy': 0.64723,
#   'key': 4.99,
#   'loudness': -6.966529999999999,
#   'mode': 0.78,
#   'speechiness': 0.047395999999999994,
#   'acousticness': 0.31885587,
#   'instrumentalness': 0.004207530499999999,
#   'liveness': 0.164891,
#   'valence': 0.58229,
#   'tempo': 125.05906,
#   'duration_ms': 236496.5,
#   'time_signature': 3.95},
#  'trap': {'danceability': 0.7608399999999998,
#   'energy': 0.62452,
#   'key': 4.94,
#   'loudness': -6.206210000000001,
#   'mode': 0.54,
#   'speechiness': 0.16139299999999998,
#   'acousticness': 0.10745519000000002,
#   'instrumentalness': 0.0003136244,
#   'liveness': 0.17385199999999998,
#   'valence': 0.447755,
#   'tempo': 121.88688999999998,
#   'duration_ms': 218099.6,
#   'time_signature': 3.96},
#  'musica mexicana': {'danceability': 0.7109000000000001,
#   'energy': 0.60031,
#   'key': 5.33,
#   'loudness': -5.673520000000001,
#   'mode': 0.8,
#   'speechiness': 0.05296499999999999,
#   'acousticness': 0.45225550000000014,
#   'instrumentalness': 0.0004202939,
#   'liveness': 0.15139300000000003,
#   'valence': 0.80763,
#   'tempo': 127.44153999999999,
#   'duration_ms': 194401.45,
#   'time_signature': 3.57},
#  'classic rock': {'danceability': 0.5552799999999999,
#   'energy': 0.6133000000000001,
#   'key': 4.76,
#   'loudness': -9.79571,
#   'mode': 0.81,
#   'speechiness': 0.044455999999999996,
#   'acousticness': 0.25939881,
#   'instrumentalness': 0.042559370900000004,
#   'liveness': 0.16817400000000002,
#   'valence': 0.64794,
#   'tempo': 121.62599,
#   'duration_ms': 254267.34,
#   'time_signature': 3.94},
#  'permanent wave': {'danceability': 0.54915,
#   'energy': 0.678913,
#   'key': 4.77,
#   'loudness': -8.144680000000001,
#   'mode': 0.67,
#   'speechiness': 0.04474900000000001,
#   'acousticness': 0.17081078900000002,
#   'instrumentalness': 0.0421649041,
#   'liveness': 0.159722,
#   'valence': 0.5652010000000002,
#   'tempo': 121.56210000000002,
#   'duration_ms': 246353.88,
#   'time_signature': 3.94},
#  'alternative metal': {'danceability': 0.48890999999999996,
#   'energy': 0.8594799999999999,
#   'key': 5.38,
#   'loudness': -5.27981,
#   'mode': 0.49,
#   'speechiness': 0.07120800000000001,
#   'acousticness': 0.010018463800000002,
#   'instrumentalness': 0.0524052453,
#   'liveness': 0.18334999999999999,
#   'valence': 0.44574299999999994,
#   'tempo': 123.35508000000002,
#   'duration_ms': 237293.36,
#   'time_signature': 3.91},
#  'pop rap': {'danceability': 0.7175999999999999,
#   'energy': 0.68027,
#   'key': 5.22,
#   'loudness': -5.710990000000001,
#   'mode': 0.59,
#   'speechiness': 0.15823399999999999,
#   'acousticness': 0.146556,
#   'instrumentalness': 0.0005287529,
#   'liveness': 0.17442999999999995,
#   'valence': 0.5564330000000001,
#   'tempo': 110.39965000000002,
#   'duration_ms': 225931.83,
#   'time_signature': 4.0},
#  'r&b': {'danceability': 0.6837700000000001,
#   'energy': 0.5772700000000001,
#   'key': 5.77,
#   'loudness': -7.60221,
#   'mode': 0.42,
#   'speechiness': 0.095068,
#   'acousticness': 0.19314018999999993,
#   'instrumentalness': 0.0015498126999999998,
#   'liveness': 0.15183599999999997,
#   'valence': 0.5973400000000001,
#   'tempo': 113.65275,
#   'duration_ms': 261649.94,
#   'time_signature': 3.98},
#  'pop dance': {'danceability': 0.64952,
#   'energy': 0.8017799999999998,
#   'key': 5.53,
#   'loudness': -4.9537,
#   'mode': 0.56,
#   'speechiness': 0.06949,
#   'acousticness': 0.08046076,
#   'instrumentalness': 0.069709252,
#   'liveness': 0.22414399999999998,
#   'valence': 0.426756,
#   'tempo': 124.67268,
#   'duration_ms': 183377.48,
#   'time_signature': 3.97},
#  'edm': {'danceability': 0.6349600000000001,
#   'energy': 0.8049000000000001,
#   'key': 5.52,
#   'loudness': -5.091050000000001,
#   'mode': 0.62,
#   'speechiness': 0.06857,
#   'acousticness': 0.07024820000000002,
#   'instrumentalness': 0.0984722224,
#   'liveness': 0.22650700000000001,
#   'valence': 0.3711110000000001,
#   'tempo': 127.79189000000001,
#   'duration_ms': 196325.01,
#   'time_signature': 3.99},
#  'corrido': {'danceability': 0.72359,
#   'energy': 0.6596700000000001,
#   'key': 5.91,
#   'loudness': -5.950500000000001,
#   'mode': 0.72,
#   'speechiness': 0.07495800000000001,
#   'acousticness': 0.3772879999999999,
#   'instrumentalness': 0.001150357,
#   'liveness': 0.149436,
#   'valence': 0.8063000000000001,
#   'tempo': 122.51270999999998,
#   'duration_ms': 185204.75,
#   'time_signature': 3.15},
#  'norteno': {'danceability': 0.7188500000000001,
#   'energy': 0.6389,
#   'key': 5.66,
#   'loudness': -6.3303600000000015,
#   'mode': 0.85,
#   'speechiness': 0.07572,
#   'acousticness': 0.36998600000000004,
#   'instrumentalness': 0.00014266259999999998,
#   'liveness': 0.13790399999999997,
#   'valence': 0.8366300000000001,
#   'tempo': 127.69469000000001,
#   'duration_ms': 187940.49,
#   'time_signature': 3.48},
#  'album rock': {'danceability': 0.53103,
#   'energy': 0.6745000000000002,
#   'key': 4.86,
#   'loudness': -9.096990000000002,
#   'mode': 0.79,
#   'speechiness': 0.045721999999999985,
#   'acousticness': 0.15368011,
#   'instrumentalness': 0.022137454799999998,
#   'liveness': 0.17964399999999997,
#   'valence': 0.603881,
#   'tempo': 121.86645,
#   'duration_ms': 264779.72,
#   'time_signature': 3.97},
#  'contemporary country': {'danceability': 0.58785,
#   'energy': 0.6952200000000001,
#   'key': 5.24,
#   'loudness': -5.818910000000001,
#   'mode': 0.94,
#   'speechiness': 0.041138,
#   'acousticness': 0.21741395,
#   'instrumentalness': 0.0017094905999999995,
#   'liveness': 0.16365400000000002,
#   'valence': 0.57379,
#   'tempo': 129.36979999999997,
#   'duration_ms': 205793.75,
#   'time_signature': 3.94},
#  'filmi': {'danceability': 0.60714,
#   'energy': 0.57281,
#   'key': 5.13,
#   'loudness': -8.641839999999998,
#   'mode': 0.68,
#   'speechiness': 0.052529000000000006,
#   'acousticness': 0.5177995,
#   'instrumentalness': 0.043046064,
#   'liveness': 0.165616,
#   'valence': 0.62446,
#   'tempo': 116.63975999999998,
#   'duration_ms': 279651.96,
#   'time_signature': 3.77},
#  'canadian pop': {'danceability': 0.62061,
#   'energy': 0.6587750000000001,
#   'key': 5.2,
#   'loudness': -6.3082899999999995,
#   'mode': 0.68,
#   'speechiness': 0.060919,
#   'acousticness': 0.19585206600000002,
#   'instrumentalness': 0.0050926348,
#   'liveness': 0.17773200000000003,
#   'valence': 0.5285230000000001,
#   'tempo': 117.16169,
#   'duration_ms': 212822.15,
#   'time_signature': 3.94},
#  'k-pop': {'danceability': 0.6727100000000001,
#   'energy': 0.8221200000000001,
#   'key': 5.18,
#   'loudness': -3.41873,
#   'mode': 0.49,
#   'speechiness': 0.09107799999999999,
#   'acousticness': 0.1514351,
#   'instrumentalness': 0.00013529470000000002,
#   'liveness': 0.19253599999999998,
#   'valence': 0.6251099999999999,
#   'tempo': 122.80728999999998,
#   'duration_ms': 204890.67,
#   'time_signature': 4.01},
#  'nueva musica mexicana': {'danceability': 0.68306,
#   'energy': 0.61027,
#   'key': 5.73,
#   'loudness': -5.72559,
#   'mode': 0.74,
#   'speechiness': 0.065365,
#   'acousticness': 0.41814899999999994,
#   'instrumentalness': 0.0013756208,
#   'liveness': 0.166456,
#   'valence': 0.7949600000000001,
#   'tempo': 129.15071,
#   'duration_ms': 189867.14,
#   'time_signature': 3.24},
#  'soft rock': {'danceability': 0.5640199999999999,
#   'energy': 0.558297,
#   'key': 5.41,
#   'loudness': -10.557470000000002,
#   'mode': 0.81,
#   'speechiness': 0.038969000000000004,
#   'acousticness': 0.31110215999999996,
#   'instrumentalness': 0.015035430800000001,
#   'liveness': 0.156074,
#   'valence': 0.60318,
#   'tempo': 119.47065,
#   'duration_ms': 251676.77,
#   'time_signature': 3.98},
#  'sierreno': {'danceability': 0.7055000000000001,
#   'energy': 0.63535,
#   'key': 5.86,
#   'loudness': -5.68609,
#   'mode': 0.71,
#   'speechiness': 0.059615,
#   'acousticness': 0.44435700000000006,
#   'instrumentalness': 0.0001543721,
#   'liveness': 0.151,
#   'valence': 0.8038699999999999,
#   'tempo': 123.66222000000003,
#   'duration_ms': 190626.47,
#   'time_signature': 3.17},
#  'hard rock': {'danceability': 0.4632899999999999,
#   'energy': 0.7253500000000002,
#   'key': 5.16,
#   'loudness': -8.56629,
#   'mode': 0.68,
#   'speechiness': 0.056838999999999994,
#   'acousticness': 0.0827447286,
#   'instrumentalness': 0.0506737661,
#   'liveness': 0.18622199999999992,
#   'valence': 0.51467,
#   'tempo': 121.66002999999999,
#   'duration_ms': 267230.55,
#   'time_signature': 3.97},
#  'post-teen pop': {'danceability': 0.65779,
#   'energy': 0.7176,
#   'key': 5.54,
#   'loudness': -5.0976,
#   'mode': 0.64,
#   'speechiness': 0.05974199999999999,
#   'acousticness': 0.12388563999999999,
#   'instrumentalness': 0.0015011928999999998,
#   'liveness': 0.172198,
#   'valence': 0.563501,
#   'tempo': 121.54806999999997,
#   'duration_ms': 201584.25,
#   'time_signature': 3.97},
#  'uk pop': {'danceability': 0.6229399999999999,
#   'energy': 0.57514,
#   'key': 5.34,
#   'loudness': -6.657360000000001,
#   'mode': 0.69,
#   'speechiness': 0.064238,
#   'acousticness': 0.35235350000000004,
#   'instrumentalness': 0.0015968308,
#   'liveness': 0.15579900000000002,
#   'valence': 0.46033699999999994,
#   'tempo': 116.45488999999999,
#   'duration_ms': 197258.08,
#   'time_signature': 3.97},
#  'sad sierreno': {'danceability': 0.6606400000000001,
#   'energy': 0.5830759999999999,
#   'key': 5.85,
#   'loudness': -7.681760000000001,
#   'mode': 0.5,
#   'speechiness': 0.05184500000000001,
#   'acousticness': 0.4214843,
#   'instrumentalness': 0.0028451618,
#   'liveness': 0.13100499999999998,
#   'valence': 0.636221,
#   'tempo': 120.70692,
#   'duration_ms': 194261.26,
#   'time_signature': 3.25},
#  'nu metal': {'danceability': 0.48574,
#   'energy': 0.8620099999999998,
#   'key': 5.3,
#   'loudness': -5.272900000000001,
#   'mode': 0.5,
#   'speechiness': 0.073451,
#   'acousticness': 0.009359254000000001,
#   'instrumentalness': 0.0515568717,
#   'liveness': 0.20278,
#   'valence': 0.4326709999999999,
#   'tempo': 122.52602,
#   'duration_ms': 235357.92,
#   'time_signature': 3.9},
#  'mellow gold': {'danceability': 0.56201,
#   'energy': 0.5640270000000001,
#   'key': 5.5,
#   'loudness': -10.446789999999998,
#   'mode': 0.78,
#   'speechiness': 0.039255,
#   'acousticness': 0.33215516,
#   'instrumentalness': 0.014972345800000002,
#   'liveness': 0.15518700000000002,
#   'valence': 0.61564,
#   'tempo': 119.20727,
#   'duration_ms': 243916.26,
#   'time_signature': 3.98},
#  'melodic rap': {'danceability': 0.7387200000000002,
#   'energy': 0.5865,
#   'key': 5.06,
#   'loudness': -7.26596,
#   'mode': 0.57,
#   'speechiness': 0.148276,
#   'acousticness': 0.19128589999999998,
#   'instrumentalness': 0.0023581772,
#   'liveness': 0.17596399999999998,
#   'valence': 0.41952899999999993,
#   'tempo': 123.27427,
#   'duration_ms': 181100.82,
#   'time_signature': 3.96},
#  'country': {'danceability': 0.6034400000000001,
#   'energy': 0.6742100000000001,
#   'key': 5.15,
#   'loudness': -7.449899999999999,
#   'mode': 0.95,
#   'speechiness': 0.04079399999999999,
#   'acousticness': 0.23817674999999996,
#   'instrumentalness': 0.0006857393999999999,
#   'liveness': 0.16651699999999994,
#   'valence': 0.6389900000000001,
#   'tempo': 126.11672,
#   'duration_ms': 206540.84,
#   'time_signature': 3.94},
#  'post-grunge': {'danceability': 0.50026,
#   'energy': 0.8157499999999998,
#   'key': 5.58,
#   'loudness': -5.558889999999999,
#   'mode': 0.62,
#   'speechiness': 0.05659800000000001,
#   'acousticness': 0.0242292423,
#   'instrumentalness': 0.0054100351,
#   'liveness': 0.159129,
#   'valence': 0.486674,
#   'tempo': 124.04229,
#   'duration_ms': 232214.84,
#   'time_signature': 3.93},
#  'desi pop': {'danceability': 0.6738600000000001,
#   'energy': 0.6899500000000001,
#   'key': 5.38,
#   'loudness': -5.49661,
#   'mode': 0.48,
#   'speechiness': 0.090822,
#   'acousticness': 0.33680738000000005,
#   'instrumentalness': 0.0008097829,
#   'liveness': 0.17375200000000002,
#   'valence': 0.559269,
#   'tempo': 109.95584999999997,
#   'duration_ms': 216408.29,
#   'time_signature': 3.98},
#  'alt z': {'danceability': 0.63677,
#   'energy': 0.54377,
#   'key': 5.21,
#   'loudness': -7.084639999999999,
#   'mode': 0.59,
#   'speechiness': 0.08615600000000001,
#   'acousticness': 0.35356034999999997,
#   'instrumentalness': 0.0031037271000000006,
#   'liveness': 0.16158,
#   'valence': 0.453335,
#   'tempo': 121.68363,
#   'duration_ms': 185244.67,
#   'time_signature': 3.93},
#  'banda': {'danceability': 0.70784,
#   'energy': 0.59686,
#   'key': 5.2,
#   'loudness': -5.857360000000001,
#   'mode': 0.83,
#   'speechiness': 0.054511000000000004,
#   'acousticness': 0.4495035,
#   'instrumentalness': 0.0079608246,
#   'liveness': 0.148934,
#   'valence': 0.8364199999999998,
#   'tempo': 126.89725,
#   'duration_ms': 191965.85,
#   'time_signature': 3.6},
#  'urban contemporary': {'danceability': 0.6943299999999999,
#   'energy': 0.5827,
#   'key': 5.61,
#   'loudness': -7.8873000000000015,
#   'mode': 0.47,
#   'speechiness': 0.09717100000000001,
#   'acousticness': 0.19310788999999995,
#   'instrumentalness': 0.0011494589,
#   'liveness': 0.153997,
#   'valence': 0.60975,
#   'tempo': 111.38564999999998,
#   'duration_ms': 264756.16,
#   'time_signature': 3.98},
#  'sertanejo universitario': {'danceability': 0.63644,
#   'energy': 0.7697700000000002,
#   'key': 5.0,
#   'loudness': -5.05144,
#   'mode': 0.82,
#   'speechiness': 0.068264,
#   'acousticness': 0.41881419999999997,
#   'instrumentalness': 0.008563718599999999,
#   'liveness': 0.485317,
#   'valence': 0.64216,
#   'tempo': 129.05588999999998,
#   'duration_ms': 186786.1,
#   'time_signature': 3.92},
#  'alternative rock': {'danceability': 0.49362,
#   'energy': 0.7324199999999998,
#   'key': 5.35,
#   'loudness': -7.92412,
#   'mode': 0.75,
#   'speechiness': 0.051142999999999994,
#   'acousticness': 0.08597308610000001,
#   'instrumentalness': 0.16639151989999998,
#   'liveness': 0.17828,
#   'valence': 0.600169,
#   'tempo': 124.46858999999999,
#   'duration_ms': 227381.48,
#   'time_signature': 3.96},
#  'art pop': {'danceability': 0.5620599999999999,
#   'energy': 0.534107,
#   'key': 5.19,
#   'loudness': -9.781039999999999,
#   'mode': 0.62,
#   'speechiness': 0.044452,
#   'acousticness': 0.33313599000000005,
#   'instrumentalness': 0.2442911233,
#   'liveness': 0.16289499999999996,
#   'valence': 0.424893,
#   'tempo': 118.73257,
#   'duration_ms': 242936.19,
#   'time_signature': 3.95},
#  'modern bollywood': {'danceability': 0.6581400000000001,
#   'energy': 0.63568,
#   'key': 5.81,
#   'loudness': -6.88467,
#   'mode': 0.62,
#   'speechiness': 0.06026700000000001,
#   'acousticness': 0.3953004,
#   'instrumentalness': 0.013999303200000002,
#   'liveness': 0.16052799999999998,
#   'valence': 0.5871200000000001,
#   'tempo': 117.04547999999998,
#   'duration_ms': 247703.98,
#   'time_signature': 3.87},
#  'atl hip hop': {'danceability': 0.75099,
#   'energy': 0.65224,
#   'key': 5.6,
#   'loudness': -6.026269999999999,
#   'mode': 0.55,
#   'speechiness': 0.186124,
#   'acousticness': 0.11807429000000001,
#   'instrumentalness': 0.000301839,
#   'liveness': 0.18311000000000002,
#   'valence': 0.5217740000000001,
#   'tempo': 122.55659,
#   'duration_ms': 228826.63,
#   'time_signature': 3.91},
#  'reggaeton colombiano': {'danceability': 0.7531899999999999,
#   'energy': 0.71092,
#   'key': 5.51,
#   'loudness': -5.480510000000001,
#   'mode': 0.6,
#   'speechiness': 0.140693,
#   'acousticness': 0.22677786,
#   'instrumentalness': 0.0010318921,
#   'liveness': 0.171205,
#   'valence': 0.6942699999999999,
#   'tempo': 124.82802000000001,
#   'duration_ms': 202500.87,
#   'time_signature': 4.0},
#  'singer-songwriter': {'danceability': 0.55376,
#   'energy': 0.4594241,
#   'key': 4.91,
#   'loudness': -11.724469999999998,
#   'mode': 0.82,
#   'speechiness': 0.039188999999999995,
#   'acousticness': 0.4590644600000001,
#   'instrumentalness': 0.0325468358,
#   'liveness': 0.140831,
#   'valence': 0.541199,
#   'tempo': 115.41674999999998,
#   'duration_ms': 235860.3,
#   'time_signature': 3.96},
#  'country road': {'danceability': 0.5944900000000001,
#   'energy': 0.7146099999999999,
#   'key': 5.15,
#   'loudness': -6.038879999999999,
#   'mode': 0.96,
#   'speechiness': 0.039832000000000006,
#   'acousticness': 0.19655475,
#   'instrumentalness': 0.0013424408999999997,
#   'liveness': 0.18442600000000006,
#   'valence': 0.6290399999999999,
#   'tempo': 128.36532,
#   'duration_ms': 205911.95,
#   'time_signature': 3.95},
#  'colombian pop': {'danceability': 0.6986200000000001,
#   'energy': 0.64385,
#   'key': 5.1,
#   'loudness': -6.45462,
#   'mode': 0.72,
#   'speechiness': 0.076373,
#   'acousticness': 0.3318121,
#   'instrumentalness': 0.000310698,
#   'liveness': 0.16335899999999998,
#   'valence': 0.663137,
#   'tempo': 124.31735,
#   'duration_ms': 204945.56,
#   'time_signature': 3.93},
#  'tropical house': {'danceability': 0.6949399999999999,
#   'energy': 0.71647,
#   'key': 5.03,
#   'loudness': -6.11788,
#   'mode': 0.58,
#   'speechiness': 0.064877,
#   'acousticness': 0.11554029999999998,
#   'instrumentalness': 0.1083327178,
#   'liveness': 0.19140199999999996,
#   'valence': 0.459677,
#   'tempo': 119.35565000000001,
#   'duration_ms': 194152.63,
#   'time_signature': 4.0},
#  'arrocha': {'danceability': 0.6978299999999998,
#   'energy': 0.7696399999999999,
#   'key': 4.25,
#   'loudness': -4.53364,
#   'mode': 0.68,
#   'speechiness': 0.061331,
#   'acousticness': 0.4069302,
#   'instrumentalness': 0.010015004899999999,
#   'liveness': 0.355296,
#   'valence': 0.7221199999999998,
#   'tempo': 133.59372000000002,
#   'duration_ms': 179306.98,
#   'time_signature': 4.0},
#  'french hip hop': {'danceability': 0.7591999999999999,
#   'energy': 0.6499099999999999,
#   'key': 5.23,
#   'loudness': -6.704089999999999,
#   'mode': 0.38,
#   'speechiness': 0.18511399999999997,
#   'acousticness': 0.3170892,
#   'instrumentalness': 0.0006455972999999999,
#   'liveness': 0.138844,
#   'valence': 0.54667,
#   'tempo': 120.60047999999999,
#   'duration_ms': 196590.2,
#   'time_signature': 3.95},
#  'corridos tumbados': {'danceability': 0.66401,
#   'energy': 0.618236,
#   'key': 5.83,
#   'loudness': -7.48218,
#   'mode': 0.46,
#   'speechiness': 0.059419999999999994,
#   'acousticness': 0.37670300000000007,
#   'instrumentalness': 0.00023623910000000002,
#   'liveness': 0.138575,
#   'valence': 0.7227399999999998,
#   'tempo': 114.90483999999998,
#   'duration_ms': 184450.91,
#   'time_signature': 3.08},
#  'southern hip hop': {'danceability': 0.7413799999999999,
#   'energy': 0.65117,
#   'key': 5.8,
#   'loudness': -6.21871,
#   'mode': 0.57,
#   'speechiness': 0.16551,
#   'acousticness': 0.11240064999999999,
#   'instrumentalness': 0.00011366399999999999,
#   'liveness': 0.160557,
#   'valence': 0.510319,
#   'tempo': 115.61499999999998,
#   'duration_ms': 234154.04,
#   'time_signature': 4.0},
#  'pop urbaine': {'danceability': 0.7583,
#   'energy': 0.6532800000000002,
#   'key': 5.32,
#   'loudness': -6.668119999999999,
#   'mode': 0.33,
#   'speechiness': 0.16434099999999996,
#   'acousticness': 0.3146512,
#   'instrumentalness': 0.0010337129,
#   'liveness': 0.133642,
#   'valence': 0.558208,
#   'tempo': 120.85573000000001,
#   'duration_ms': 193617.71,
#   'time_signature': 3.96},
#  'indietronica': {'danceability': 0.6116199999999999,
#   'energy': 0.7101100000000001,
#   'key': 5.28,
#   'loudness': -6.56102,
#   'mode': 0.56,
#   'speechiness': 0.059733,
#   'acousticness': 0.134313539,
#   'instrumentalness': 0.1792484966,
#   'liveness': 0.201188,
#   'valence': 0.527384,
#   'tempo': 123.21812,
#   'duration_ms': 239003.13,
#   'time_signature': 3.98},
#  'mexican pop': {'danceability': 0.65713,
#   'energy': 0.62612,
#   'key': 5.48,
#   'loudness': -7.438490000000001,
#   'mode': 0.75,
#   'speechiness': 0.051331999999999996,
#   'acousticness': 0.36072057,
#   'instrumentalness': 0.0046344479,
#   'liveness': 0.146501,
#   'valence': 0.58718,
#   'tempo': 126.50017,
#   'duration_ms': 222754.28,
#   'time_signature': 3.9},
#  'sertanejo': {'danceability': 0.62679,
#   'energy': 0.71665,
#   'key': 5.24,
#   'loudness': -5.609650000000001,
#   'mode': 0.85,
#   'speechiness': 0.059459,
#   'acousticness': 0.45751220000000004,
#   'instrumentalness': 0.008565655499999998,
#   'liveness': 0.43618100000000015,
#   'valence': 0.62154,
#   'tempo': 125.44367000000004,
#   'duration_ms': 195410.41,
#   'time_signature': 3.84},
#  'indie pop': {'danceability': 0.57168,
#   'energy': 0.568746,
#   'key': 5.26,
#   'loudness': -8.16529,
#   'mode': 0.78,
#   'speechiness': 0.046533,
#   'acousticness': 0.34000271399999993,
#   'instrumentalness': 0.08235196620000002,
#   'liveness': 0.16223100000000001,
#   'valence': 0.443491,
#   'tempo': 118.13105,
#   'duration_ms': 211883.98,
#   'time_signature': 3.9},
#  'pop punk': {'danceability': 0.47190000000000004,
#   'energy': 0.8769900000000002,
#   'key': 4.83,
#   'loudness': -4.28202,
#   'mode': 0.76,
#   'speechiness': 0.089874,
#   'acousticness': 0.027317833099999994,
#   'instrumentalness': 0.009658567300000002,
#   'liveness': 0.19274200000000005,
#   'valence': 0.498484,
#   'tempo': 142.94691999999998,
#   'duration_ms': 208877.38,
#   'time_signature': 3.92},
#  'gangster rap': {'danceability': 0.7768299999999999,
#   'energy': 0.67746,
#   'key': 6.61,
#   'loudness': -6.85833,
#   'mode': 0.45,
#   'speechiness': 0.208402,
#   'acousticness': 0.103786,
#   'instrumentalness': 0.0032834807,
#   'liveness': 0.212355,
#   'valence': 0.61653,
#   'tempo': 111.87710000000001,
#   'duration_ms': 246709.47,
#   'time_signature': 4.0},
#  'latin alternative': {'danceability': 0.6154200000000001,
#   'energy': 0.7315100000000001,
#   'key': 5.94,
#   'loudness': -6.89717,
#   'mode': 0.6,
#   'speechiness': 0.054203,
#   'acousticness': 0.14357142,
#   'instrumentalness': 0.020456803399999998,
#   'liveness': 0.20401000000000002,
#   'valence': 0.6343500000000001,
#   'tempo': 122.78109999999998,
#   'duration_ms': 238421.06,
#   'time_signature': 3.98},
#  'ranchera': {'danceability': 0.54458,
#   'energy': 0.409304,
#   'key': 5.74,
#   'loudness': -9.6205,
#   'mode': 0.8,
#   'speechiness': 0.050086000000000006,
#   'acousticness': 0.605165,
#   'instrumentalness': 0.005417614099999999,
#   'liveness': 0.21356399999999998,
#   'valence': 0.63947,
#   'tempo': 127.73458999999998,
#   'duration_ms': 200447.88,
#   'time_signature': 3.73},
#  'new wave pop': {'danceability': 0.6319199999999999,
#   'energy': 0.7211799999999998,
#   'key': 5.03,
#   'loudness': -8.61421,
#   'mode': 0.67,
#   'speechiness': 0.043397000000000005,
#   'acousticness': 0.18012598999999999,
#   'instrumentalness': 0.027913169800000005,
#   'liveness': 0.18313400000000002,
#   'valence': 0.6824100000000002,
#   'tempo': 118.05326000000001,
#   'duration_ms': 244244.72,
#   'time_signature': 3.98},
#  'j-pop': {'danceability': 0.53096,
#   'energy': 0.7252900000000001,
#   'key': 5.03,
#   'loudness': -4.86512,
#   'mode': 0.86,
#   'speechiness': 0.04676399999999999,
#   'acousticness': 0.217647468,
#   'instrumentalness': 0.0019618407999999997,
#   'liveness': 0.17670099999999997,
#   'valence': 0.49694000000000005,
#   'tempo': 130.87149000000002,
#   'duration_ms': 270261.54,
#   'time_signature': 3.99},
#  'electropop': {'danceability': 0.6243799999999999,
#   'energy': 0.6374399999999999,
#   'key': 4.9,
#   'loudness': -6.906320000000001,
#   'mode': 0.53,
#   'speechiness': 0.068459,
#   'acousticness': 0.21637739,
#   'instrumentalness': 0.0493223203,
#   'liveness': 0.17514300000000002,
#   'valence': 0.441522,
#   'tempo': 119.07942000000001,
#   'duration_ms': 220075.45,
#   'time_signature': 4.02},
#  'rock en espanol': {'danceability': 0.6184000000000001,
#   'energy': 0.7086900000000002,
#   'key': 6.07,
#   'loudness': -7.242019999999999,
#   'mode': 0.61,
#   'speechiness': 0.05427800000000001,
#   'acousticness': 0.17710177,
#   'instrumentalness': 0.011854575399999996,
#   'liveness': 0.202578,
#   'valence': 0.63281,
#   'tempo': 122.74475999999997,
#   'duration_ms': 242752.09,
#   'time_signature': 3.97},
#  'german hip hop': {'danceability': 0.7510600000000001,
#   'energy': 0.6666000000000001,
#   'key': 5.42,
#   'loudness': -6.69355,
#   'mode': 0.39,
#   'speechiness': 0.18744899999999998,
#   'acousticness': 0.20550099999999996,
#   'instrumentalness': 0.011717821600000003,
#   'liveness': 0.140839,
#   'valence': 0.488649,
#   'tempo': 115.42453999999998,
#   'duration_ms': 171625.82,
#   'time_signature': 3.98},
#  'canadian contemporary r&b': {'danceability': 0.6619600000000001,
#   'energy': 0.49805,
#   'key': 5.09,
#   'loudness': -8.36952,
#   'mode': 0.45,
#   'speechiness': 0.08485400000000003,
#   'acousticness': 0.3217297,
#   'instrumentalness': 0.0199344567,
#   'liveness': 0.138631,
#   'valence': 0.427196,
#   'tempo': 110.64761000000003,
#   'duration_ms': 193133.5,
#   'time_signature': 3.92},
#  'soul': {'danceability': 0.64713,
#   'energy': 0.5544800000000001,
#   'key': 5.72,
#   'loudness': -10.088289999999999,
#   'mode': 0.68,
#   'speechiness': 0.05784299999999999,
#   'acousticness': 0.37347699999999995,
#   'instrumentalness': 0.040118412400000004,
#   'liveness': 0.17478100000000002,
#   'valence': 0.7097100000000001,
#   'tempo': 117.09985999999999,
#   'duration_ms': 226754.92,
#   'time_signature': 3.94},
#  'neo mellow': {'danceability': 0.56003,
#   'energy': 0.547295,
#   'key': 4.93,
#   'loudness': -7.67606,
#   'mode': 0.83,
#   'speechiness': 0.042211999999999986,
#   'acousticness': 0.3637394,
#   'instrumentalness': 0.0021139667000000003,
#   'liveness': 0.13357800000000003,
#   'valence': 0.43849899999999997,
#   'tempo': 116.53946,
#   'duration_ms': 224879.73,
#   'time_signature': 3.87},
#  'italian pop': {'danceability': 0.62744,
#   'energy': 0.6917619,
#   'key': 5.84,
#   'loudness': -5.644220000000001,
#   'mode': 0.68,
#   'speechiness': 0.09960100000000001,
#   'acousticness': 0.20762152999999997,
#   'instrumentalness': 0.0006043566,
#   'liveness': 0.16907999999999998,
#   'valence': 0.48383499999999996,
#   'tempo': 121.78129000000001,
#   'duration_ms': 194485.41,
#   'time_signature': 4.01},
#  'electro house': {'danceability': 0.67592,
#   'energy': 0.8531799999999999,
#   'key': 5.82,
#   'loudness': -4.88102,
#   'mode': 0.5,
#   'speechiness': 0.080673,
#   'acousticness': 0.05622573,
#   'instrumentalness': 0.17377817069999998,
#   'liveness': 0.234696,
#   'valence': 0.41378899999999996,
#   'tempo': 127.49162000000003,
#   'duration_ms': 186844.3,
#   'time_signature': 4.0},
#  'latin hip hop': {'danceability': 0.77606,
#   'energy': 0.7561800000000001,
#   'key': 5.87,
#   'loudness': -6.355569999999999,
#   'mode': 0.57,
#   'speechiness': 0.144753,
#   'acousticness': 0.1573175,
#   'instrumentalness': 0.013271365499999998,
#   'liveness': 0.20307199999999997,
#   'valence': 0.70148,
#   'tempo': 109.00926,
#   'duration_ms': 213657.17,
#   'time_signature': 3.97},
#  'latin arena pop': {'danceability': 0.6013799999999999,
#   'energy': 0.67702,
#   'key': 5.04,
#   'loudness': -6.24449,
#   'mode': 0.81,
#   'speechiness': 0.04789900000000001,
#   'acousticness': 0.25268927,
#   'instrumentalness': 0.005230597700000001,
#   'liveness': 0.16804,
#   'valence': 0.5487500000000002,
#   'tempo': 129.19816999999998,
#   'duration_ms': 231748.32,
#   'time_signature': 3.95},
#  'k-pop boy group': {'danceability': 0.66255,
#   'energy': 0.85299,
#   'key': 4.94,
#   'loudness': -3.3717200000000003,
#   'mode': 0.38,
#   'speechiness': 0.09944500000000002,
#   'acousticness': 0.12162994,
#   'instrumentalness': 0.00014938090000000002,
#   'liveness': 0.22022899999999995,
#   'valence': 0.6614399999999999,
#   'tempo': 119.50929000000001,
#   'duration_ms': 204051.17,
#   'time_signature': 4.0},
#  'heartland rock': {'danceability': 0.55171,
#   'energy': 0.63172,
#   'key': 4.98,
#   'loudness': -9.67365,
#   'mode': 0.87,
#   'speechiness': 0.04464200000000001,
#   'acousticness': 0.25993368800000005,
#   'instrumentalness': 0.0403197544,
#   'liveness': 0.164684,
#   'valence': 0.652933,
#   'tempo': 128.40715,
#   'duration_ms': 248714.07,
#   'time_signature': 3.95},
#  'chicago rap': {'danceability': 0.7272600000000001,
#   'energy': 0.6259800000000001,
#   'key': 5.1,
#   'loudness': -7.297129999999999,
#   'mode': 0.65,
#   'speechiness': 0.222271,
#   'acousticness': 0.14415842999999998,
#   'instrumentalness': 0.0061595146,
#   'liveness': 0.20717100000000002,
#   'valence': 0.4519489999999999,
#   'tempo': 124.94314000000003,
#   'duration_ms': 201845.11,
#   'time_signature': 4.03},
#  'pop rock': {'danceability': 0.5414200000000001,
#   'energy': 0.7073539999999998,
#   'key': 5.64,
#   'loudness': -6.674789999999999,
#   'mode': 0.83,
#   'speechiness': 0.043972,
#   'acousticness': 0.16346794400000003,
#   'instrumentalness': 0.0019947135,
#   'liveness': 0.153847,
#   'valence': 0.5275960000000001,
#   'tempo': 122.57092,
#   'duration_ms': 235367.17,
#   'time_signature': 3.96},
#  'canadian hip hop': {'danceability': 0.7316000000000001,
#   'energy': 0.57648,
#   'key': 5.6,
#   'loudness': -7.87964,
#   'mode': 0.39,
#   'speechiness': 0.174616,
#   'acousticness': 0.21903811999999998,
#   'instrumentalness': 0.0011401431,
#   'liveness': 0.150516,
#   'valence': 0.44917699999999994,
#   'tempo': 122.61372999999999,
#   'duration_ms': 186717.74,
#   'time_signature': 3.95},
#  'k-pop girl group': {'danceability': 0.7122200000000001,
#   'energy': 0.8763399999999999,
#   'key': 5.35,
#   'loudness': -2.9295,
#   'mode': 0.54,
#   'speechiness': 0.08126100000000001,
#   'acousticness': 0.11607542700000001,
#   'instrumentalness': 0.0156297953,
#   'liveness': 0.23026700000000003,
#   'valence': 0.6679600000000001,
#   'tempo': 124.13775,
#   'duration_ms': 202994.6,
#   'time_signature': 4.0},
#  'latin rock': {'danceability': 0.59911,
#   'energy': 0.71521,
#   'key': 5.26,
#   'loudness': -6.85774,
#   'mode': 0.6,
#   'speechiness': 0.046357999999999996,
#   'acousticness': 0.16200382370000002,
#   'instrumentalness': 0.0430101537,
#   'liveness': 0.19265399999999996,
#   'valence': 0.6417400000000001,
#   'tempo': 121.77707000000002,
#   'duration_ms': 238984.19,
#   'time_signature': 3.94},
#  'rap metal': {'danceability': 0.5230400000000001,
#   'energy': 0.89337,
#   'key': 5.62,
#   'loudness': -4.843019999999999,
#   'mode': 0.63,
#   'speechiness': 0.09407000000000001,
#   'acousticness': 0.018919266799999997,
#   'instrumentalness': 0.0553254761,
#   'liveness': 0.20154600000000003,
#   'valence': 0.496098,
#   'tempo': 122.44578000000003,
#   'duration_ms': 221409.5,
#   'time_signature': 3.97},
#  'modern alternative rock': {'danceability': 0.53205,
#   'energy': 0.77835,
#   'key': 5.36,
#   'loudness': -5.457819999999998,
#   'mode': 0.56,
#   'speechiness': 0.06298000000000002,
#   'acousticness': 0.0637085756,
#   'instrumentalness': 0.056607313,
#   'liveness': 0.17821800000000004,
#   'valence': 0.483434,
#   'tempo': 129.29539,
#   'duration_ms': 211138.28,
#   'time_signature': 3.95},
#  'conscious hip hop': {'danceability': 0.6928700000000001,
#   'energy': 0.7312099999999999,
#   'key': 5.66,
#   'loudness': -7.06795,
#   'mode': 0.58,
#   'speechiness': 0.23736100000000002,
#   'acousticness': 0.13593201,
#   'instrumentalness': 0.0011682976000000002,
#   'liveness': 0.22759000000000001,
#   'valence': 0.589674,
#   'tempo': 104.52711000000001,
#   'duration_ms': 240605.41,
#   'time_signature': 3.99},
#  'uk dance': {'danceability': 0.6715300000000001,
#   'energy': 0.8144800000000001,
#   'key': 5.63,
#   'loudness': -5.298330000000002,
#   'mode': 0.43,
#   'speechiness': 0.066866,
#   'acousticness': 0.07459028,
#   'instrumentalness': 0.11706304089999998,
#   'liveness': 0.179384,
#   'valence': 0.559382,
#   'tempo': 127.40180999999998,
#   'duration_ms': 187994.82,
#   'time_signature': 3.98},
#  'toronto rap': {'danceability': 0.7553399999999998,
#   'energy': 0.59503,
#   'key': 5.32,
#   'loudness': -7.59156,
#   'mode': 0.47,
#   'speechiness': 0.179768,
#   'acousticness': 0.18114141000000003,
#   'instrumentalness': 0.0025323544,
#   'liveness': 0.144233,
#   'valence': 0.46134300000000006,
#   'tempo': 124.67579000000002,
#   'duration_ms': 182131.15,
#   'time_signature': 4.03},
#  'new wave': {'danceability': 0.62372,
#   'energy': 0.7108000000000001,
#   'key': 4.76,
#   'loudness': -9.15975,
#   'mode': 0.66,
#   'speechiness': 0.044300000000000006,
#   'acousticness': 0.12417942500000001,
#   'instrumentalness': 0.08206241800000001,
#   'liveness': 0.17706599999999995,
#   'valence': 0.6965400000000002,
#   'tempo': 122.4684,
#   'duration_ms': 253047.33,
#   'time_signature': 3.98},
#  'indie rock': {'danceability': 0.5306799999999999,
#   'energy': 0.6746090000000001,
#   'key': 4.73,
#   'loudness': -7.42198,
#   'mode': 0.76,
#   'speechiness': 0.042439,
#   'acousticness': 0.23254469500000002,
#   'instrumentalness': 0.1464197674,
#   'liveness': 0.180484,
#   'valence': 0.5052209999999999,
#   'tempo': 124.83635999999998,
#   'duration_ms': 253901.2,
#   'time_signature': 3.94},
#  'viral pop': {'danceability': 0.5895800000000001,
#   'energy': 0.46157600000000004,
#   'key': 4.74,
#   'loudness': -7.748929999999999,
#   'mode': 0.82,
#   'speechiness': 0.052958999999999985,
#   'acousticness': 0.5019593,
#   'instrumentalness': 0.006235259599999999,
#   'liveness': 0.159974,
#   'valence': 0.41321500000000005,
#   'tempo': 121.87819999999999,
#   'duration_ms': 206120.58,
#   'time_signature': 3.88},
#  'indonesian pop': {'danceability': 0.52521,
#   'energy': 0.46622,
#   'key': 4.98,
#   'loudness': -7.44519,
#   'mode': 0.76,
#   'speechiness': 0.035531,
#   'acousticness': 0.5809551000000001,
#   'instrumentalness': 0.0084134159,
#   'liveness': 0.150588,
#   'valence': 0.3703270000000001,
#   'tempo': 117.76464999999999,
#   'duration_ms': 243609.78,
#   'time_signature': 3.93},
#  'folk rock': {'danceability': 0.5347000000000001,
#   'energy': 0.5009779999999999,
#   'key': 5.08,
#   'loudness': -11.210300000000002,
#   'mode': 0.76,
#   'speechiness': 0.039136,
#   'acousticness': 0.42486446,
#   'instrumentalness': 0.0242106671,
#   'liveness': 0.151737,
#   'valence': 0.576307,
#   'tempo': 117.17844,
#   'duration_ms': 223479.11,
#   'time_signature': 3.97},
#  'new romantic': {'danceability': 0.6342599999999999,
#   'energy': 0.7241500000000001,
#   'key': 4.87,
#   'loudness': -8.816320000000001,
#   'mode': 0.7,
#   'speechiness': 0.04353100000000001,
#   'acousticness': 0.147317613,
#   'instrumentalness': 0.0599220289,
#   'liveness': 0.17278,
#   'valence': 0.6960599999999999,
#   'tempo': 119.289,
#   'duration_ms': 248553.31,
#   'time_signature': 3.98},
#  'house': {'danceability': 0.7184200000000002,
#   'energy': 0.8323299999999999,
#   'key': 5.68,
#   'loudness': -5.998760000000001,
#   'mode': 0.54,
#   'speechiness': 0.072759,
#   'acousticness': 0.04492348000000001,
#   'instrumentalness': 0.3163790142,
#   'liveness': 0.19697199999999998,
#   'valence': 0.581782,
#   'tempo': 125.01653,
#   'duration_ms': 202688.71,
#   'time_signature': 3.99},
#  'east coast hip hop': {'danceability': 0.76976,
#   'energy': 0.71672,
#   'key': 5.61,
#   'loudness': -8.00149,
#   'mode': 0.55,
#   'speechiness': 0.24328500000000003,
#   'acousticness': 0.10953502999999999,
#   'instrumentalness': 0.018413731200000002,
#   'liveness': 0.20545799999999997,
#   'valence': 0.6619499999999999,
#   'tempo': 108.03439999999999,
#   'duration_ms': 252611.46,
#   'time_signature': 4.01},
#  'metal': {'danceability': 0.37607,
#   'energy': 0.88713,
#   'key': 5.07,
#   'loudness': -6.481330000000001,
#   'mode': 0.6,
#   'speechiness': 0.07662700000000001,
#   'acousticness': 0.013825719799999999,
#   'instrumentalness': 0.29617799149999996,
#   'liveness': 0.18895099999999998,
#   'valence': 0.326319,
#   'tempo': 121.57483999999998,
#   'duration_ms': 269052.97,
#   'time_signature': 3.92},
#  'italian hip hop': {'danceability': 0.6688299999999999,
#   'energy': 0.6851299999999999,
#   'key': 5.95,
#   'loudness': -6.32287,
#   'mode': 0.48,
#   'speechiness': 0.169491,
#   'acousticness': 0.25157222,
#   'instrumentalness': 0.0003013097,
#   'liveness': 0.182168,
#   'valence': 0.46572700000000006,
#   'tempo': 118.7589,
#   'duration_ms': 192923.77,
#   'time_signature': 3.93},
#  'trap argentino': {'danceability': 0.7690700000000003,
#   'energy': 0.60896,
#   'key': 4.72,
#   'loudness': -7.217199999999999,
#   'mode': 0.59,
#   'speechiness': 0.11581599999999997,
#   'acousticness': 0.27744259,
#   'instrumentalness': 0.010799494800000002,
#   'liveness': 0.143649,
#   'valence': 0.5229900000000001,
#   'tempo': 126.8161,
#   'duration_ms': 196839.24,
#   'time_signature': 3.97},
#  'bedroom pop': {'danceability': 0.6332,
#   'energy': 0.513806,
#   'key': 5.56,
#   'loudness': -9.632800000000001,
#   'mode': 0.63,
#   'speechiness': 0.046035000000000006,
#   'acousticness': 0.4353002,
#   'instrumentalness': 0.155010046,
#   'liveness': 0.171023,
#   'valence': 0.520852,
#   'tempo': 112.23759000000001,
#   'duration_ms': 199781.15,
#   'time_signature': 3.89},
#  'hoerspiel': {'danceability': 0.60242,
#   'energy': 0.5389200000000001,
#   'key': 4.81,
#   'loudness': -13.972669999999999,
#   'mode': 0.68,
#   'speechiness': 0.86234,
#   'acousticness': 0.5827060000000001,
#   'instrumentalness': 1.07866e-05,
#   'liveness': 0.41583900000000007,
#   'valence': 0.47174499999999997,
#   'tempo': 98.33583,
#   'duration_ms': 171744.62,
#   'time_signature': 3.61},
#  'slap house': {'danceability': 0.7164099999999999,
#   'energy': 0.7856799999999999,
#   'key': 5.26,
#   'loudness': -6.026260000000001,
#   'mode': 0.44,
#   'speechiness': 0.093253,
#   'acousticness': 0.09889894999999999,
#   'instrumentalness': 0.05763957039999999,
#   'liveness': 0.217265,
#   'valence': 0.41812800000000006,
#   'tempo': 123.72628000000003,
#   'duration_ms': 161167.12,
#   'time_signature': 3.96},
#  'west coast rap': {'danceability': 0.7805299999999998,
#   'energy': 0.6668400000000001,
#   'key': 6.03,
#   'loudness': -7.304239999999998,
#   'mode': 0.45,
#   'speechiness': 0.20309100000000002,
#   'acousticness': 0.11180480000000001,
#   'instrumentalness': 0.010755839899999998,
#   'liveness': 0.206792,
#   'valence': 0.615049,
#   'tempo': 100.55128,
#   'duration_ms': 251326.91,
#   'time_signature': 3.98},
#  'talent show': {'danceability': 0.5937100000000001,
#   'energy': 0.6952099999999999,
#   'key': 5.39,
#   'loudness': -5.614760000000001,
#   'mode': 0.71,
#   'speechiness': 0.060186,
#   'acousticness': 0.19682899199999995,
#   'instrumentalness': 0.0119052265,
#   'liveness': 0.19854300000000003,
#   'valence': 0.51923,
#   'tempo': 116.39669000000004,
#   'duration_ms': 214018.86,
#   'time_signature': 3.92},
#  'boy band': {'danceability': 0.65254,
#   'energy': 0.68254,
#   'key': 4.6,
#   'loudness': -6.877449999999999,
#   'mode': 0.62,
#   'speechiness': 0.056112999999999996,
#   'acousticness': 0.16505708999999996,
#   'instrumentalness': 0.0016857501000000002,
#   'liveness': 0.15246099999999999,
#   'valence': 0.6322399999999999,
#   'tempo': 119.76631999999998,
#   'duration_ms': 239031.74,
#   'time_signature': 3.97},
#  'miami hip hop': {'danceability': 0.73868,
#   'energy': 0.6325600000000001,
#   'key': 5.42,
#   'loudness': -7.3163,
#   'mode': 0.52,
#   'speechiness': 0.182542,
#   'acousticness': 0.15655107999999998,
#   'instrumentalness': 0.0015135578999999999,
#   'liveness': 0.19900500000000002,
#   'valence': 0.53338,
#   'tempo': 123.14036,
#   'duration_ms': 215588.89,
#   'time_signature': 4.01},
#  'underground hip hop': {'danceability': 0.7003400000000001,
#   'energy': 0.606261,
#   'key': 5.55,
#   'loudness': -8.02727,
#   'mode': 0.53,
#   'speechiness': 0.199742,
#   'acousticness': 0.19325510999999998,
#   'instrumentalness': 0.006421340199999999,
#   'liveness': 0.21401400000000004,
#   'valence': 0.47830000000000006,
#   'tempo': 120.26951999999997,
#   'duration_ms': 190466.5,
#   'time_signature': 4.01},
#  'spanish pop': {'danceability': 0.61329,
#   'energy': 0.74823,
#   'key': 5.6,
#   'loudness': -6.347410000000001,
#   'mode': 0.76,
#   'speechiness': 0.063494,
#   'acousticness': 0.26678596,
#   'instrumentalness': 0.0010888710999999998,
#   'liveness': 0.18309399999999998,
#   'valence': 0.64197,
#   'tempo': 128.03868,
#   'duration_ms': 226838.95,
#   'time_signature': 3.95},
#  'neo soul': {'danceability': 0.6799299999999999,
#   'energy': 0.53777,
#   'key': 6.07,
#   'loudness': -7.828099999999999,
#   'mode': 0.45,
#   'speechiness': 0.09958700000000002,
#   'acousticness': 0.28111020000000003,
#   'instrumentalness': 0.007563227100000001,
#   'liveness': 0.16538999999999998,
#   'valence': 0.566182,
#   'tempo': 112.31016999999999,
#   'duration_ms': 252754.34,
#   'time_signature': 3.89},
#  'glam metal': {'danceability': 0.46958,
#   'energy': 0.7459200000000002,
#   'key': 5.16,
#   'loudness': -8.514949999999999,
#   'mode': 0.73,
#   'speechiness': 0.057157000000000006,
#   'acousticness': 0.069712831,
#   'instrumentalness': 0.0314191329,
#   'liveness': 0.19767300000000002,
#   'valence': 0.45269200000000004,
#   'tempo': 124.75356,
#   'duration_ms': 261870.61,
#   'time_signature': 3.99},
#  'puerto rican pop': {'danceability': 0.60526,
#   'energy': 0.6285399999999999,
#   'key': 5.43,
#   'loudness': -6.95875,
#   'mode': 0.75,
#   'speechiness': 0.05578100000000001,
#   'acousticness': 0.3762686,
#   'instrumentalness': 0.0013203717,
#   'liveness': 0.17176200000000005,
#   'valence': 0.518827,
#   'tempo': 119.99246000000001,
#   'duration_ms': 236589.37,
#   'time_signature': 3.89},
#  'glam rock': {'danceability': 0.5081700000000001,
#   'energy': 0.70294,
#   'key': 4.94,
#   'loudness': -8.53838,
#   'mode': 0.74,
#   'speechiness': 0.061531,
#   'acousticness': 0.20768087000000002,
#   'instrumentalness': 0.08970480759999999,
#   'liveness': 0.224693,
#   'valence': 0.6147469999999999,
#   'tempo': 127.54077,
#   'duration_ms': 226326.91,
#   'time_signature': 3.96},
#  'stomp and holler': {'danceability': 0.54635,
#   'energy': 0.546639,
#   'key': 4.35,
#   'loudness': -8.485829999999998,
#   'mode': 0.83,
#   'speechiness': 0.037477,
#   'acousticness': 0.43045918,
#   'instrumentalness': 0.038329553899999994,
#   'liveness': 0.151142,
#   'valence': 0.4431900000000001,
#   'tempo': 119.41160000000002,
#   'duration_ms': 224065.25,
#   'time_signature': 3.95},
#  'progressive house': {'danceability': 0.57942,
#   'energy': 0.84205,
#   'key': 5.36,
#   'loudness': -6.9633899999999995,
#   'mode': 0.47,
#   'speechiness': 0.05825,
#   'acousticness': 0.035464419500000004,
#   'instrumentalness': 0.505252022,
#   'liveness': 0.237504,
#   'valence': 0.22726200000000002,
#   'tempo': 127.89469000000001,
#   'duration_ms': 235670.26,
#   'time_signature': 3.99},
#  'piano rock': {'danceability': 0.50879,
#   'energy': 0.641122,
#   'key': 4.97,
#   'loudness': -7.232310000000001,
#   'mode': 0.8,
#   'speechiness': 0.045488999999999995,
#   'acousticness': 0.29319345900000005,
#   'instrumentalness': 0.0183091873,
#   'liveness': 0.16646899999999998,
#   'valence': 0.42916400000000005,
#   'tempo': 126.91212000000002,
#   'duration_ms': 229735.47,
#   'time_signature': 3.9},
#  'dark trap': {'danceability': 0.6732300000000001,
#   'energy': 0.6779900000000001,
#   'key': 4.05,
#   'loudness': -6.57606,
#   'mode': 0.7,
#   'speechiness': 0.154226,
#   'acousticness': 0.11612778599999998,
#   'instrumentalness': 0.0393131899,
#   'liveness': 0.217001,
#   'valence': 0.33191100000000007,
#   'tempo': 124.70790000000001,
#   'duration_ms': 160652.15,
#   'time_signature': 3.93},
#  'ccm': {'danceability': 0.48482,
#   'energy': 0.63519,
#   'key': 5.42,
#   'loudness': -6.29748,
#   'mode': 0.85,
#   'speechiness': 0.041743999999999996,
#   'acousticness': 0.20303358,
#   'instrumentalness': 0.00027700330000000005,
#   'liveness': 0.19903600000000005,
#   'valence': 0.34589400000000003,
#   'tempo': 123.02304999999998,
#   'duration_ms': 256456.47,
#   'time_signature': 3.86},
#  'country rock': {'danceability': 0.56599,
#   'energy': 0.5508500999999999,
#   'key': 5.06,
#   'loudness': -11.26211,
#   'mode': 0.92,
#   'speechiness': 0.040644,
#   'acousticness': 0.33156266799999995,
#   'instrumentalness': 0.0470939599,
#   'liveness': 0.15380799999999997,
#   'valence': 0.651867,
#   'tempo': 119.52003000000002,
#   'duration_ms': 247732.39,
#   'time_signature': 3.95},
#  'punjabi pop': {'danceability': 0.69599,
#   'energy': 0.7345100000000001,
#   'key': 4.89,
#   'loudness': -4.748230000000001,
#   'mode': 0.35,
#   'speechiness': 0.146859,
#   'acousticness': 0.24609760000000006,
#   'instrumentalness': 4.362909999999999e-05,
#   'liveness': 0.17871800000000002,
#   'valence': 0.61183,
#   'tempo': 114.10251999999998,
#   'duration_ms': 195843.78,
#   'time_signature': 4.01},
#  'sleep': {'danceability': 0.160222,
#   'energy': 0.0530696,
#   'key': 3.91,
#   'loudness': -29.442490000000003,
#   'mode': 0.85,
#   'speechiness': 0.048494999999999996,
#   'acousticness': 0.8964799999999998,
#   'instrumentalness': 0.8709599999999998,
#   'liveness': 0.105516,
#   'valence': 0.07258300000000001,
#   'tempo': 98.25598,
#   'duration_ms': 179588.85,
#   'time_signature': 3.6},
#  'synthpop': {'danceability': 0.6361700000000001,
#   'energy': 0.7168399999999999,
#   'key': 4.84,
#   'loudness': -9.306370000000001,
#   'mode': 0.64,
#   'speechiness': 0.04332799999999999,
#   'acousticness': 0.14459898300000001,
#   'instrumentalness': 0.08698468210000002,
#   'liveness': 0.18135099999999998,
#   'valence': 0.6915300000000001,
#   'tempo': 119.845,
#   'duration_ms': 250422.35,
#   'time_signature': 3.99},
#  'detroit hip hop': {'danceability': 0.67925,
#   'energy': 0.6733399999999999,
#   'key': 5.56,
#   'loudness': -7.262560000000002,
#   'mode': 0.6,
#   'speechiness': 0.26274600000000004,
#   'acousticness': 0.11953390300000001,
#   'instrumentalness': 0.023170042099999996,
#   'liveness': 0.21253600000000003,
#   'valence': 0.45316400000000007,
#   'tempo': 121.12362000000002,
#   'duration_ms': 201691.97,
#   'time_signature': 4.07},
#  'rap francais': {'danceability': 0.7556099999999998,
#   'energy': 0.63204,
#   'key': 5.04,
#   'loudness': -7.229490000000001,
#   'mode': 0.38,
#   'speechiness': 0.225152,
#   'acousticness': 0.3385279999999999,
#   'instrumentalness': 0.0007485997,
#   'liveness': 0.138397,
#   'valence': 0.527519,
#   'tempo': 124.04737999999999,
#   'duration_ms': 191495.93,
#   'time_signature': 3.94},
#  'tropical': {'danceability': 0.7328699999999999,
#   'energy': 0.7355099999999999,
#   'key': 5.34,
#   'loudness': -6.494019999999999,
#   'mode': 0.66,
#   'speechiness': 0.053903,
#   'acousticness': 0.36501300000000003,
#   'instrumentalness': 0.007572930099999999,
#   'liveness': 0.152317,
#   'valence': 0.84618,
# ...
#   'time_signature': 3.95},
#  'sound': {'danceability': 0.198915,
#   'energy': 0.6257203,
#   'key': 4.26,
#   'loudness': -25.299930000000003,
#   'mode': 0.59,
#   'speechiness': 0.08828,
#   'acousticness': 0.4749115281000001,
#   'instrumentalness': 0.92119,
#   'liveness': 0.448095,
#   'valence': 0.0603568,
#   'tempo': 91.26526,
#   'duration_ms': 165996.47,
#   'time_signature': 3.66},
#  'ambient': {'danceability': 0.25149,
#   'energy': 0.1790467,
#   'key': 5.15,
#   'loudness': -23.365,
#   'mode': 0.55,
#   'speechiness': 0.048279,
#   'acousticness': 0.79608808,
#   'instrumentalness': 0.8557419999999999,
#   'liveness': 0.12486599999999999,
#   'valence': 0.13334,
#   'tempo': 104.08258,
#   'duration_ms': 294940.98,
#   'time_signature': 3.7},
#  'jazz cover': {'danceability': 0.6764285714285714,
#   'energy': 0.37826938775510205,
#   'key': 4.846938775510204,
#   'loudness': -11.311234693877552,
#   'mode': 0.5714285714285714,
#   'speechiness': 0.04498061224489795,
#   'acousticness': 0.5158727551020409,
#   'instrumentalness': 0.055760695306122446,
#   'liveness': 0.131565306122449,
#   'valence': 0.4191030612244897,
#   'tempo': 118.57647959183673,
#   'duration_ms': 203743.44897959183,
#   'time_signature': 3.9591836734693877},
#  'rock uruguayo': {'danceability': 0.59707,
#   'energy': 0.63754,
#   'key': 6.03,
#   'loudness': -8.102310000000001,
#   'mode': 0.59,
#   'speechiness': 0.06661800000000001,
#   'acousticness': 0.30674014000000005,
#   'instrumentalness': 0.044893192500000005,
#   'liveness': 0.25124399999999997,
#   'valence': 0.6123000000000001,
#   'tempo': 120.18950000000001,
#   'duration_ms': 223069.18,
#   'time_signature': 3.95},
#  'alabama rap': {'danceability': 0.76445,
#   'energy': 0.59102,
#   'key': 4.36,
#   'loudness': -7.89164,
#   'mode': 0.67,
#   'speechiness': 0.24441699999999997,
#   'acousticness': 0.12378054000000001,
#   'instrumentalness': 4.097719999999999e-05,
#   'liveness': 0.20673400000000006,
#   'valence': 0.4670910000000001,
#   'tempo': 124.81931,
#   'duration_ms': 200333.04,
#   'time_signature': 3.96},
#  'funk mandelao': {'danceability': 0.8267900000000001,
#   'energy': 0.72646,
#   'key': 5.09,
#   'loudness': -3.3614100000000002,
#   'mode': 0.6,
#   'speechiness': 0.16504800000000003,
#   'acousticness': 0.34202768000000006,
#   'instrumentalness': 0.028309842900000003,
#   'liveness': 0.19398400000000002,
#   'valence': 0.6221269999999999,
#   'tempo': 130.06904999999998,
#   'duration_ms': 169304.7,
#   'time_signature': 4.02},
#  'musica bajacaliforniana': {'danceability': 0.7034699999999999,
#   'energy': 0.6992300000000001,
#   'key': 5.47,
#   'loudness': -6.96884,
#   'mode': 0.82,
#   'speechiness': 0.08859199999999998,
#   'acousticness': 0.29451,
#   'instrumentalness': 0.0044216901,
#   'liveness': 0.18111799999999995,
#   'valence': 0.8221300000000002,
#   'tempo': 123.39699999999999,
#   'duration_ms': 183503.21,
#   'time_signature': 3.2},
#  'rap baiano': {'danceability': 0.7434600000000002,
#   'energy': 0.59967,
#   'key': 4.93,
#   'loudness': -8.81515,
#   'mode': 0.49,
#   'speechiness': 0.18104599999999998,
#   'acousticness': 0.33200009999999996,
#   'instrumentalness': 0.0156363681,
#   'liveness': 0.15946000000000002,
#   'valence': 0.5476719999999999,
#   'tempo': 117.80476,
#   'duration_ms': 212553.16,
#   'time_signature': 3.93},
#  'rap cristiano': {'danceability': 0.7246999999999999,
#   'energy': 0.7511,
#   'key': 5.5,
#   'loudness': -5.78225,
#   'mode': 0.57,
#   'speechiness': 0.15133000000000002,
#   'acousticness': 0.24451710000000001,
#   'instrumentalness': 0.0003985000999999999,
#   'liveness': 0.164444,
#   'valence': 0.6065699999999999,
#   'tempo': 122.18307,
#   'duration_ms': 223840.6,
#   'time_signature': 3.96},
#  'asmr': {'danceability': 0.475663,
#   'energy': 0.18927089999999996,
#   'key': 4.54,
#   'loudness': -35.39118,
#   'mode': 0.71,
#   'speechiness': 0.13959100000000002,
#   'acousticness': 0.23361592620000005,
#   'instrumentalness': 0.49320477069999996,
#   'liveness': 0.217389,
#   'valence': 0.10308830000000001,
#   'tempo': 99.34668999999998,
#   'duration_ms': 219566.53,
#   'time_signature': 3.5},
#  'jazztronica': {'danceability': 0.6306600000000001,
#   'energy': 0.600153,
#   'key': 5.21,
#   'loudness': -9.343330000000002,
#   'mode': 0.51,
#   'speechiness': 0.05787900000000001,
#   'acousticness': 0.294915478,
#   'instrumentalness': 0.505036724,
#   'liveness': 0.16546300000000003,
#   'valence': 0.503623,
#   'tempo': 117.18421999999998,
#   'duration_ms': 268490.04,
#   'time_signature': 3.92},
#  'german singer-songwriter': {'danceability': 0.6100099999999999,
#   'energy': 0.50714,
#   'key': 5.57,
#   'loudness': -9.01616,
#   'mode': 0.69,
#   'speechiness': 0.06085200000000001,
#   'acousticness': 0.4515787,
#   'instrumentalness': 0.0161780199,
#   'liveness': 0.157912,
#   'valence': 0.46875800000000006,
#   'tempo': 124.52607000000002,
#   'duration_ms': 209510.29,
#   'time_signature': 3.94},
#  'proto-metal': {'danceability': 0.41583,
#   'energy': 0.7129099999999999,
#   'key': 5.4,
#   'loudness': -9.404679999999999,
#   'mode': 0.61,
#   'speechiness': 0.07468599999999999,
#   'acousticness': 0.131392641,
#   'instrumentalness': 0.1941755766,
#   'liveness': 0.18618400000000002,
#   'valence': 0.5796520000000001,
#   'tempo': 124.12342999999997,
#   'duration_ms': 235163.26,
#   'time_signature': 3.93},
#  'pakistani pop': {'danceability': 0.58134,
#   'energy': 0.5274099999999999,
#   'key': 5.06,
#   'loudness': -9.57324,
#   'mode': 0.57,
#   'speechiness': 0.0483,
#   'acousticness': 0.44703200000000004,
#   'instrumentalness': 0.0027232765,
#   'liveness': 0.184867,
#   'valence': 0.499,
#   'tempo': 116.40974,
#   'duration_ms': 302174.18,
#   'time_signature': 3.88},
#  'roots worship': {'danceability': 0.44909000000000016,
#   'energy': 0.3721314,
#   'key': 5.02,
#   'loudness': -10.429930000000002,
#   'mode': 0.91,
#   'speechiness': 0.034712999999999994,
#   'acousticness': 0.5541028480000001,
#   'instrumentalness': 0.024054770099999997,
#   'liveness': 0.1589,
#   'valence': 0.296975,
#   'tempo': 118.79225000000001,
#   'duration_ms': 237643.52,
#   'time_signature': 3.66},
#  'new age piano': {'danceability': 0.36044,
#   'energy': 0.1246495,
#   'key': 5.25,
#   'loudness': -20.61411,
#   'mode': 0.73,
#   'speechiness': 0.045766,
#   'acousticness': 0.9765999999999999,
#   'instrumentalness': 0.9022600000000002,
#   'liveness': 0.10963999999999999,
#   'valence': 0.16959100000000002,
#   'tempo': 105.33799999999998,
#   'duration_ms': 236649.51,
#   'time_signature': 3.72},
#  'st louis rap': {'danceability': 0.7377800000000001,
#   'energy': 0.6162,
#   'key': 5.68,
#   'loudness': -7.995390000000001,
#   'mode': 0.43,
#   'speechiness': 0.22108799999999998,
#   'acousticness': 0.20742326000000003,
#   'instrumentalness': 0.0020914082,
#   'liveness': 0.17377800000000002,
#   'valence': 0.484402,
#   'tempo': 134.05411,
#   'duration_ms': 180852.14,
#   'time_signature': 4.0},
#  'hel': {'danceability': 0.472237,
#   'energy': 0.643155,
#   'key': 5.6,
#   'loudness': -7.529529999999999,
#   'mode': 0.45,
#   'speechiness': 0.052714999999999984,
#   'acousticness': 0.25791341500000003,
#   'instrumentalness': 0.05455248230000001,
#   'liveness': 0.19783,
#   'valence': 0.323758,
#   'tempo': 120.48763,
#   'duration_ms': 247344.26,
#   'time_signature': 3.85},
#  'mississippi hip hop': {'danceability': 0.7187400000000003,
#   'energy': 0.6245,
#   'key': 5.71,
#   'loudness': -7.45085,
#   'mode': 0.54,
#   'speechiness': 0.20805399999999996,
#   'acousticness': 0.20322668,
#   'instrumentalness': 0.0134153945,
#   'liveness': 0.186342,
#   'valence': 0.532522,
#   'tempo': 119.88193,
#   'duration_ms': 203422.09,
#   'time_signature': 4.0},
#  'mexican rock-and-roll': {'danceability': 0.5878199999999999,
#   'energy': 0.516624,
#   'key': 4.98,
#   'loudness': -9.82869,
#   'mode': 0.8,
#   'speechiness': 0.044701,
#   'acousticness': 0.5791451,
#   'instrumentalness': 0.0080191468,
#   'liveness': 0.20273,
#   'valence': 0.6970900000000002,
#   'tempo': 118.62126,
#   'duration_ms': 170752.25,
#   'time_signature': 3.86},
#  'azonto': {'danceability': 0.7873100000000001,
#   'energy': 0.7367199999999999,
#   'key': 5.64,
#   'loudness': -6.399600000000001,
#   'mode': 0.64,
#   'speechiness': 0.090573,
#   'acousticness': 0.21075336,
#   'instrumentalness': 0.021560216999999996,
#   'liveness': 0.15134,
#   'valence': 0.78479,
#   'tempo': 113.31379999999999,
#   'duration_ms': 273438.24,
#   'time_signature': 4.02},
#  'indonesian r&b': {'danceability': 0.5888300000000001,
#   'energy': 0.47644000000000003,
#   'key': 4.15,
#   'loudness': -9.16094,
#   'mode': 0.66,
#   'speechiness': 0.073973,
#   'acousticness': 0.54398,
#   'instrumentalness': 0.053749181199999996,
#   'liveness': 0.19200600000000004,
#   'valence': 0.414318,
#   'tempo': 120.1056,
#   'duration_ms': 226623.41,
#   'time_signature': 3.94},
#  'hands up': {'danceability': 0.60891,
#   'energy': 0.9350200000000001,
#   'key': 5.62,
#   'loudness': -5.7554300000000005,
#   'mode': 0.58,
#   'speechiness': 0.068181,
#   'acousticness': 0.022841352000000006,
#   'instrumentalness': 0.17260787579999998,
#   'liveness': 0.264208,
#   'valence': 0.43302799999999997,
#   'tempo': 141.6892,
#   'duration_ms': 210264.06,
#   'time_signature': 4.0},
#  'scream rap': {'danceability': 0.59689,
#   'energy': 0.7598400000000001,
#   'key': 4.81,
#   'loudness': -5.498179999999999,
#   'mode': 0.74,
#   'speechiness': 0.170068,
#   'acousticness': 0.109640464,
#   'instrumentalness': 0.0539743033,
#   'liveness': 0.261594,
#   'valence': 0.358465,
#   'tempo': 118.63295,
#   'duration_ms': 160877.38,
#   'time_signature': 3.94},
#  'spacegrunge': {'danceability': 0.39604,
#   'energy': 0.74908,
#   'key': 5.29,
#   'loudness': -7.4779599999999995,
#   'mode': 0.77,
#   'speechiness': 0.052897999999999994,
#   'acousticness': 0.08048846850000001,
#   'instrumentalness': 0.3648458766999999,
#   'liveness': 0.19078900000000001,
#   'valence': 0.35301599999999994,
#   'tempo': 128.22004,
#   'duration_ms': 254299.49,
#   'time_signature': 3.91},
#  'south african pop': {'danceability': 0.67849,
#   'energy': 0.6113099999999999,
#   'key': 5.5,
#   'loudness': -8.26862,
#   'mode': 0.57,
#   'speechiness': 0.066837,
#   'acousticness': 0.23175013699999997,
#   'instrumentalness': 0.09555613870000002,
#   'liveness': 0.15710600000000002,
#   'valence': 0.488322,
#   'tempo': 119.94288999999999,
#   'duration_ms': 272011.96,
#   'time_signature': 3.97},
#  'ghanaian hip hop': {'danceability': 0.7552599999999999,
#   'energy': 0.6890199999999999,
#   'key': 4.96,
#   'loudness': -6.682210000000001,
#   'mode': 0.55,
#   'speechiness': 0.17683700000000002,
#   'acousticness': 0.3287819999999999,
#   'instrumentalness': 0.0005647334,
#   'liveness': 0.16989399999999996,
#   'valence': 0.6794330000000001,
#   'tempo': 117.41833000000001,
#   'duration_ms': 213624.61,
#   'time_signature': 3.97},
#  'antiviral pop': {'danceability': 0.66999,
#   'energy': 0.6814930000000001,
#   'key': 6.24,
#   'loudness': -7.04944,
#   'mode': 0.56,
#   'speechiness': 0.10318499999999997,
#   'acousticness': 0.228784609,
#   'instrumentalness': 0.06062810140000001,
#   'liveness': 0.19571100000000002,
#   'valence': 0.572069,
#   'tempo': 121.85843000000001,
#   'duration_ms': 203444.02,
#   'time_signature': 3.95},
#  'tierra caliente': {'danceability': 0.66342,
#   'energy': 0.60421,
#   'key': 5.78,
#   'loudness': -6.790939999999999,
#   'mode': 0.94,
#   'speechiness': 0.08642199999999998,
#   'acousticness': 0.39470200000000005,
#   'instrumentalness': 0.0016044914,
#   'liveness': 0.17001099999999994,
#   'valence': 0.8768600000000001,
#   'tempo': 135.11598,
#   'duration_ms': 187358.09,
#   'time_signature': 3.48},
#  'wonky': {'danceability': 0.5523800000000001,
#   'energy': 0.571303,
#   'key': 5.46,
#   'loudness': -9.56992,
#   'mode': 0.54,
#   'speechiness': 0.11197300000000002,
#   'acousticness': 0.28711423899999994,
#   'instrumentalness': 0.5250305724000001,
#   'liveness': 0.19177,
#   'valence': 0.37191700000000005,
#   'tempo': 116.85895,
#   'duration_ms': 212554.3,
#   'time_signature': 3.95},
#  'westcoast flow': {'danceability': 0.7525499999999999,
#   'energy': 0.55168,
#   'key': 5.09,
#   'loudness': -8.537040000000001,
#   'mode': 0.46,
#   'speechiness': 0.20144300000000004,
#   'acousticness': 0.25557456,
#   'instrumentalness': 0.00011070859999999999,
#   'liveness': 0.147834,
#   'valence': 0.42840000000000006,
#   'tempo': 99.51442000000002,
#   'duration_ms': 164252.62,
#   'time_signature': 3.98},
#  'new jersey indie': {'danceability': 0.47363999999999995,
#   'energy': 0.7297600000000002,
#   'key': 4.65,
#   'loudness': -6.853839999999999,
#   'mode': 0.85,
#   'speechiness': 0.05019699999999999,
#   'acousticness': 0.1522993534,
#   'instrumentalness': 0.11310587899999999,
#   'liveness': 0.18901700000000002,
#   'valence': 0.48274300000000003,
#   'tempo': 124.54739,
#   'duration_ms': 212223.81,
#   'time_signature': 3.95},
#  'future house': {'danceability': 0.6955000000000002,
#   'energy': 0.8442000000000001,
#   'key': 5.52,
#   'loudness': -4.909189999999999,
#   'mode': 0.38,
#   'speechiness': 0.065463,
#   'acousticness': 0.07550503000000001,
#   'instrumentalness': 0.24085783109999997,
#   'liveness': 0.24568900000000002,
#   'valence': 0.381505,
#   'tempo': 125.90346999999998,
#   'duration_ms': 190534.68,
#   'time_signature': 3.97},
#  'classic kollywood': {'danceability': 0.58,
#   'energy': 0.5572299999999999,
#   'key': 4.77,
#   'loudness': -9.264389999999999,
#   'mode': 0.47,
#   'speechiness': 0.09885399999999998,
#   'acousticness': 0.690859,
#   'instrumentalness': 0.1479996009,
#   'liveness': 0.21167599999999998,
#   'valence': 0.7009199999999999,
#   'tempo': 117.99481000000002,
#   'duration_ms': 251245.38,
#   'time_signature': 3.82},
#  'indiecoustica': {'danceability': 0.56088,
#   'energy': 0.4954030000000001,
#   'key': 4.95,
#   'loudness': -8.7573,
#   'mode': 0.89,
#   'speechiness': 0.039093,
#   'acousticness': 0.49612108,
#   'instrumentalness': 0.0312673612,
#   'liveness': 0.12801900000000002,
#   'valence': 0.37797000000000003,
#   'tempo': 119.65051,
#   'duration_ms': 216136.58,
#   'time_signature': 3.88},
#  'viral trap': {'danceability': 0.7569499999999999,
#   'energy': 0.5965400000000001,
#   'key': 5.65,
#   'loudness': -7.66751,
#   'mode': 0.72,
#   'speechiness': 0.175056,
#   'acousticness': 0.1372490248,
#   'instrumentalness': 0.0526393246,
#   'liveness': 0.186756,
#   'valence': 0.43213100000000004,
#   'tempo': 132.95221999999998,
#   'duration_ms': 208351.01,
#   'time_signature': 3.98},
#  'scam rap': {'danceability': 0.703,
#   'energy': 0.6200842105263159,
#   'key': 5.621052631578947,
#   'loudness': -8.188600000000001,
#   'mode': 0.5157894736842106,
#   'speechiness': 0.26658105263157894,
#   'acousticness': 0.11747552105263158,
#   'instrumentalness': 0.0012520662105263158,
#   'liveness': 0.1747873684210527,
#   'valence': 0.38938631578947364,
#   'tempo': 122.11613684210523,
#   'duration_ms': 166072.44210526315,
#   'time_signature': 4.073684210526316},
#  'japanese classical': {'danceability': 0.30932299999999996,
#   'energy': 0.11904960000000003,
#   'key': 5.1,
#   'loudness': -23.12736,
#   'mode': 0.5,
#   'speechiness': 0.052216000000000005,
#   'acousticness': 0.9015099999999999,
#   'instrumentalness': 0.6310145760000001,
#   'liveness': 0.151116,
#   'valence': 0.148264,
#   'tempo': 101.78491,
#   'duration_ms': 313987.0,
#   'time_signature': 3.81},
#  'haryanvi hip hop': {'danceability': 0.7479399999999999,
#   'energy': 0.7792600000000001,
#   'key': 5.27,
#   'loudness': -4.642410000000001,
#   'mode': 0.39,
#   'speechiness': 0.14700000000000002,
#   'acousticness': 0.25267300000000004,
#   'instrumentalness': 0.00018858360000000002,
#   'liveness': 0.265145,
#   'valence': 0.7064900000000002,
#   'tempo': 117.89801000000001,
#   'duration_ms': 210363.22,
#   'time_signature': 3.98},
#  'finnish dance pop': {'danceability': 0.7136100000000001,
#   'energy': 0.7459800000000001,
#   'key': 5.22,
#   'loudness': -5.7533199999999995,
#   'mode': 0.42,
#   'speechiness': 0.097597,
#   'acousticness': 0.12700965000000003,
#   'instrumentalness': 0.0014674883999999996,
#   'liveness': 0.225128,
#   'valence': 0.61942,
#   'tempo': 121.31064,
#   'duration_ms': 198835.63,
#   'time_signature': 3.96},
#  'teen pop': {'danceability': 0.6631100000000001,
#   'energy': 0.63211,
#   'key': 5.38,
#   'loudness': -6.61284,
#   'mode': 0.66,
#   'speechiness': 0.083217,
#   'acousticness': 0.25911842,
#   'instrumentalness': 0.007411857800000001,
#   'liveness': 0.178527,
#   'valence': 0.5304860000000001,
#   'tempo': 118.41672999999999,
#   'duration_ms': 198430.49,
#   'time_signature': 4.0},
#  ...}

# %%
import pandas as pd
import numpy as np

# (same code as before to create genre_track_ids and genre_audio_features_avg)

# Filter the original DataFrame based on genres with averaged out features
valid_genres = [genre for genre, features in genre_audio_features_avg.items() if features is not None]
filtered_df = df[df['GENRE'].isin(valid_genres)].copy()

# Add the average features to the filtered DataFrame
numeric_features = features_df.select_dtypes(include=np.number).columns
for feature_name in numeric_features:
    filtered_df[f'{feature_name}'] = filtered_df['GENRE'].apply(lambda genre: genre_audio_features_avg[genre][feature_name])

# Print the filtered DataFrame with average features
filtered_df.head()
filtered_df.to_csv("avg_genres.csv", index=False)
